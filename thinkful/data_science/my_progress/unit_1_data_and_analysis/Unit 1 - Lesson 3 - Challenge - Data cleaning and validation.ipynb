# %% [markdown]
# # Challenge - Data cleaning and validation

# %%
import re

from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Build DataFrame from csv file
file = 'WELLCOME_APCspend2013_forThinkful.csv'
wellcome = pd.read_csv(file, encoding='ISO-8859-1')

# %%
wellcome
# Out:
#                             PMID/PMCID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# 25                            23072351
# 26                          PMC3477822
# 27                          PMC3530960
# 28                23458425 PMC3630740
# 29                      PMID: 20146481
# ...                                ...
# 2097                           3575693
# 2098        PMID: 22188548 PMC3492912
# 2099        PMID: 22764734 PMC3798095
# 2100                    PMID: 23703895
# 2101                 PMCID: PMC3664106
# 2102                    PMID: 23649934
# 2103                        PMC2955965
# 2104        PMID: 19948006 PMC3551259
# 2105                    PMID: 23305527
# 2106                 PMCID: PMC3600532
# 2107                        PMC3440570
# 2108              23670821 PMC3738939
# 2109                          23640856
# 2110                    PMID: 23918316
# 2111                 PMCID: PMC3728731
# 2112       23495205685.88 PMC3743159
# 2113         PMID:22997008 PMC3569869
# 2114                           3708104
# 2115                        PMC3713766
# 2116                        PMC3819359
# 2117                       PMC3773237
# 2118                       PMC3815011
# 2119                        PMC3805356
# 2120                             Epub
# 2121                        PMC3707567
# 2122                           2901593
# 2123                           3748854
# 2124                           3785148
# 2125          PMCID:\n    PMC3647051\n
# 2126  PMID: 23846567  (Epub July 2013)
#
#                                          Publisher  \
# 0                                              CUP
# 1                                              ACS
# 2                                              ACS
# 3                                              ACS
# 4                                              ACS
# 5                                              ACS
# 6                                              ACS
# 7                                              ACS
# 8     ACS (Amercian Chemical Society) Publications
# 9     ACS (Amercian Chemical Society) Publications
# 10    ACS (Amercian Chemical Society) Publications
# 11    ACS (Amercian Chemical Society) Publications
# 12    ACS (Amercian Chemical Society) Publications
# 13                                ACS Publications
# 14                                ACS Publications
# 15                                   AGA Institute
# 16                                           AMBSB
# 17           American Association of Immunologists
# 18           American Association of Immunologists
# 19                       American Chemical Society
# 20                       American Chemical Society
# 21                       American Chemical Society
# 22                       American Chemical Society
# 23                       AMERICAN CHEMICAL SOCIETY
# 24                       American Chemical Society
# 25                       American Chemical Society
# 26                       American Chemical Society
# 27                       American Chemical Society
# 28                       American Chemical Society
# 29                       American Chemical Society
# ...                                            ...
# 2097                               Wiley-Blackwell
# 2098                               Wiley-Blackwell
# 2099                               Wiley-Blackwell
# 2100                               Wiley-Blackwell
# 2101                               Wiley-Blackwell
# 2102                               Wiley-Blackwell
# 2103                               Wiley-Blackwell
# 2104                               Wiley-Blackwell
# 2105                               Wiley-Blackwell
# 2106                               Wiley-Blackwell
# 2107            Wiley-Blackwell, John Wiley & Sons
# 2108                                     Wiley-VCH
# 2109                                     Wiley-VCH
# 2110                                     Wiley-VCH
# 2111                                     Wiley-VCH
# 2112                                     Wiley-VCH
# 2113                                     Wiley-VCH
# 2114                               Wliey-Blackwell
# 2115                                Wolters Kluwer
# 2116                                Wolters Kluwer
# 2117                                Wolters Kluwer
# 2118                                Wolters Kluwer
# 2119                                Wolters Kluwer
# 2120                                Wolters Kluwer
# 2121                                Wolters Kluwer
# 2122                         Wolters Kluwer Health
# 2123                        Wolters Kluwer Health
# 2124                        Wolters Kluwer Health
# 2125                 Wolters Kluwer N.V./Lippinott
# 2126                               Wolters Kluwers
#
#                                           Journal title  \
# 0                                Psychological Medicine
# 1                                     Biomacromolecules
# 2                                            J Med Chem
# 3                                            J Med Chem
# 4                                            J Org Chem
# 5                        Journal of Medicinal Chemistry
# 6                          Journal of Proteome Research
# 7                                             Mol Pharm
# 8                                  ACS Chemical Biology
# 9                                  ACS Chemical Biology
# 10         Journal of Chemical Information and Modeling
# 11                       Journal of Medicinal Chemistry
# 12                       Journal of Medicinal Chemistry
# 13                                         Biochemistry
# 14                       Journal of Medicinal Chemistry
# 15                                     Gastroenterology
# 16                      Journal of Biological Chemistry
# 17                                Journal of Immunology
# 18                                Journal of Immunology
# 19                                 ACS Chemical Biology
# 20                                 ACS Chemical Biology
# 21                                 ACS Chemical Biology
# 22                            ACS Chemical Neuroscience
# 23                                             ACS NANO
# 24                            American Chemical Society
# 25                                 Analytical Chemistry
# 26                                 Analytical Chemistry
# 27                                 Analytical Chemistry
# 28                               Bioconjugate Chemistry
# 29                       Journal of Medicinal Chemistry
# ...                                                 ...
# 2097                             Molecular Microbiology
# 2098                                    Obesity Reviews
# 2099                                    Obesity Reviews
# 2100                             Statistics in Medicine
# 2101                                         Stem Cells
# 2102                                            Synapse
# 2103               The European Journal of Neuroscience
# 2104                                            Traffic
# 2105                                            Traffic
# 2106                         Zoonoses and Public Health
# 2107                American Journal of Transplantation
# 2108                                 Angew chems Int Ed
# 2109                                        CHEMBIOCHEM
# 2110                                        Chemmedchem
# 2111                                        Chemmedchem
# 2112                                        ChemMedChem
# 2113                                          Protemics
# 2114                   Journal of Small Animal Practice
# 2115                                               AIDS
# 2116                                       AIDS Journal
# 2117                                            AIDS UK
# 2118                                            AIDS UK
# 2119  JAIDS Journal of Acquired Immune Deficiency Sy...
# 2120  Journal of Acquired Immune Deficiency Syndroms...
# 2121                                    Journal of Aids
# 2122                               Circulation Research
# 2123                                               AIDS
# 2124                               Pediatr Infect Dis J
# 2125                                               AIDS
# 2126    Journal of Acquired Immune Deficiency Syndromes
#
#                                           Article title  \
# 0     Reduced parahippocampal cortical thickness in ...
# 1     Structural characterization of a Model Gram-ne...
# 2     Fumaroylamino-4,5-epoxymorphinans and related ...
# 3     Orvinols with mixed kappa/mu opioid receptor a...
# 4     Regioselective opening of myo-inositol orthoes...
# 5     Comparative Structural and Functional Studies ...
# 6     Mapping Proteolytic Processing in the Secretom...
# 7     Quantitative silencing of EGFP reporter gene b...
# 8     A Novel Allosteric Inhibitor of the Uridine Di...
# 9     Chemical proteomic analysis reveals the drugab...
# 10    Locating Sweet Spots for Screening Hits and Ev...
# 11    Synthesis and evaluation of ?-thymidine analog...
# 12    Discovery and structure-activity relationships...
# 13    Monomeric 14-3-3 has a chaperone-like activity...
# 14    Synthesis and in vitro and in vivo characteriz...
# 15    Much of the genetic risk of colorectal cancer ...
# 16                  Annexin-1 interaction with FPR2/ALX
# 17    Sialoadhesin ligand expression identifies a su...
# 18    Regulation of Foxp3+ Inducible Regulatory T Ce...
# 19    Discovery of an allosteric inhibitor binding s...
# 20    Synthesis of alpha-glucan in mycobacteria invo...
# 21    Discovery of ?2 Adrenergic Receptor Ligands Us...
# 22    Continuous online microdialysis using microflu...
# 23    HYDROXY-TERMINATED CONJUGATED POLYMER NANOPART...
# 24    Characterizing the Fatty Acid Binding Site in ...
# 25    Amphipathic polymers facilitate the study of f...
# 26    Quantitative dynamics of phosphorproteome: the...
# 27    Variable-Pitch Rectangular Cross-section Radio...
# 28    Design, synthesis and functional activity of l...
# 29    Toward biophysical probes for the 5-HT3 recept...
# ...                                                 ...
# 2097  Shigella IpaD has a Dual Role: Signal Transduc...
# 2098  Does maternal body mass index during pregnancy...
# 2099  Obesity and socioeconomic status in developing...
# 2100  Combining multiple imputation and meta-analysi...
# 2101  Matrix remodelling maintains ESC self-renewal ...
# 2102  Presynaptic pH and vesicle fusion in Drosophil...
# 2103  Hyperpolarization-activated ion channels as ta...
# 2104  Efficient internalization of MHC I requires ly...
# 2105  Proteomic analysis of clathrin interactions in...
# 2106  Ecology of zoonotic infectious diseases in bat...
# 2107  Low dose rapamycin treatment increases the abi...
# 2108  Design and synthesis of cyclic ADP-4-thioribos...
# 2109  A Prototypical Small-Molecule Modulator Uncoup...
# 2110  Structure-Activity Relationship Studies of Pyr...
# 2111  From On-Target to Off-Target Activity: Identif...
# 2112  Synthesis and structure-activity relationship ...
# 2113  Carbon source-induced reprogramming of the cel...
# 2114  Prevalence, outcome and risk factors for post-...
# 2115  HIV infected adolescents in Southern Africa ca...
# 2116  Short title: TB and VL breakthrough and failur...
# 2117   Sexual behaviour in a rural high HIV prevalence
# 2118  HIV incidence and survival from age-specific s...
# 2119  Accelerated biological ageing in HIV-infected ...
# 2120  Reduction in early mortality on antiretroviral...
# 2121  Risk factors for seropositivity to Kaposi sarc...
# 2122  Mechanistic Links Between Na+ Channel (SCN5A) ...
# 2123  Evaluation of an empiric risk screening score ...
# 2124  Topical umbilical cord care for prevention of ...
# 2125  Grassroots Community Organisations' Contributi...
# 2126  A novel community health worker tool outperfor...
#
#      COST (£) charged to Wellcome (inc VAT when charged)
# 0                                                 £0.00
# 1                                              £2381.04
# 2                                               £642.56
# 3                                               £669.64
# 4                                               £685.88
# 5                                              £2392.20
# 6                                              £2367.95
# 7                                               £649.33
# 8                                              £1294.59
# 9                                              £1294.78
# 10                                             £1329.69
# 11                                             £1287.20
# 12                                             £1324.66
# 13                                              £665.64
# 14                                             £1006.72
# 15                                              £238.08
# 16                                              £265.67
# 17                                             £2035.00
# 18                                             £3108.08
# 19                                             £1267.76
# 20                                             £2286.73
# 21                                              £947.07
# 22                                             £1186.80
# 23                                              £642.89
# 24                                             £1533.29
# 25                                             £2082.74
# 26                                             £2314.10
# 27                                              £759.67
# 28                                             £1565.26
# 29                                              £572.74
# ...                                                 ...
# 2097                                           £2236.02
# 2098                                           £2275.02
# 2099                                           £2373.57
# 2100                                            £791.19
# 2101                                           £1551.49
# 2102                                           £1961.68
# 2103                                           £1982.35
# 2104                                           £2239.22
# 2105                                           £2377.65
# 2106                                           £2272.15
# 2107                                           £1900.70
# 2108                                           £3026.17
# 2109                                           £1851.15
# 2110                                           £1812.89
# 2111                                           £1816.70
# 2112                                           £2168.05
# 2113                                           £1409.96
# 2114                                           £2400.00
# 2115                                           £1968.63
# 2116                                           £2015.72
# 2117                                           £1836.92
# 2118                                           £1836.92
# 2119                                           £1375.80
# 2120                                           £1836.92
# 2121                                           £2009.65
# 2122                                           £1334.15
# 2123                                           £1834.77
# 2124                                           £1834.77
# 2125                                           £2374.52
# 2126                                           £2034.75
#
# [2127 rows x 5 columns]

# %%
# Determine DataFrame shape
wellcome.shape
# Out:
# (2127, 5)

# %%
# Describe the DataFrame
wellcome.describe()
# Out:
#        PMID/PMCID Publisher Journal title  \
# count        1928      2127          2126
# unique       1880       299           984
# top             -  Elsevier      PLoS One
# freq            7       387            92
#
#                                             Article title  \
# count                                                2127
# unique                                               2126
# top     Exclusive breastfeeding, diarrhoel morbidity a...
# freq                                                    2
#
#        COST (£) charged to Wellcome (inc VAT when charged)
# count                                                2127
# unique                                               1402
# top                                              £2040.00
# freq                                                   94

# %% [markdown]
# ### 1. Determine the five most common journals and the total articles for each.

# %%
# After some quick cleaning, what does a Top 20 list for journals look like?
wellcome['Journal title'] = wellcome['Journal title'].apply(lambda x: str(x).upper().strip().replace('  ', ' '))
top_20 = wellcome['Journal title'].value_counts().head(20)
top_20
# Out:
# PLOS ONE                                           191
# JOURNAL OF BIOLOGICAL CHEMISTRY                     53
# NEUROIMAGE                                          29
# NUCLEIC ACIDS RESEARCH                              26
# PLOS PATHOGENS                                      24
# PLOS GENETICS                                       24
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES     22
# PLOS NEGLECTED TROPICAL DISEASES                    20
# NATURE COMMUNICATIONS                               19
# HUMAN MOLECULAR GENETICS                            19
# BMC PUBLIC HEALTH                                   15
# MOVEMENT DISORDERS                                  15
# BRAIN                                               14
# JOURNAL OF NEUROSCIENCE                             13
# BIOCHEMICAL JOURNAL                                 12
# DEVELOPMENTAL CELL                                  12
# JOURNAL OF GENERAL VIROLOGY                         11
# CURRENT BIOLOGY                                     11
# MALARIA JOURNAL                                     10
# BMJ                                                 10
# Name: Journal title, dtype: int64

# %%
# Make a list of unique journal names prior to any additional cleaning
current = wellcome['Journal title'].apply(lambda x: str(x).upper().strip().replace('  ', ' ')).unique()
choices = sorted(list(current))
choices
# Out:
# ['ACADEMY OF NUTRITION AND DIETETICS',
#  'ACS CHEMICAL BIOLOGY',
#  'ACS CHEMICAL NEUROSCIENCE',
#  'ACS NANO',
#  'ACTA CRYSTALLOGRAPHICA SECTION D, BIOLOGICAL CRYSTALLOGRAPHY',
#  'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY',
#  'ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS',
#  'ACTA CRYSTALLOGRAPHICA, SECTION D',
#  'ACTA CRYSTALLOGRAPHY D',
#  'ACTA D',
#  'ACTA DERMATO VENEREOLOGICA',
#  'ACTA DIABETOLOGICA',
#  'ACTA F',
#  'ACTA NEUROPATHOL',
#  'ACTA NEUROPATHOLOGICA',
#  'ACTA OPTHALMOLOGICA',
#  'ACTA PHYSIOL',
#  'ADDICTION',
#  'ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY',
#  'AGE',
#  'AGE AND AGEING',
#  'AGEING & SOCIETY',
#  'AGING CELL',
#  'AIDS',
#  'AIDS BEHAV',
#  'AIDS CARE',
#  'AIDS JOURNAL',
#  'AIDS RESEARCH AND THERAPY',
#  'AIDS UK',
#  'ALCOHOL AND ALCOHOLISM',
#  'ALIMENTRARY PHARMACOLOGY & THERAPEUTICS',
#  'AM J BIOETH',
#  'AM J TROP MED HYG',
#  'AMERICAL JOURNAL OF PSYCHIATRY',
#  'AMERICAN CHEMICAL SOCIETY',
#  'AMERICAN ETHNOLOGIST',
#  'AMERICAN JNL EPIDEMIOLOGY',
#  'AMERICAN JOURNAL FOR CLINICAL NUTRITION',
#  'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE',
#  'AMERICAN JOURNAL OF CLINICAL NUTRITION',
#  'AMERICAN JOURNAL OF EPIDEMIOLOGY',
#  'AMERICAN JOURNAL OF GERIATRIC PSYCHIATRY',
#  'AMERICAN JOURNAL OF HUMAN GENETICS',
#  'AMERICAN JOURNAL OF MEDICAL GENETICS',
#  'AMERICAN JOURNAL OF MEDICAL GENETICS PART A',
#  'AMERICAN JOURNAL OF PATHOLOGY',
#  'AMERICAN JOURNAL OF PREVENTIVE MEDICINE',
#  'AMERICAN JOURNAL OF PSYCHIATRY',
#  'AMERICAN JOURNAL OF PUBLIC HEALTH',
#  'AMERICAN JOURNAL OF TRANSPLANTATION',
#  'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE',
#  'AMERICAN SOCIETY FOR NUTRITION',
#  'ANAL BIOANAL CHEM.',
#  'ANALYTICAL BIOCHEMISTRY',
#  'ANALYTICAL CHEMISTRY',
#  'ANGEW CHEMS INT ED',
#  'ANGEWANDE CHEMIE',
#  'ANGEWANDTE CHEMIE',
#  'ANGEWANDTE CHEMIE INTERNATIONAL EDITION',
#  'ANIMAL BEHAVIOUR',
#  'ANNALS OF HUMAN GENETICS',
#  'ANNALS OF NEUROLOGY',
#  'ANNALS OF SCIENCE',
#  'ANNALS OF THE NEW YORK ACADEMY OF SCIENCES',
#  'ANTIMICOBIAL AGENTS AND CHEMOTHERAPY',
#  'ANTIMICROBIAL AGENTS AND CHEMOTHERAPY',
#  'ANTIMICROBIAL AGFENTS AND CHEMOTHERAPY',
#  'ANTIOXIDANTS & REDOX SIGNALING',
#  'ANTIOXIDANTS AND REDOX SIGNALING',
#  'APPLIED ENERGY',
#  'ARCHIVES OF DISEASE IN CHILDHOOD',
#  'ARTHRITIS & RHEUMATISM',
#  'ARTHRITIS AND RHEUMATISM',
#  'ARTHRITIS RESEARCH & THERAPY',
#  'ARTHRITIS RESEARCH AND THERAPY',
#  'ASIAN JOURNAL OF PSYCHIATRY',
#  'ASN NEURO',
#  'ATHEROSCLEROSIS',
#  'AUTOPHAGY',
#  'AZANIA: ARCHAEOLOGICAL RESEARCH IN AFRICA',
#  'BBA - MOLECULAR BASIS OF DISEASE',
#  'BEHAVIOR RESEARCH AND THERAPY',
#  'BEHAVIORAL NEUROSCIENCE',
#  'BEHAVIOUR RESEARCH AND THERAPY',
#  'BEHAVIOURAL BRAIN RESEARCH',
#  'BIINFORMATICS',
#  'BIOCHEM JOURNAL',
#  'BIOCHEM SOC TRANS',
#  'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS',
#  'BIOCHEMICAL JOURNAL',
#  'BIOCHEMICAL JOURNALS',
#  'BIOCHEMICAL PHARMACOLOGY',
#  'BIOCHEMICAL SOCIETY TRANSACTIONS',
#  'BIOCHEMISTRY',
#  'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS',
#  'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE',
#  'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH',
#  'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE',
#  'BIOCHIMIE',
#  'BIOCONJUGATE CHEMISTRY',
#  'BIOETHICS',
#  'BIOGERONTOLOGY',
#  'BIOINFORMATICS',
#  'BIOINFORMATICS ONLINE',
#  'BIOL OPEN',
#  'BIOLOGICAL PSYCHIATRY',
#  'BIOLOGICAL PSYCHOLOGY',
#  'BIOLOGICIAL CHEMISTRY',
#  'BIOLOGY',
#  'BIOLOGY LETTERS',
#  'BIOLOGY OPEN',
#  'BIOMACROMOLECULES',
#  'BIOMATERIALS',
#  'BIOMED CENTRAL',
#  'BIOMEDICAL MICRODEVICES',
#  'BIOMOLECULAR NMR ASSIGNMENTS',
#  'BIOPHYSICAL JOURNAL',
#  'BIOPOLYMERS',
#  'BIOSCIENCE REPORTS',
#  'BIOSOCIETIES',
#  'BIOSYSTEMS',
#  'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY',
#  'BJOPHTHALMOL',
#  'BJP',
#  'BLOOD',
#  'BLOOD JOURNAL 2012',
#  'BMC BIOLOGY',
#  'BMC GENETICS',
#  'BMC GENOME BIOLOGY',
#  'BMC GENOMICS',
#  'BMC GENOMICS.',
#  'BMC HEALTH SERVICES RESEARCH',
#  'BMC INFECTIOUS DISEASES',
#  'BMC MEDICAL ETHICS',
#  'BMC MEDICAL GENETICS',
#  'BMC MEDICAL IMAGING',
#  'BMC MEDICINE',
#  'BMC MICROBIOLOGY',
#  'BMC MOLECULAR BIOLOGY',
#  'BMC NEUROLOGY',
#  'BMC NEUROSCIENCE',
#  'BMC PEDIATRICS',
#  'BMC PSYCHIATRY',
#  'BMC PUBLIC HEALTH',
#  'BMC RESEARCH NOTES',
#  'BMC VETERINARY RESEARCH',
#  'BMJ',
#  'BMJ OPEN',
#  'BMJ QUALITY AND SAFETY',
#  'BMS GENOMICS',
#  'BONE',
#  'BRAIN',
#  'BRAIN AND COGNITION',
#  'BRAIN AND LANGUAGE',
#  'BRAIN ONLINE',
#  'BRAIN RESEARCH',
#  'BRAIN STRUCTURE AND FUNCTION',
#  'BRAIN TOPOGRAPHY',
#  'BRIEFINGS IN BIOINFORMATICS',
#  'BRIEFINGS IN FUNCTIONAL GENOMICS',
#  'BRITISH JOUNAL OF PHARMACOLOGY',
#  'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE',
#  'BRITISH JOURNAL OF CANCER',
#  'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY',
#  'BRITISH JOURNAL OF DERMATOLOGY',
#  'BRITISH JOURNAL OF HAEMATOLOGY',
#  'BRITISH JOURNAL OF OPHTHALMOLOGY',
#  'BRITISH JOURNAL OF OPTHALMOLOGY',
#  'BRITISH JOURNAL OF PHARMACOLOGY',
#  'BRITISH JOURNAL OF PSYCHIATRY',
#  'BRITISH JOURNAL OF THE HISTORY OF SCIENCE',
#  'BRITISH MEDICAL BULLETIN',
#  'BRITISH MEDICAL JOURNAL',
#  'BRITSH JOURNAL OF PSYCHIATRY',
#  'BRT JNL CLINICAL PHARMACOLOGY',
#  'BULLETIN OF THE HISTORY OF MEDICINE',
#  'CALCIFIED TISSUE INTERNATIONAL',
#  'CANADIAN JOURNAL OF AFRICAN STUDIES',
#  'CANCER LETTERS',
#  'CANCER RESEARCH',
#  'CARDIOVASCULAR RESEARCH',
#  'CELL',
#  'CELL ADHESION AND MIGRATION',
#  'CELL AND TISSUE RESEARCH',
#  'CELL CALCIUM',
#  'CELL CYCLE',
#  'CELL DEATH & DISEASE',
#  'CELL DEATH AND DIFFERENTIATION',
#  'CELL DEATH AND DISEASE',
#  'CELL DEATH DIFFERENTIATION',
#  'CELL HOST & MICROBE',
#  'CELL HOST AND MICROBE',
#  'CELL JOURNAL',
#  'CELL METABOLISM',
#  'CELL PRESS - CELL REPORTS',
#  'CELL REPORTS',
#  'CELL STEM CELL',
#  'CELLULAR AND MOLECULAR CELL SCIENCES',
#  'CELLULAR AND MOLECULAR LIFE SCIENCES',
#  'CELLULAR MICROBIOLOGY',
#  'CELLULAR SIGNALLING',
#  'CENTAURUS',
#  'CEREBRAL CORTEX',
#  'CEREBRAL CORTEX ONLINE',
#  'CEREBRAL CORTEX PRINT',
#  'CHANNELS',
#  'CHEMBIOCHEM',
#  'CHEMICAL COMMUNICATION',
#  'CHEMICAL SOCIETY REVIEWS',
#  'CHEMISTRY - EUROPEAN JOURNAL',
#  'CHEMMEDCHEM',
#  'CHEMSITRY & BIOLOGY',
#  'CHEST',
#  'CHILD NEUROPSYCHOLOGY',
#  'CHILD PSYCHOLOGY PSYCHIATRY',
#  'CHILD: CARE, HEALTH DEVELOPMENT',
#  'CHILD: CARE, HEATH & DEVELOPMENT',
#  'CHILDS NERV SYST',
#  'CHROMOSOME RESEARCH',
#  'CHRONIC ILLNESS',
#  'CIRCULATION RESEARCH',
#  'CLINICAL AND EXPERIMENTAL ALLERGY',
#  'CLINICAL AND VACCINE IMMUNOLOGY',
#  'CLINICAL GENETICS',
#  'CLINICAL INFECTIOUS DISEASES',
#  'CLINICAL INFECTIOUS DISEASES ONLINE',
#  'CLINICAL NEUROLOGY AND NEUROSURGERY',
#  'CLINICAL PROTEOMICS',
#  'CLINICAL RADIOLOGY',
#  'CLINICAL TRANSCRIPTIONAL SCIENCE',
#  'CLINICLA INFECTIOUS DISEASE',
#  'COGNITION',
#  'COGNITIVE DEVELOPMENT',
#  'COGNITIVE PROCESSING',
#  'COGNITIVE THERAPY AND RESEARCH',
#  'COMPUTATIONAL BIOLOGY',
#  'CONSCIOUSNESS & COGNITION',
#  'CONSCIOUSNESS AND COGNITION',
#  'CORTEX',
#  'COST EFFECTIVENESS AND RESOURCE ALLOCATION',
#  'CRIMINAL BEHAVIOR AND MENTAL HEALTH',
#  'CURR BIOL.',
#  'CURRENT ANALYTICAL CHEMISTRY',
#  'CURRENT ATHEROSCLEROSIS REPORTS',
#  'CURRENT BIOLOGY',
#  'CURRENT OBSTETRICS AND GYNECOLOGY REPORTS',
#  'CURRENT OPINION IN NEUROBIOLOGY',
#  'CURRENT OPINION MICROBIOLOGY',
#  'CURRENT OPINIONS IN NEUROBIOLOGY',
#  'CURRENT TOPICS IN MEDICINAL CHEMISTRY',
#  'CYTOSKELETON',
#  'DALTON TRANSACTIONS',
#  'DATABASE',
#  'DEPRESSION AND ANXIETY',
#  'DERMATOLOGIC SURGERY',
#  'DEV WORLD BIOETH.',
#  'DEV. WORLD BIOETH',
#  'DEVELOPING WORLD BIOETHICS',
#  'DEVELOPMENT',
#  'DEVELOPMENT CELL',
#  'DEVELOPMENT DYNAMICS',
#  'DEVELOPMENT GENES AND EVOLUTION',
#  'DEVELOPMENT SCIENCE',
#  'DEVELOPMENTAL BIOLOGY',
#  'DEVELOPMENTAL CELL',
#  'DEVELOPMENTAL COGNITIVE NEUROSCIENCE',
#  'DEVELOPMENTAL SCIENCE',
#  'DIABETIC MEDICINE',
#  'DIABETOLOGIA',
#  'DIAGNOSTIC MICROBIOLOGY AND INFECTIOUS DISEASE',
#  'DISEASE MODELS AND MECHANISMS',
#  'DRUG AND ALCOHOL REVIEW',
#  'ECOLOGY AND EVOLUTION',
#  'ECOLOGY LETTERS',
#  'ECONOMIC HISTORY REVIEW',
#  'ELSEVIER',
#  'EMBO',
#  'EMBO JOURNAL',
#  'EMBO MOLECULAR MEDICINE',
#  'EMBO REPORTS',
#  'EMOTION',
#  'ENDEAVOUR',
#  'ENDOCRINE RELATED CANCER',
#  'ENDOCRINOLOGY',
#  'ENGLISH STUDIES',
#  'ENVIRONMENT AND PLANNING A',
#  'EPIDEMIOLOGY AND INFECTION',
#  'EPIGENETICS',
#  'EPIGENTICS',
#  'EPILEPSIA',
#  'EPILEPSY RESEARCH',
#  'ESSAYS IN BIOCHEMISTRY',
#  'ETHN HEALTH',
#  'EUKARYOTIC CELL',
#  'EUR J IMMUNOL',
#  'EUROPEAN CHILD AND ADOLESCENT PSYCHIATRY',
#  'EUROPEAN CHILD AND ADOLESCENT PSYCHIATTY',
#  'EUROPEAN HEART JOURNAL ONLINE',
#  'EUROPEAN HISTORY QUARTERLY',
#  'EUROPEAN JOURNAL OF CELL BIOLOGY',
#  'EUROPEAN JOURNAL OF CLINICAL PHARMACOLOGY',
#  'EUROPEAN JOURNAL OF ENDOCRINOLOGY',
#  'EUROPEAN JOURNAL OF ENGLISH STUDIES',
#  'EUROPEAN JOURNAL OF EPIDEMIOLOGY',
#  'EUROPEAN JOURNAL OF HEALTH LAW',
#  'EUROPEAN JOURNAL OF HUMAN GENETICS',
#  'EUROPEAN JOURNAL OF IMMUNOLOGY',
#  'EUROPEAN JOURNAL OF MEDICAL GENETICS',
#  'EUROPEAN JOURNAL OF NEUROSCIENCE',
#  'EUROPEAN JOURNAL OF PREVENTIVE CARDIOLOGY',
#  'EUROPEAN JOURNAL OF PUBLIC HEALTH',
#  'EUROPEAN NEUROPSYCHOPHARMACOLOGY',
#  'EUROPEAN RADIOLOGY',
#  'EUROPEAN RESPIRATORY JOURNAL',
#  'EVALUATION IN CLINICAL PRACTICE',
#  'EVIDENCE, ETHOS AND EXPERIMENT: THE ANTHROPOLOGY AND HISTORY OF MEDICAL RESEARCH IN AFRICA.',
#  'EVODEVO',
#  'EVOLUTION',
#  'EVOLUTIONARY APPLICATIONS',
#  'EXPERIMENTAL BRAIN RESEARCH',
#  'EXPERIMENTAL CELL RESEARCH',
#  'EXPERIMENTAL EYE RESEARCH',
#  'EXPERIMENTAL HEMATOLOGY',
#  'EXPERIMENTAL NEUROLOGY',
#  'EXPERIMENTAL PARASITOLOGY',
#  'EXPERIMENTAL PHYSIOLOGY',
#  'EXPERT REVIEWS IN ANTI-INFECTIVE CHEMOTHERAPY',
#  'EXPERT REVIEWS IN MOLECULAR MEDICINE',
#  'FASEB JOURNAL',
#  'FEBS J.',
#  'FEBS JOURNAL',
#  'FEBS LETTERS',
#  'FEBS OPEN BIO',
#  'FEMS MICROBIOLOGY LETTERS',
#  'FERTILITY AND STERILITY',
#  'FREE RADICAL AND BIOLOGY MEDICINE',
#  'FRONTIERS',
#  'FRONTIERS IN AUDITORY COGNITIVE NEUROSCIENCE',
#  'FRONTIERS IN BEHAVIORAL NEUROSCIENCE',
#  'FRONTIERS IN BRAIN IMAGING METHODS',
#  'FRONTIERS IN CELLULAR NEUROSCIENCE',
#  'FRONTIERS IN COGNITION',
#  'FRONTIERS IN COGNITIVE SCIENCE',
#  'FRONTIERS IN CONSCIOUSNESS RESEARCH',
#  'FRONTIERS IN DECISION NEUROSCIENCE',
#  'FRONTIERS IN DEVELOPMENTAL PSYCHOLOGY',
#  'FRONTIERS IN ELECTROPHYSIOLOGY',
#  'FRONTIERS IN ENDOCRINOLOGY',
#  'FRONTIERS IN GENETICS',
#  'FRONTIERS IN HUMAN NEUROSCIENCE',
#  'FRONTIERS IN IMMUNOLOGICAL MEMORY',
#  'FRONTIERS IN IMMUNOLOGY',
#  'FRONTIERS IN INFLAMMATION',
#  'FRONTIERS IN INTEGRATIVE NEUROSCIENCE',
#  'FRONTIERS IN INVERTEBRATE PHYSIOLOGY',
#  'FRONTIERS IN MOLECULAR NEUROSCIENCE',
#  'FRONTIERS IN NEURAL CIRCUITS',
#  'FRONTIERS IN NEUROROBOTICS',
#  'FRONTIERS IN PERCEPTION SCIENCE',
#  'FRONTIERS IN SCHIZOPHRENIA',
#  'FRONTIERS IN SYSTEMS NEUROSCIENCE',
#  'FRONTIERS IN T CELL BIOLOGY',
#  'FRONTLINE GASTROENTEROLOGY',
#  'FUNGAL BIOLOGY',
#  'FUNGAL ECOLOGY',
#  'FUTURE MEDICINAL CHEMISTRY',
#  'FUTURE MICROBIOLOGY',
#  'FUTURE NEUROLOGY',
#  'FUTURE VIROLOGY',
#  'G3: GENES, GENOMES, GENETICS',
#  'GASTROENTEROLOGY',
#  'GENE',
#  'GENE THERAPY',
#  'GENES & DEVELOPMENT',
#  'GENES BRAIN BEHAVIOUR',
#  'GENESIS: JOURNAL OF GENETICS',
#  'GENETIC EPIDEMIOLOGY',
#  'GENETIC EPIDEMOLOGY',
#  'GENETICS',
#  'GENETICS IN MEDICINE',
#  'GENOME BIOLOGY',
#  'GENOME MEDICINE',
#  'GENOME RESEARCH',
#  'GLIA',
#  'GLYCOBIOLOGY',
#  'GUT',
#  'HAEMATOLOGICA',
#  'HAEMATOLOGICA/THE HAEMATOLOGY JOURNAL',
#  'HBM JNL HUMAN BRAIN MAPPING',
#  'HEALTH',
#  'HEALTH & PLACE',
#  'HEALTH AND PLACE',
#  'HEALTH POLICY PLANNING',
#  'HEALTH PROMOTION INTERNATIONAL',
#  'HEALTH PSYCHOLOGY',
#  'HEALTH: AN INTERDISCIPLINARY JOURNAL FOR THE SOCIAL STUDY OF HEALTH, ILLNESS AND MEDICINE',
#  'HEART',
#  'HEART AND CIRCULATORY PHYSIOLOGY',
#  'HEPATOLOGY',
#  'HEPTOLOGY',
#  'HERNIA',
#  'HIPPOCAMPUS',
#  'HISTORY OF THE HUMAN SCIENCES',
#  'HISTORY WORKSHOP JOURNAL',
#  'HPB',
#  'HUM RESOUR HEALTH',
#  'HUMAN BRAIN MAPPING',
#  'HUMAN MOL GENETICS ONLINE',
#  'HUMAN MOLECULAR GENETICS',
#  'HUMAN MOLECULAR GENETICS ONLINE',
#  'HUMAN MUTATION',
#  'HUMAN MUTATION: VARIATION, INFORMATICS, AND DISEASE',
#  'HUMAN REPRODUCTION',
#  'HUMAN RESOURCES FOR HEALTH',
#  'IJTLD',
#  'IMMNUNOBIOLOGY',
#  'IMMUNITY',
#  'IMMUNOGENETICS',
#  'IMMUNOLOGICAL REVIEWS',
#  'IMMUNOLOGY',
#  'IMMUNOLOGY LETTERS',
#  'IMPLEMENT SCI.',
#  'INFECTION AND IMMUNITY',
#  'INFECTION GENETICS AND EVOLUTION',
#  'INFLAMMATION RESEARCH',
#  'INFLAMMATORY BOWEL DISEASES',
#  'INFLUENZA OTHER RESPI VIRUSES.',
#  'INT J EPIDEMIOL',
#  'INT JOURNAL FOR PARASITOLOGY',
#  'INTERFACE',
#  'INTERNATIONAL HEALTH',
#  'INTERNATIONAL IMMUNOLOGY',
#  'INTERNATIONAL JOURAL OF EPIDEMIOLOGY',
#  'INTERNATIONAL JOURNAL FOR EQUITY IN HEALTH',
#  'INTERNATIONAL JOURNAL FOR PARASITOLOGY',
#  'INTERNATIONAL JOURNAL OF APPLIED EARTH OBSERVATION AND GEOINFORMATION',
#  'INTERNATIONAL JOURNAL OF BEHAVIORAL NUTRITION AND PHYSICAL ACTIVITY',
#  'INTERNATIONAL JOURNAL OF BEHAVIOURAL NUTRITION AND PHYSICAL ACTIVITY',
#  'INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY',
#  'INTERNATIONAL JOURNAL OF CARDIOLOGY',
#  'INTERNATIONAL JOURNAL OF DEVELOPMENTAL BIOLOGY',
#  'INTERNATIONAL JOURNAL OF EPIDEMIOLOGY',
#  'INTERNATIONAL JOURNAL OF EXPERIMENTAL PATHOLOGY',
#  'INTERNATIONAL JOURNAL OF FINANCIAL RESEARCH',
#  'INTERNATIONAL JOURNAL OF GERIATRIC PSYCHIATRY',
#  'INTERNATIONAL JOURNAL OF HEALTH GEOGRAPHICS',
#  'INTERNATIONAL JOURNAL OF LAW IN CONTEXT',
#  'INTERNATIONAL JOURNAL OF MOLECULAR SCIENCES',
#  'INTERNATIONAL JOURNAL OF OBESITY',
#  'INTERNATIONAL JOURNAL OF PARASITOLOGY',
#  'INTERNATIONAL JOURNAL OF RHEUMATOLOGY',
#  'INTERNATIONAL JOURNAL OF STROKE',
#  'INTERNATIONAL JOURNAL OF TUBERCULOSIS AND LUNG DISEASE',
#  'INTERNATIONAL PSYCHOGERIATRICS',
#  'INTERNATIONAL REVIEWS OF IMMUNOLOGY',
#  'INYERNATIONAL JOURNAL OF EPIDEMIOLOGY',
#  'J BIOL CHEM.',
#  'J BIOL CHEMISTRY',
#  'J CARDIOVASC MAGN RESON',
#  'J CELL SCI.',
#  'J CLIN MICROBIOL',
#  'J IMMUNOL',
#  'J INFECT DIS',
#  'J MED CHEM',
#  'J MED CHEM.',
#  'J MED INTERNET RESEARCH',
#  'J MOL BIOL',
#  'J ORG CHEM',
#  'J STEROID BIOCHEM MOL BIOL',
#  'J SYNCHROTRON RADIAT.',
#  'JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES',
#  'JERPH',
#  'JNL OF THE INTERNATIONAL NEUROPSYCHOLOGICAL SOCIETY',
#  'JOUNRAL OF CLINICAL MICROBIOLOGY',
#  'JOURNAL OD CLINICAL ENDOCRINOLOGY',
#  'JOURNAL OF ABNORMAL PSYCHOLOGY',
#  'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES',
#  'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)',
#  'JOURNAL OF AFFECTIVE DISORDERS',
#  'JOURNAL OF AIDS',
#  'JOURNAL OF ALLERGY',
#  'JOURNAL OF ALLERGY & CLINICAL IMMUNOLOGY',
#  'JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY',
#  'JOURNAL OF ALZHEIMER DISEASE',
#  'JOURNAL OF ANTHROPOLOGICAL ARCHAEOLOGY',
#  'JOURNAL OF ANTIMICROBIAL CHEMOTHERAPY',
#  'JOURNAL OF APPLIED CRYSTALLOGRAPHY',
#  'JOURNAL OF APPLIED PHYSIOLOGY',
#  'JOURNAL OF ARCHAEOLOGICAL SCIENCE',
#  'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS',
#  'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS',
#  'JOURNAL OF BACTERIOLOGY',
#  'JOURNAL OF BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY',
#  'JOURNAL OF BEHAVIOUR THERAPY AND EXPERIMENTAL PSYCHIATRY',
#  'JOURNAL OF BIOENERGETICS AND BIOMEMBRANES',
#  'JOURNAL OF BIOETHICAL INQUIRY',
#  'JOURNAL OF BIOL CHEM',
#  'JOURNAL OF BIOLOGICAL CHEMISTRY',
#  'JOURNAL OF BIOLOGICAL PHYSICS',
#  'JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING',
#  'JOURNAL OF BONE AND MINERAL RESEARCH',
#  'JOURNAL OF CELL PHYSIOLOGY',
#  'JOURNAL OF CELL SCIENCE',
#  'JOURNAL OF CELLULAR BIOCHEMISTRY',
#  'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM',
#  'JOURNAL OF CHEMICAL INFORMATION AND MODELING',
#  'JOURNAL OF CHEMINFORMATICS',
#  'JOURNAL OF CHILD PSYCHOLOGY AND PSYCHIATRY',
#  'JOURNAL OF CLINICAL ENDOCRINOLOGY',
#  'JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM',
#  'JOURNAL OF CLINICAL EPIDEMIOLOGY',
#  'JOURNAL OF CLINICAL MICROBIOLOGY',
#  'JOURNAL OF CLINICAL PATHOLOGY',
#  'JOURNAL OF CLINICAL VIROLOGY',
#  'JOURNAL OF COGNITIVE NEUROSCIENCE',
#  'JOURNAL OF COMPARATIVE NEUROLOGY',
#  'JOURNAL OF COMPUTATIONAL NEUROSCIENCE',
#  'JOURNAL OF CONSULTING AND CLINICAL PSYCHOLOGY',
#  'JOURNAL OF CULTURAL ECONOMY',
#  'JOURNAL OF CYCSTIC FIBROSIS',
#  'JOURNAL OF DEPRESSION & ANXIETY',
#  'JOURNAL OF ENDOCRINOLOGY',
#  'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH',
#  'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH',
#  'JOURNAL OF EVALUATION IN CLINICAL PRACTICE',
#  'JOURNAL OF EVOLUTIONARY BIOLOGY',
#  'JOURNAL OF EXPERIMENTAL NANOSCIENCE',
#  'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: ANIMAL BEHAVIOUR PROCESS',
#  'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE',
#  'JOURNAL OF FAMILY PSYCHOLOGY',
#  'JOURNAL OF GENERAL VIROLOGY',
#  'JOURNAL OF GERONTOLOGY SERIES A: MEDICAL SCIENCES',
#  'JOURNAL OF HEPATOLOGY',
#  'JOURNAL OF HISTOCHEMISTRY & CYTOCHEMISTRY',
#  'JOURNAL OF HISTORICAL GEOGRAPHY',
#  'JOURNAL OF HOSPITAL INFECTIONS',
#  'JOURNAL OF IMMUNOLOGY',
#  'JOURNAL OF INFECTION',
#  'JOURNAL OF INFECTIOUS DISEASES',
#  'JOURNAL OF INHERITED METABOLIC',
#  'JOURNAL OF INTERNAL MEDICINE',
#  'JOURNAL OF INVESTIGATIVE DERMATOLOGY',
#  'JOURNAL OF LEUKOCYTE BIOLOGY',
#  'JOURNAL OF MECHANISMS OF AGEING AND DEVELOPMENT',
#  'JOURNAL OF MEDICAL ETHICS',
#  'JOURNAL OF MEDICAL GENETICS',
#  'JOURNAL OF MEDICAL VIROLOGY',
#  'JOURNAL OF MEDICINAL CHEMISTRY',
#  'JOURNAL OF MICROBIOLOGY',
#  'JOURNAL OF MICROSCOPY',
#  'JOURNAL OF MOLECULAR BIOLOGY',
#  'JOURNAL OF MOLECULAR ENDOCRINOLOGY',
#  'JOURNAL OF MOLECULAR MEDICINE',
#  'JOURNAL OF MOLECULAR NEUROSCIENCE',
#  'JOURNAL OF NEURAL TRANSMISSION',
#  'JOURNAL OF NEUROCHEMISTRY',
#  'JOURNAL OF NEUROENDOCRINOLOGY',
#  'JOURNAL OF NEUROINFLAMMATION',
#  'JOURNAL OF NEUROLOGY',
#  'JOURNAL OF NEUROLOGY & TRANSLATIONAL NEUROSCIENCE',
#  'JOURNAL OF NEUROLOGY, NEUROSURGERY & PSYCHIATRY',
#  'JOURNAL OF NEUROLOGY, NEUROSURGERY AND PSYCHIATRY',
#  'JOURNAL OF NEUROPHYSIOLOGY',
#  'JOURNAL OF NEUROSCIENCE',
#  'JOURNAL OF NEUROSCIENCE METHODS',
#  'JOURNAL OF NUTRITION',
#  'JOURNAL OF NUTRITION EDUCATION AND BEHAVIOUR',
#  'JOURNAL OF ORTHOPEDIC RESEARCH',
#  'JOURNAL OF PAEDIATRIC UROLOGY',
#  'JOURNAL OF PARASITOLOGY RESEARCH',
#  'JOURNAL OF PATHOLOGY',
#  'JOURNAL OF PHYSIOLOGY',
#  'JOURNAL OF POVERTY AND SOCIAL JUSTICE',
#  'JOURNAL OF PROTEOME RESEARCH',
#  'JOURNAL OF PROTEOMICS',
#  'JOURNAL OF PSYCHOPHARMACOLOGY',
#  'JOURNAL OF PUBLIC HEALTH',
#  'JOURNAL OF SLEEP RESEARCH',
#  'JOURNAL OF SMALL ANIMAL PRACTICE',
#  'JOURNAL OF STRUCTURAL BIOLOGY',
#  'JOURNAL OF THE AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY',
#  'JOURNAL OF THE AMERICAN CHEMICAL SOCIETY',
#  'JOURNAL OF THE AMERICAN COLLEGE OF CARDIOLOGY',
#  'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY',
#  'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY',
#  'JOURNAL OF THE HISTORY OF THE BEHAVIORAL SCIENCES',
#  'JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE',
#  'JOURNAL OF THE INTERNATIONAL AIDS SOCIETY',
#  'JOURNAL OF THE NATIONAL CANCER INSTITUTE',
#  'JOURNAL OF THE NEUROLOGICAL SCIENCES',
#  'JOURNAL OF THE ROYAL SOCIETY INTERFACE',
#  'JOURNAL OF THE ROYAL SOCIETY OF MEDICINE SHORT REPORTS',
#  'JOURNAL OF THE ROYAL SOCIETY, INTERFACE',
#  'JOURNAL OF THE ROYAL STATISTICAL SOCIETY: SERIES C (APPLIED STATISTICS)',
#  'JOURNAL OF TRANSPORT GEOGRAPHY',
#  'JOURNAL OF VIRAL HEPATITIS',
#  'JOURNAL OF VIROL',
#  'JOURNAL OF VIROLOGICAL METHODS',
#  'JOURNAL OF VIROLOGY',
#  'JOURNAL OF VISION',
#  'JOURNAL OF VISUALIZED EXPERIEMENTS',
#  'JOURNAL OF VISUALIZED EXPERIMENTS',
#  'JOURNAL OF VISULAIZED EXPERMIMENTS',
#  'KIDNEY INTERNATIONAL',
#  'LANCET',
#  'LANCET GLOBAL HEALTH',
#  'LANCET INFECT DIS',
#  'LEARNING AND INDIVIDUAL DIFFERENCES',
#  'LEARNING AND MEMORY',
#  'LEUKEMIA',
#  'LIPIDS IN HEALTH AND DISEASE',
#  'MAGNETIC RESONANCE IN MEDICINE',
#  'MALARIA JOURNAL',
#  'MAMMALIAN GENOME',
#  'MARTEN CHILD NUTR',
#  'MATERNAL AND CHILD NUTRITION',
#  'MATH BIOSCI',
#  'MATRIX BIOLOGY',
#  'MATURITAS',
#  'MBIO',
#  'MCP (MOLECULAR & CELLULAR PROTEOMICS)',
#  'MECHANISMS OF AGEING AND DEVELOPMENT',
#  'MEDICAL ANTHROPOLOGY',
#  'MEDICAL HISTORY',
#  'MEDICAL HUMANITIES',
#  'MEDICAL LAW REVIEW',
#  'METABOLOMICS',
#  'METHODS IN MOLECULAR BIOLOGY',
#  'MICROBES AND INFECTION',
#  'MICROBES INFECT',
#  'MICROBIOLOGY',
#  'MOL BIO',
#  'MOL BIOL AND EVOLUTION',
#  'MOL PHARM',
#  'MOLECLUAR & CELLULAR ENDOCRINOLOGY',
#  'MOLECULAR & BIOCHEMICAL PARASITOLOGY',
#  'MOLECULAR & CELLULAR PROTEOMICS',
#  'MOLECULAR AND CELLULAR BIOCHEMISTRY',
#  'MOLECULAR AND CELLULAR BIOLOGY',
#  'MOLECULAR AND CELLULAR ENDOCRINOLOGY',
#  'MOLECULAR AND CELLULAR PROTEOMICS',
#  'MOLECULAR BIOLOGY',
#  'MOLECULAR BIOLOGY AND EVOLUTION',
#  'MOLECULAR BRAIN',
#  'MOLECULAR CELL',
#  'MOLECULAR ENDOCRINOLOGY',
#  'MOLECULAR GENETICS & GENOMIC MEDICINE',
#  'MOLECULAR GENETICS AND METABOLISM',
#  'MOLECULAR IMMUNOLOGY',
#  'MOLECULAR MEMBRANE BIOLOGY',
#  'MOLECULAR MICROBIOLOGY',
#  'MOLECULAR PAIN',
#  'MOLECULAR PHYLOGENETICS AND EVOLUTION',
#  'MOVEMENT DISORDERS',
#  'MUCOSAL IMMUNOLOGY',
#  'MUSCLE AND NERVE',
#  'N BIOTECHNOL.',
#  'NAN',
#  'NANOTECHNOLOGY',
#  'NATIONAL ACADEMY OF SCIENCES',
#  'NATURE COMMUNICATIONS',
#  'NATURE NEUROSCIENCE',
#  'NATURE SCIENTIFIC REPORTS',
#  'NEGLECTED TROPICAL DISEASE',
#  'NEPHROLOGY DIALYSIS AND TRANSPLANTATION',
#  'NEPHROLOGY DIALYSIS TRANSPLANTATION',
#  'NEPHRON PHYSIOLOGY',
#  'NEUROBIOLOGY OF AGING',
#  'NEUROBIOLOGY OF DISEASE',
#  'NEUROBIOLOGY OF LEARNING AND MEMORY',
#  'NEUROCHEMISTRY INTERNATIONAL',
#  'NEURODEGENERATIVE DISEASES',
#  'NEUROEPIDEMIOLOGY',
#  'NEUROGENETICS',
#  'NEUROIMAGE',
#  'NEUROIMAGE: CLINICAL',
#  'NEUROINFORMATICS',
#  'NEUROLOGY',
#  'NEUROMOLECULAR MEDICINE',
#  'NEUROMUSCULAR DISORDERS',
#  'NEURON',
#  'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY',
#  'NEUROPHARMACOLOGY',
#  'NEUROPHYSIOLOGIA',
#  'NEUROPSYCHOBIOLOGY',
#  'NEUROPSYCHOLOGIA',
#  'NEUROPSYCHOPHARMACOLOGY',
#  'NEUROSCIENCE',
#  'NEUROSCIENCE AND BEHAVIOURAL REVIEWS',
#  'NEUROSCIENCE LETTERS',
#  'NEUROSCIENTIST',
#  'NICOTINE AND TOBACO RESEARCH',
#  'NITRIC OXIDE',
#  'NMR IN BIOMEDICINE',
#  'NUCLEIC ACIDS RESEARCH',
#  'NUTRITION JOURNAL',
#  'OBESITY REVIEWS',
#  'ONCOGENE',
#  'ONCOTARGET',
#  'OPEN CHOICE',
#  'OPHTHALMOLOGY',
#  'OPTICS EXPRESS',
#  'ORGANIC & BIOMOLECULAR CHEMISTRY',
#  'ORPHANET JOURNAL OF RARE DISEASES',
#  'OSTEOARTHRITIS AND CARTILAGE',
#  'OSTEOPOROSIS INTERNATIONAL',
#  'OXFORD JOURNALS',
#  'OXFORD UNIVERSITY PRESS',
#  'OXIDATIVE MEDICINE & CELLULAR LONGEVITY',
#  'PAIN',
#  'PARASIT VECTORS.',
#  'PARASITE IMMUNOLOGY',
#  'PARASITES AND VECTORS',
#  'PARASITOLOGY',
#  'PARKINSONISM AND RELATED DISORDERS',
#  'PARSITOLOGY',
#  'PEDIATR INFECT DIS J',
#  'PEDIATRICS',
#  'PERSONALITY AND INDIVIDUAL DIFFERENCES',
#  'PFLUGERS ARCHIV',
#  'PFLUGERS ARCHIVE',
#  'PHILOS TRANS R SOC LONDON B BIOL SCI',
#  'PHILOSOPHICAL TRANSACTIONS B',
#  'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES',
#  'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES',
#  'PHYSICS IN BIOLOGY AND MEDICINE',
#  'PLANT BIOTECHNOLOGY JOURNAL',
#  'PLOS',
#  'PLOS BIOLOGY',
#  'PLOS COMPUTATIONAL BIOLOGY',
#  'PLOS GENETICS',
#  'PLOS MEDICINE',
#  'PLOS MEDICINE JOURNAL',
#  'PLOS NEGECTED TROPICAL DISEASES',
#  'PLOS NEGLECTED TROPICAL DISEASES',
#  'PLOS NTD',
#  'PLOS ONE',
#  'PLOS PATHOGENS',
#  'PMEDICINE-D-12-03130',
#  'PNAS',
#  'PNAS (PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA',
#  'PNAS USA',
#  'PNTD',
#  'PONE-D12-17947',
#  'POPULATION, SPACE AND PLACE',
#  'POSTGRADUATE MEDICAL JOURNAL',
#  'PREVENTIVE MEDICINE',
#  'PROC NATL ACAD SCI U S A.',
#  'PROCEDDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF USA',
#  'PROCEEDINGS B',
#  'PROCEEDINGS OF ROYAL SOCIETY',
#  'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES',
#  'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES (PNAS)',
#  'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA',
#  'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE USA',
#  'PROCEEDINGS OF THE ROYAL SOCIETY',
#  'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES',
#  'PROTEIN ENGINEERING, DESIGN AND SELECTION (',
#  'PROTEIN EXPR PURIF.',
#  'PROTEIN SCIENCE',
#  'PROTEMICS',
#  'PROTIST',
#  'PSYCHOLOGICAL ASSESSMENT',
#  'PSYCHOLOGICAL MEDICINE',
#  'PSYCHOLOGICAL REVIEW',
#  'PSYCHOLOGICAL SCIENCE',
#  'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY',
#  'PSYCHOPHARMACOLOGY',
#  'PUBLIC HEALTH',
#  'PUBLIC HEALTH ETHICS',
#  'PUBLIC HEALTH NUTRITION',
#  'PUBLIC LIBRARY OF SCIENCE',
#  'PUBLIC SERVICE REVIEW',
#  'PULMONARY PHARMACOLOGY & THERAPEUTICS',
#  'PYSCHOLOGICAL MEDICINE',
#  'QJM: AN INTERNATIONAL JOURNAL OF MEDICINE',
#  'QUALITATIVE RESEARCH',
#  'RAPID COMMUNICATIONS IN MASS SPECTROMETRY',
#  'REPRODUCTION(CAMBRIDGE, ENGLAND)',
#  'REPRODUCTIVE MEDICINE AND BIOLOGY',
#  'REPRODUCTIVE SCIENCES',
#  'RESEARCH IN VETERINARY SCIENCE',
#  'RESPIRATION',
#  'RESPIRATORY RESEARCH',
#  'RHEUMATOLOGY',
#  'RNA',
#  'RNA BIOLOGY',
#  'RSTB 2012.0145',
#  'SCHIZOPHRENIA BULLETIN',
#  'SCHIZOPHRENIA RESEARCH',
#  'SCI REP',
#  'SCIENCE AS CULTURE',
#  'SCIENCE-RESEARCH',
#  'SCIENTIFIC REPORTS',
#  'SCIENTIFIC REPORTS-11-00861B',
#  'SEIZURE',
#  'SEMINARS IN IMMUNOPATHOLOGY',
#  'SEMINARS IN ONCOLOGY',
#  'SENSORS',
#  'SEX TRANSM INFECT.',
#  'SEXUALLY TRANSMITTED INFECTIONS',
#  'SGM OPEN OPTION',
#  'SOCIAL COGNITIVE AND AFFECTIVE NEUROSCIENCE',
#  'SOCIAL HISTORY OF MEDICINE',
#  'SOCIAL PSYCHIATRY & PSYCHIATRIC EPIDEMIOLOGY',
#  'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL',
#  'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY',
#  'SOCIAL SCIENCE & MEDICINE',
#  'SOCIAL SCIENCE AND MEDICINE',
#  'SOCIAL STUDIES OF SCIENCE',
#  'SOCIOLOGY OF HEALTH & ILLNESS',
#  'SOUTH ASIAN HISTORY AND CULTURE',
#  'SPEECH LANGUAGE AND HEARING RESEARCH',
#  'SPRINGER',
#  'SPRINGER SCIENCE + BUSINESS MEDIA',
#  'STATISTICS IN MEDICINE',
#  'STEM CELL REPORTS',
#  'STEM CELL RESEARCH',
#  'STEM CELLS',
#  'STEM CELLS AND DEVELOPMENT',
#  'STRUCTURE',
#  'STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C',
#  'STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C: STUDIES IN HISTORY AND PHILOSOPHY OF BIOLOGICAL AND BIOMEDICAL SCIENCES',
#  'SYNAPSE',
#  'TETRAHEDRON LETTERS',
#  'THE AMERICAL JOURNAL OF HUMAN GENETICS',
#  'THE AMERICAN JOURNAL OF HUMAN GENETICS',
#  'THE BIOCHEMICAL JOURNAL',
#  'THE BRITISH JOURNAL OF PSYCHIATRY',
#  'THE EMBO JOURNAL',
#  'THE EUROPEAN JOURNAL OF NEUROSCIENCE',
#  'THE FASEB JOURNAL',
#  'THE FEBS JOURNAL',
#  'THE HISTORY OF THE FAMILY',
#  'THE INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY',
#  'THE JOURNAL OF ABNORMAL CHILD PSYCHOLOGY AND PSYCHIATRY',
#  'THE JOURNAL OF COGNITIVE NEUROSCIENCE',
#  'THE JOURNAL OF IMMUNOLOGY',
#  'THE JOURNAL OF INFECTIOUS DISEASES',
#  'THE JOURNAL OF INVESTIGATIVE DERMATOLOGY',
#  'THE JOURNAL OF NEUROPHYSIOLOGY',
#  'THE JOURNAL OF NEUROSCIENCE',
#  'THE JOURNAL OF PATHOLOGY',
#  'THE JOURNAL OF PHYSIOLOGY',
#  'THE JOURNAL OF STEROID BIOCHEMISTRY & MOLECULAR BIOLOGY',
#  'THE JOURNAL OF VISUALIZED EXPERIMENTS',
#  'THE LANCET',
#  'THE LANCET NEUROLOGY',
#  'THE VET. JOURNAL',
#  'THERANOSTICS',
#  'THORAX',
#  'THORAX AN INTERNATIONAL JOURNAL FOR RESPIRATORY MEDICINE',
#  'TICKS AND TICK-BORNE DISEASES',
#  'TISSUE ENGINEERING: PART A',
#  'TRAFFIC',
#  'TRANSACTIONS OF THE ROYAL SOCIETY OF TROPICAL MEDICINE AND HYGIENE',
#  'TRANSLATIONAL PSYCHIATRY',
#  'TRENDS IN COGNITIVE SCIENCE',
#  'TRENDS IN GENETICS',
#  'TRENDS IN MICROBIOLOGY',
#  'TRENDS IN MOLECULAR MEDICINE',
#  'TRENDS IN NEUROSCIENCE',
#  'TRENDS IN NEUROSCIENCES',
#  'TRENDS IN PARASITOLOGY',
#  'TRIALS',
#  'TROP MED INT HEALTH',
#  'TROPICAL ANIMAL HEALTH & PRODUCTION',
#  'TROPICAL MEDICINE AND INTERNATIONAL HEALTH',
#  'TUBERCULOSIS',
#  'URBAN HISTORY',
#  'UROLITHIASIS',
#  'VACCINE',
#  'VASCULAR PHARMACOLOGY',
#  'VETERINARY MICROBIOLOGY',
#  'VETERINARY PARASITOLOGY',
#  'VETERINARY RECORD',
#  'VETERINARY RESEARCH',
#  'VIROLOGY',
#  'VIROLOGY JOURNAL',
#  'VIRUS RESEARCH',
#  'VISION RESEARCH',
#  'VISUAL NEUROSCIENCE',
#  'ZOONOSES AND PUBLIC HEALTH']

# %%
# Clean Top 20 using fuzzy matching
for journal in list(top_20.index):
    print("Name: ", journal + '\n')
    fuzzy_matching = [x[0] for x in process.extract(journal, choices, limit=20)]
    list_fuzzy_matching = list(enumerate(fuzzy_matching))
    for item in list_fuzzy_matching:
        print(item)
    answer = None
    while answer not in ['y', 'N']:
        answer = input("Does the name in question match any of the items above? (Enter 'y' or 'N'): ")
    index_best_name = None
    indices_other_names = []
    if answer is 'y':
        while index_best_name not in [x[0] for x in list_fuzzy_matching]:
            index_best_name = int(input("Which number corresponds to the best name? (Enter a number): "))
        while indices_other_names == []:
            indices_other_names = input("Enter number(s) separated by commas: ")
            indices_other_names = [int(n) for n in indices_other_names.split(',')]
            for num in indices_other_names:
                if num not in [x[0] for x in list_fuzzy_matching]:
                    indices_other_names = []
                else:
                    pass
        key = list_fuzzy_matching[index_best_name][1]
        vals = [x[1] for x in list_fuzzy_matching if x[0] in indices_other_names]
        print(key, vals)
        print('\n')
        wellcome['Journal title'] = wellcome['Journal title'].apply(lambda x, k=key, v=vals: k if x in v else x)
# Out:
# Name:  PLOS ONE
#
# (0, 'PLOS ONE')
# (1, 'PLOS')
# (2, 'PLOS BIOLOGY')
# (3, 'PLOS COMPUTATIONAL BIOLOGY')
# (4, 'PLOS GENETICS')
# (5, 'PLOS MEDICINE')
# (6, 'PLOS MEDICINE JOURNAL')
# (7, 'PLOS NEGECTED TROPICAL DISEASES')
# (8, 'PLOS NEGLECTED TROPICAL DISEASES')
# (9, 'PLOS PATHOGENS')
# (10, 'PLOS NTD')
# (11, 'ANNALS OF NEUROLOGY')
# (12, 'BONE')
# (13, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (14, 'BIOINFORMATICS ONLINE')
# (15, 'BIOLOGY OPEN')
# (16, 'CHILDS NERV SYST')
# (17, 'CLINICAL INFECTIOUS DISEASES ONLINE')
# (18, 'EUROPEAN HEART JOURNAL ONLINE')
# (19, 'EUROPEAN JOURNAL OF NEUROSCIENCE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF BIOLOGICAL CHEMISTRY
#
# (0, 'JOURNAL OF BIOLOGICAL CHEMISTRY')
# (1, 'ACTA CRYSTALLOGRAPHICA SECTION D, BIOLOGICAL CRYSTALLOGRAPHY')
# (2, 'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY')
# (3, 'AIDS JOURNAL')
# (4, 'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE')
# (5, 'ANALYTICAL CHEMISTRY')
# (6, 'ANNALS OF NEUROLOGY')
# (7, 'ANNALS OF SCIENCE')
# (8, 'BIOCHEM JOURNAL')
# (9, 'BIOCHEMICAL JOURNAL')
# (10, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (11, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (12, 'BIOPHYSICAL JOURNAL')
# (13, 'BLOOD JOURNAL 2012')
# (14, 'CELL JOURNAL')
# (15, 'EMBO JOURNAL')
# (16, 'EVIDENCE, ETHOS AND EXPERIMENT: THE ANTHROPOLOGY AND HISTORY OF MEDICAL RESEARCH IN AFRICA.')
# (17, 'FASEB JOURNAL')
# (18, 'FEBS JOURNAL')
# (19, 'HEALTH: AN INTERDISCIPLINARY JOURNAL FOR THE SOCIAL STUDY OF HEALTH, ILLNESS AND MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES
#
# (0, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (1, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES (PNAS)')
# (2, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE USA')
# (3, 'PROCEDDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF USA')
# (4, 'NATIONAL ACADEMY OF SCIENCES')
# (5, 'PNAS (PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA')
# (6, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES OF THE UNITED STATES OF AMERICA')
# (7, 'AMERICAL JOURNAL OF PSYCHIATRY')
# (8, 'AMERICAN JOURNAL OF PATHOLOGY')
# (9, 'AMERICAN JOURNAL OF PSYCHIATRY')
# (10, 'ANNALS OF HUMAN GENETICS')
# (11, 'ANNALS OF NEUROLOGY')
# (12, 'ANNALS OF SCIENCE')
# (13, 'ASIAN JOURNAL OF PSYCHIATRY')
# (14, 'BRITISH JOUNAL OF PHARMACOLOGY')
# (15, 'BRITISH JOURNAL OF CANCER')
# (16, 'BRITISH JOURNAL OF DERMATOLOGY')
# (17, 'BRITISH JOURNAL OF HAEMATOLOGY')
# (18, 'BRITISH JOURNAL OF OPTHALMOLOGY')
# (19, 'BRITISH JOURNAL OF PHARMACOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  NEUROIMAGE
#
# (0, 'NEUROIMAGE')
# (1, 'AGE')
# (2, 'NEUROIMAGE: CLINICAL')
# (3, 'NEURON')
# (4, 'NEUROSCIENCE')
# (5, 'ACS CHEMICAL NEUROSCIENCE')
# (6, 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE')
# (7, 'BEHAVIORAL NEUROSCIENCE')
# (8, 'BMC NEUROSCIENCE')
# (9, 'CLINICAL NEUROLOGY AND NEUROSURGERY')
# (10, 'DEVELOPMENTAL COGNITIVE NEUROSCIENCE')
# (11, 'EUROPEAN JOURNAL OF NEUROSCIENCE')
# (12, 'FRONTIERS IN BEHAVIORAL NEUROSCIENCE')
# (13, 'FRONTIERS IN CELLULAR NEUROSCIENCE')
# (14, 'FRONTIERS IN DECISION NEUROSCIENCE')
# (15, 'FRONTIERS IN HUMAN NEUROSCIENCE')
# (16, 'FRONTIERS IN INTEGRATIVE NEUROSCIENCE')
# (17, 'FRONTIERS IN MOLECULAR NEUROSCIENCE')
# (18, 'FRONTIERS IN SYSTEMS NEUROSCIENCE')
# (19, 'JOURNAL OF COGNITIVE NEUROSCIENCE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  NUCLEIC ACIDS RESEARCH
#
# (0, 'NUCLEIC ACIDS RESEARCH')
# (1, 'AZANIA: ARCHAEOLOGICAL RESEARCH IN AFRICA')
# (2, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (3, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (4, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (5, 'BRAIN RESEARCH')
# (6, 'EVIDENCE, ETHOS AND EXPERIMENT: THE ANTHROPOLOGY AND HISTORY OF MEDICAL RESEARCH IN AFRICA.')
# (7, 'FRONTIERS IN CONSCIOUSNESS RESEARCH')
# (8, 'INTERNATIONAL JOURNAL OF FINANCIAL RESEARCH')
# (9, 'JOURNAL OF BONE AND MINERAL RESEARCH')
# (10, 'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY')
# (11, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (12, 'SPEECH LANGUAGE AND HEARING RESEARCH')
# (13, 'VIRUS RESEARCH')
# (14, 'AIDS CARE')
# (15, 'SCIENCE-RESEARCH')
# (16, 'AIDS')
# (17, 'CIRCULATION RESEARCH')
# (18, 'QUALITATIVE RESEARCH')
# (19, 'CANCER RESEARCH')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PLOS NEGLECTED TROPICAL DISEASES
#
# (0, 'PLOS NEGLECTED TROPICAL DISEASES')
# (1, 'PLOS NEGECTED TROPICAL DISEASES')
# (2, 'NEGLECTED TROPICAL DISEASE')
# (3, 'PLOS')
# (4, 'PLOS BIOLOGY')
# (5, 'PLOS GENETICS')
# (6, 'PLOS MEDICINE')
# (7, 'PLOS MEDICINE JOURNAL')
# (8, 'PLOS NTD')
# (9, 'PLOS ONE')
# (10, 'PLOS PATHOGENS')
# (11, 'TRANSACTIONS OF THE ROYAL SOCIETY OF TROPICAL MEDICINE AND HYGIENE')
# (12, 'ACTA D')
# (13, 'JOURNAL OF INFECTIOUS DISEASES')
# (14, 'LIPIDS IN HEALTH AND DISEASE')
# (15, 'TICKS AND TICK-BORNE DISEASES')
# (16, 'BMC INFECTIOUS DISEASES')
# (17, 'NEURODEGENERATIVE DISEASES')
# (18, 'THE JOURNAL OF INFECTIOUS DISEASES')
# (19, 'CLINICAL INFECTIOUS DISEASES ONLINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PLOS GENETICS
#
# (0, 'PLOS GENETICS')
# (1, 'GENE')
# (2, 'GENETICS')
# (3, 'PLOS')
# (4, 'AMERICAN JOURNAL OF HUMAN GENETICS')
# (5, 'AMERICAN JOURNAL OF MEDICAL GENETICS')
# (6, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (7, 'ANNALS OF HUMAN GENETICS')
# (8, 'BMC MEDICAL GENETICS')
# (9, 'EUROPEAN JOURNAL OF HUMAN GENETICS')
# (10, 'EUROPEAN JOURNAL OF MEDICAL GENETICS')
# (11, 'FRONTIERS IN GENETICS')
# (12, 'G3: GENES, GENOMES, GENETICS')
# (13, 'GENESIS: JOURNAL OF GENETICS')
# (14, 'GENETICS IN MEDICINE')
# (15, 'HUMAN MOL GENETICS ONLINE')
# (16, 'HUMAN MOLECULAR GENETICS')
# (17, 'HUMAN MOLECULAR GENETICS ONLINE')
# (18, 'INFECTION GENETICS AND EVOLUTION')
# (19, 'JOURNAL OF MEDICAL GENETICS')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PLOS PATHOGENS
#
# (0, 'PLOS PATHOGENS')
# (1, 'PLOS')
# (2, 'PLOS COMPUTATIONAL BIOLOGY')
# (3, 'PLOS MEDICINE JOURNAL')
# (4, 'PLOS NEGECTED TROPICAL DISEASES')
# (5, 'PLOS NEGLECTED TROPICAL DISEASES')
# (6, 'PLOS NTD')
# (7, 'PLOS ONE')
# (8, 'GENE')
# (9, 'PLOS GENETICS')
# (10, 'AGE')
# (11, 'AMERICAN JOURNAL OF PATHOLOGY')
# (12, 'THE JOURNAL OF PATHOLOGY')
# (13, 'SEMINARS IN IMMUNOPATHOLOGY')
# (14, 'PLOS BIOLOGY')
# (15, 'JOURNAL OF PATHOLOGY')
# (16, 'ATHEROSCLEROSIS')
# (17, 'PLOS MEDICINE')
# (18, 'DEVELOPMENT GENES AND EVOLUTION')
# (19, 'INTERNATIONAL JOURNAL OF EXPERIMENTAL PATHOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  HUMAN MOLECULAR GENETICS
#
# (0, 'HUMAN MOLECULAR GENETICS')
# (1, 'HUMAN MOLECULAR GENETICS ONLINE')
# (2, 'GENE')
# (3, 'GENETICS')
# (4, 'AMERICAN JOURNAL OF MEDICAL GENETICS')
# (5, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (6, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (7, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (8, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (9, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (10, 'BMC GENETICS')
# (11, 'CELLULAR AND MOLECULAR CELL SCIENCES')
# (12, 'CELLULAR AND MOLECULAR LIFE SCIENCES')
# (13, 'EUROPEAN JOURNAL OF MEDICAL GENETICS')
# (14, 'EXPERT REVIEWS IN MOLECULAR MEDICINE')
# (15, 'HUMAN MUTATION')
# (16, 'HUMAN MUTATION: VARIATION, INFORMATICS, AND DISEASE')
# (17, 'INTERNATIONAL JOURNAL OF MOLECULAR SCIENCES')
# (18, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE')
# (19, 'MCP (MOLECULAR & CELLULAR PROTEOMICS)')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  NATURE COMMUNICATIONS
#
# (0, 'NATURE COMMUNICATIONS')
# (1, 'ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS')
# (2, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (3, 'RAPID COMMUNICATIONS IN MASS SPECTROMETRY')
# (4, 'CHEMICAL COMMUNICATION')
# (5, 'ADDICTION')
# (6, 'COGNITION')
# (7, 'NAN')
# (8, 'NATURE SCIENTIFIC REPORTS')
# (9, 'FRONTIERS IN COGNITION')
# (10, 'IMMUNITY')
# (11, 'BRAIN AND COGNITION')
# (12, 'NATURE NEUROSCIENCE')
# (13, 'BRAIN')
# (14, 'BRAIN STRUCTURE AND FUNCTION')
# (15, 'CONSCIOUSNESS & COGNITION')
# (16, 'EVOLUTIONARY APPLICATIONS')
# (17, 'CIRCULATION RESEARCH')
# (18, 'EMOTION')
# (19, 'EVALUATION IN CLINICAL PRACTICE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BRAIN
#
# (0, 'BRAIN')
# (1, 'BEHAVIOURAL BRAIN RESEARCH')
# (2, 'BRAIN AND COGNITION')
# (3, 'BRAIN AND LANGUAGE')
# (4, 'BRAIN ONLINE')
# (5, 'BRAIN RESEARCH')
# (6, 'BRAIN STRUCTURE AND FUNCTION')
# (7, 'BRAIN TOPOGRAPHY')
# (8, 'EXPERIMENTAL BRAIN RESEARCH')
# (9, 'FRONTIERS IN BRAIN IMAGING METHODS')
# (10, 'GENES BRAIN BEHAVIOUR')
# (11, 'HBM JNL HUMAN BRAIN MAPPING')
# (12, 'HUMAN BRAIN MAPPING')
# (13, 'MOLECULAR BRAIN')
# (14, 'MOLECULAR MEMBRANE BIOLOGY')
# (15, 'PAIN')
# (16, 'NAN')
# (17, 'RNA')
# (18, 'AGE AND AGEING')
# (19, 'AGEING & SOCIETY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BIOCHEMICAL JOURNAL
#
# (0, 'BIOCHEMICAL JOURNAL')
# (1, 'BIOCHEMICAL JOURNALS')
# (2, 'THE BIOCHEMICAL JOURNAL')
# (3, 'RNA')
# (4, 'BIOCHEM JOURNAL')
# (5, 'AIDS JOURNAL')
# (6, 'AMERICAL JOURNAL OF PSYCHIATRY')
# (7, 'AMERICAN JOURNAL FOR CLINICAL NUTRITION')
# (8, 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE')
# (9, 'AMERICAN JOURNAL OF CLINICAL NUTRITION')
# (10, 'AMERICAN JOURNAL OF EPIDEMIOLOGY')
# (11, 'AMERICAN JOURNAL OF GERIATRIC PSYCHIATRY')
# (12, 'AMERICAN JOURNAL OF HUMAN GENETICS')
# (13, 'AMERICAN JOURNAL OF MEDICAL GENETICS')
# (14, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (15, 'AMERICAN JOURNAL OF PATHOLOGY')
# (16, 'AMERICAN JOURNAL OF PREVENTIVE MEDICINE')
# (17, 'AMERICAN JOURNAL OF PSYCHIATRY')
# (18, 'AMERICAN JOURNAL OF PUBLIC HEALTH')
# (19, 'AMERICAN JOURNAL OF TRANSPLANTATION')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF NEUROSCIENCE
#
# (0, 'JOURNAL OF NEUROSCIENCE')
# (1, 'EUROPEAN JOURNAL OF NEUROSCIENCE')
# (2, 'JOURNAL OF COGNITIVE NEUROSCIENCE')
# (3, 'JOURNAL OF MOLECULAR NEUROSCIENCE')
# (4, 'JOURNAL OF NEUROSCIENCE METHODS')
# (5, 'THE JOURNAL OF NEUROSCIENCE')
# (6, 'NEUROSCIENCE')
# (7, 'RNA')
# (8, 'THE EUROPEAN JOURNAL OF NEUROSCIENCE')
# (9, 'AIDS JOURNAL')
# (10, 'AMERICAN JOURNAL FOR CLINICAL NUTRITION')
# (11, 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE')
# (12, 'AMERICAN JOURNAL OF CLINICAL NUTRITION')
# (13, 'AMERICAN JOURNAL OF GERIATRIC PSYCHIATRY')
# (14, 'AMERICAN JOURNAL OF MEDICAL GENETICS')
# (15, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (16, 'AMERICAN JOURNAL OF PREVENTIVE MEDICINE')
# (17, 'AMERICAN JOURNAL OF TRANSPLANTATION')
# (18, 'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE')
# (19, 'ANNALS OF THE NEW YORK ACADEMY OF SCIENCES')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BMC PUBLIC HEALTH
#
# (0, 'BMC PUBLIC HEALTH')
# (1, 'PUBLIC HEALTH')
# (2, 'HEALTH')
# (3, 'AMERICAN JOURNAL OF PUBLIC HEALTH')
# (4, 'BMC BIOLOGY')
# (5, 'BMC HEALTH SERVICES RESEARCH')
# (6, 'CHILD: CARE, HEALTH DEVELOPMENT')
# (7, 'CRIMINAL BEHAVIOR AND MENTAL HEALTH')
# (8, 'ETHN HEALTH')
# (9, 'EUROPEAN JOURNAL OF HEALTH LAW')
# (10, 'EUROPEAN JOURNAL OF PUBLIC HEALTH')
# (11, 'HEALTH PROMOTION INTERNATIONAL')
# (12, 'HEALTH: AN INTERDISCIPLINARY JOURNAL FOR THE SOCIAL STUDY OF HEALTH, ILLNESS AND MEDICINE')
# (13, 'HUMAN RESOURCES FOR HEALTH')
# (14, 'INTERNATIONAL JOURNAL FOR EQUITY IN HEALTH')
# (15, 'INTERNATIONAL JOURNAL OF HEALTH GEOGRAPHICS')
# (16, 'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH')
# (17, 'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH')
# (18, 'LIPIDS IN HEALTH AND DISEASE')
# (19, 'SOCIOLOGY OF HEALTH & ILLNESS')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  MOVEMENT DISORDERS
#
# (0, 'MOVEMENT DISORDERS')
# (1, 'JOURNAL OF AFFECTIVE DISORDERS')
# (2, 'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS')
# (3, 'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS')
# (4, 'PARKINSONISM AND RELATED DISORDERS')
# (5, 'PNTD')
# (6, 'NEUROMUSCULAR DISORDERS')
# (7, 'GENETICS')
# (8, 'EPIGENTICS')
# (9, 'DEVELOPMENT DYNAMICS')
# (10, 'FRONTIERS')
# (11, 'IMPLEMENT SCI.')
# (12, 'SENSORS')
# (13, 'DEVELOPMENT')
# (14, 'ENDEAVOUR')
# (15, 'EPIGENETICS')
# (16, 'NEURODEGENERATIVE DISEASES')
# (17, 'DEVELOPMENT SCIENCE')
# (18, 'FEBS OPEN BIO')
# (19, 'DEVELOPMENTAL BIOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  DEVELOPMENTAL CELL
#
# (0, 'DEVELOPMENTAL CELL')
# (1, 'DEVELOPMENT CELL')
# (2, 'CELL')
# (3, 'DEVELOPMENT')
# (4, 'AGING CELL')
# (5, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (6, 'CELL ADHESION AND MIGRATION')
# (7, 'CELL CALCIUM')
# (8, 'CELL CYCLE')
# (9, 'CELL DEATH AND DIFFERENTIATION')
# (10, 'CELL JOURNAL')
# (11, 'CELL REPORTS')
# (12, 'CELLULAR AND MOLECULAR CELL SCIENCES')
# (13, 'DEVELOPMENTAL COGNITIVE NEUROSCIENCE')
# (14, 'EUROPEAN JOURNAL OF CELL BIOLOGY')
# (15, 'FRONTIERS IN DEVELOPMENTAL PSYCHOLOGY')
# (16, 'FRONTIERS IN T CELL BIOLOGY')
# (17, 'INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY')
# (18, 'INTERNATIONAL JOURNAL OF DEVELOPMENTAL BIOLOGY')
# (19, 'J CELL SCI.')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  CURRENT BIOLOGY
#
# (0, 'CURRENT BIOLOGY')
# (1, 'BIOLOGY')
# (2, 'ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS')
# (3, 'ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY')
# (4, 'CURRENT ANALYTICAL CHEMISTRY')
# (5, 'CURRENT ATHEROSCLEROSIS REPORTS')
# (6, 'CURRENT OBSTETRICS AND GYNECOLOGY REPORTS')
# (7, 'CURRENT OPINION IN NEUROBIOLOGY')
# (8, 'CURRENT OPINION MICROBIOLOGY')
# (9, 'CURRENT OPINIONS IN NEUROBIOLOGY')
# (10, 'CURRENT TOPICS IN MEDICINAL CHEMISTRY')
# (11, 'EUROPEAN JOURNAL OF CELL BIOLOGY')
# (12, 'FREE RADICAL AND BIOLOGY MEDICINE')
# (13, 'FRONTIERS IN T CELL BIOLOGY')
# (14, 'INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY')
# (15, 'INTERNATIONAL JOURNAL OF DEVELOPMENTAL BIOLOGY')
# (16, 'JOURNAL OF EVOLUTIONARY BIOLOGY')
# (17, 'JOURNAL OF LEUKOCYTE BIOLOGY')
# (18, 'JOURNAL OF MOLECULAR BIOLOGY')
# (19, 'JOURNAL OF STRUCTURAL BIOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF GENERAL VIROLOGY
#
# (0, 'JOURNAL OF GENERAL VIROLOGY')
# (1, 'JOURNAL OF VIROLOGY')
# (2, 'GENE')
# (3, 'VIROLOGY')
# (4, 'AIDS JOURNAL')
# (5, 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE')
# (6, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (7, 'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE')
# (8, 'ANNALS OF SCIENCE')
# (9, 'ANNALS OF THE NEW YORK ACADEMY OF SCIENCES')
# (10, 'BIOCHEM JOURNAL')
# (11, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (12, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (13, 'BLOOD JOURNAL 2012')
# (14, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (15, 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')
# (16, 'CELL JOURNAL')
# (17, 'EMBO JOURNAL')
# (18, 'EUROPEAN JOURNAL OF CLINICAL PHARMACOLOGY')
# (19, 'EUROPEAN JOURNAL OF PREVENTIVE CARDIOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  MALARIA JOURNAL
#
# (0, 'MALARIA JOURNAL')
# (1, 'RNA')
# (2, 'AMERICAL JOURNAL OF PSYCHIATRY')
# (3, 'AMERICAN JOURNAL FOR CLINICAL NUTRITION')
# (4, 'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE')
# (5, 'AMERICAN JOURNAL OF CLINICAL NUTRITION')
# (6, 'AMERICAN JOURNAL OF EPIDEMIOLOGY')
# (7, 'AMERICAN JOURNAL OF GERIATRIC PSYCHIATRY')
# (8, 'AMERICAN JOURNAL OF HUMAN GENETICS')
# (9, 'AMERICAN JOURNAL OF MEDICAL GENETICS')
# (10, 'AMERICAN JOURNAL OF MEDICAL GENETICS PART A')
# (11, 'AMERICAN JOURNAL OF PATHOLOGY')
# (12, 'AMERICAN JOURNAL OF PREVENTIVE MEDICINE')
# (13, 'AMERICAN JOURNAL OF PSYCHIATRY')
# (14, 'AMERICAN JOURNAL OF PUBLIC HEALTH')
# (15, 'AMERICAN JOURNAL OF TRANSPLANTATION')
# (16, 'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE')
# (17, 'ASIAN JOURNAL OF PSYCHIATRY')
# (18, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (19, 'BRITISH JOURNAL OF CANCER')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BMJ
#
# (0, 'BMJ')
# (1, 'BMJ OPEN')
# (2, 'BMJ QUALITY AND SAFETY')
# (3, 'BJP')
# (4, 'AM J BIOETH')
# (5, 'AM J TROP MED HYG')
# (6, 'BIOCHEM JOURNAL')
# (7, 'BJOPHTHALMOL')
# (8, 'BMC BIOLOGY')
# (9, 'BMC GENETICS')
# (10, 'BMC GENOME BIOLOGY')
# (11, 'BMC GENOMICS')
# (12, 'BMC GENOMICS.')
# (13, 'BMC INFECTIOUS DISEASES')
# (14, 'BMC MEDICAL ETHICS')
# (15, 'BMC MEDICAL GENETICS')
# (16, 'BMC MEDICAL IMAGING')
# (17, 'BMC MEDICINE')
# (18, 'BMC MICROBIOLOGY')
# (19, 'BMC MOLECULAR BIOLOGY')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N

# %%
# Updated Top 20 list prior to more cleaning
top_20 = wellcome['Journal title'].value_counts().head(20)
top_20
# Out:
# PLOS ONE                                           208
# JOURNAL OF BIOLOGICAL CHEMISTRY                     65
# NEUROIMAGE                                          31
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES     29
# NUCLEIC ACIDS RESEARCH                              29
# PLOS NEGLECTED TROPICAL DISEASES                    24
# PLOS PATHOGENS                                      24
# PLOS GENETICS                                       24
# HUMAN MOLECULAR GENETICS                            20
# NATURE COMMUNICATIONS                               19
# BRAIN                                               18
# BMC PUBLIC HEALTH                                   15
# MOVEMENT DISORDERS                                  15
# JOURNAL OF NEUROSCIENCE                             15
# BIOCHEMICAL JOURNAL                                 15
# DEVELOPMENTAL CELL                                  13
# JOURNAL OF GENERAL VIROLOGY                         11
# CURRENT BIOLOGY                                     11
# MALARIA JOURNAL                                     10
# BMJ                                                 10
# Name: Journal title, dtype: int64

# %%
# Make a list of unique journal names prior to more cleaning
updated = wellcome['Journal title'].unique()
updated_choices = sorted(list(updated))
updated_choices
# Out:
# ['ACADEMY OF NUTRITION AND DIETETICS',
#  'ACS CHEMICAL BIOLOGY',
#  'ACS CHEMICAL NEUROSCIENCE',
#  'ACS NANO',
#  'ACTA CRYSTALLOGRAPHICA SECTION D, BIOLOGICAL CRYSTALLOGRAPHY',
#  'ACTA CRYSTALLOGRAPHICA SECTION D: BIOLOGICAL CRYSTALLOGRAPHY',
#  'ACTA CRYSTALLOGRAPHICA SECTION F: STRUCTURAL BIOLOGY AND CRYSTALLIZATION COMMUNICATIONS',
#  'ACTA CRYSTALLOGRAPHICA, SECTION D',
#  'ACTA CRYSTALLOGRAPHY D',
#  'ACTA D',
#  'ACTA DERMATO VENEREOLOGICA',
#  'ACTA DIABETOLOGICA',
#  'ACTA F',
#  'ACTA NEUROPATHOL',
#  'ACTA NEUROPATHOLOGICA',
#  'ACTA OPTHALMOLOGICA',
#  'ACTA PHYSIOL',
#  'ADDICTION',
#  'ADVANCES IN EXPERIMENTAL MEDICINE AND BIOLOGY',
#  'AGE',
#  'AGE AND AGEING',
#  'AGEING & SOCIETY',
#  'AGING CELL',
#  'AIDS',
#  'AIDS BEHAV',
#  'AIDS CARE',
#  'AIDS JOURNAL',
#  'AIDS RESEARCH AND THERAPY',
#  'AIDS UK',
#  'ALCOHOL AND ALCOHOLISM',
#  'ALIMENTRARY PHARMACOLOGY & THERAPEUTICS',
#  'AM J BIOETH',
#  'AM J TROP MED HYG',
#  'AMERICAL JOURNAL OF PSYCHIATRY',
#  'AMERICAN CHEMICAL SOCIETY',
#  'AMERICAN ETHNOLOGIST',
#  'AMERICAN JNL EPIDEMIOLOGY',
#  'AMERICAN JOURNAL FOR CLINICAL NUTRITION',
#  'AMERICAN JOURNAL OF BIOETHICS--NEUROSCIENCE',
#  'AMERICAN JOURNAL OF CLINICAL NUTRITION',
#  'AMERICAN JOURNAL OF EPIDEMIOLOGY',
#  'AMERICAN JOURNAL OF GERIATRIC PSYCHIATRY',
#  'AMERICAN JOURNAL OF HUMAN GENETICS',
#  'AMERICAN JOURNAL OF MEDICAL GENETICS',
#  'AMERICAN JOURNAL OF MEDICAL GENETICS PART A',
#  'AMERICAN JOURNAL OF PATHOLOGY',
#  'AMERICAN JOURNAL OF PREVENTIVE MEDICINE',
#  'AMERICAN JOURNAL OF PSYCHIATRY',
#  'AMERICAN JOURNAL OF PUBLIC HEALTH',
#  'AMERICAN JOURNAL OF TRANSPLANTATION',
#  'AMERICAN JOURNAL OF TROPICAL MEDICINE & HYGIENE',
#  'AMERICAN SOCIETY FOR NUTRITION',
#  'ANAL BIOANAL CHEM.',
#  'ANALYTICAL BIOCHEMISTRY',
#  'ANALYTICAL CHEMISTRY',
#  'ANGEW CHEMS INT ED',
#  'ANGEWANDE CHEMIE',
#  'ANGEWANDTE CHEMIE',
#  'ANGEWANDTE CHEMIE INTERNATIONAL EDITION',
#  'ANIMAL BEHAVIOUR',
#  'ANNALS OF HUMAN GENETICS',
#  'ANNALS OF NEUROLOGY',
#  'ANNALS OF SCIENCE',
#  'ANNALS OF THE NEW YORK ACADEMY OF SCIENCES',
#  'ANTIMICOBIAL AGENTS AND CHEMOTHERAPY',
#  'ANTIMICROBIAL AGENTS AND CHEMOTHERAPY',
#  'ANTIMICROBIAL AGFENTS AND CHEMOTHERAPY',
#  'ANTIOXIDANTS & REDOX SIGNALING',
#  'ANTIOXIDANTS AND REDOX SIGNALING',
#  'APPLIED ENERGY',
#  'ARCHIVES OF DISEASE IN CHILDHOOD',
#  'ARTHRITIS & RHEUMATISM',
#  'ARTHRITIS AND RHEUMATISM',
#  'ARTHRITIS RESEARCH & THERAPY',
#  'ARTHRITIS RESEARCH AND THERAPY',
#  'ASIAN JOURNAL OF PSYCHIATRY',
#  'ASN NEURO',
#  'ATHEROSCLEROSIS',
#  'AUTOPHAGY',
#  'AZANIA: ARCHAEOLOGICAL RESEARCH IN AFRICA',
#  'BBA - MOLECULAR BASIS OF DISEASE',
#  'BEHAVIOR RESEARCH AND THERAPY',
#  'BEHAVIORAL NEUROSCIENCE',
#  'BEHAVIOUR RESEARCH AND THERAPY',
#  'BEHAVIOURAL BRAIN RESEARCH',
#  'BIINFORMATICS',
#  'BIOCHEM JOURNAL',
#  'BIOCHEM SOC TRANS',
#  'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS',
#  'BIOCHEMICAL JOURNAL',
#  'BIOCHEMICAL PHARMACOLOGY',
#  'BIOCHEMICAL SOCIETY TRANSACTIONS',
#  'BIOCHEMISTRY',
#  'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS',
#  'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE',
#  'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH',
#  'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE',
#  'BIOCHIMIE',
#  'BIOCONJUGATE CHEMISTRY',
#  'BIOETHICS',
#  'BIOGERONTOLOGY',
#  'BIOINFORMATICS',
#  'BIOINFORMATICS ONLINE',
#  'BIOL OPEN',
#  'BIOLOGICAL PSYCHIATRY',
#  'BIOLOGICAL PSYCHOLOGY',
#  'BIOLOGICIAL CHEMISTRY',
#  'BIOLOGY',
#  'BIOLOGY LETTERS',
#  'BIOLOGY OPEN',
#  'BIOMACROMOLECULES',
#  'BIOMATERIALS',
#  'BIOMED CENTRAL',
#  'BIOMEDICAL MICRODEVICES',
#  'BIOMOLECULAR NMR ASSIGNMENTS',
#  'BIOPHYSICAL JOURNAL',
#  'BIOPOLYMERS',
#  'BIOSCIENCE REPORTS',
#  'BIOSOCIETIES',
#  'BIOSYSTEMS',
#  'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY',
#  'BJOPHTHALMOL',
#  'BJP',
#  'BLOOD',
#  'BLOOD JOURNAL 2012',
#  'BMC BIOLOGY',
#  'BMC GENETICS',
#  'BMC GENOME BIOLOGY',
#  'BMC GENOMICS',
#  'BMC GENOMICS.',
#  'BMC HEALTH SERVICES RESEARCH',
#  'BMC INFECTIOUS DISEASES',
#  'BMC MEDICAL ETHICS',
#  'BMC MEDICAL GENETICS',
#  'BMC MEDICAL IMAGING',
#  'BMC MEDICINE',
#  'BMC MICROBIOLOGY',
#  'BMC MOLECULAR BIOLOGY',
#  'BMC NEUROLOGY',
#  'BMC NEUROSCIENCE',
#  'BMC PEDIATRICS',
#  'BMC PSYCHIATRY',
#  'BMC PUBLIC HEALTH',
#  'BMC RESEARCH NOTES',
#  'BMC VETERINARY RESEARCH',
#  'BMJ',
#  'BMJ OPEN',
#  'BMJ QUALITY AND SAFETY',
#  'BMS GENOMICS',
#  'BONE',
#  'BRAIN',
#  'BRAIN AND COGNITION',
#  'BRAIN AND LANGUAGE',
#  'BRAIN RESEARCH',
#  'BRAIN STRUCTURE AND FUNCTION',
#  'BRAIN TOPOGRAPHY',
#  'BRIEFINGS IN BIOINFORMATICS',
#  'BRIEFINGS IN FUNCTIONAL GENOMICS',
#  'BRITISH JOUNAL OF PHARMACOLOGY',
#  'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE',
#  'BRITISH JOURNAL OF CANCER',
#  'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY',
#  'BRITISH JOURNAL OF DERMATOLOGY',
#  'BRITISH JOURNAL OF HAEMATOLOGY',
#  'BRITISH JOURNAL OF OPHTHALMOLOGY',
#  'BRITISH JOURNAL OF OPTHALMOLOGY',
#  'BRITISH JOURNAL OF PHARMACOLOGY',
#  'BRITISH JOURNAL OF PSYCHIATRY',
#  'BRITISH JOURNAL OF THE HISTORY OF SCIENCE',
#  'BRITISH MEDICAL BULLETIN',
#  'BRITISH MEDICAL JOURNAL',
#  'BRITSH JOURNAL OF PSYCHIATRY',
#  'BRT JNL CLINICAL PHARMACOLOGY',
#  'BULLETIN OF THE HISTORY OF MEDICINE',
#  'CALCIFIED TISSUE INTERNATIONAL',
#  'CANADIAN JOURNAL OF AFRICAN STUDIES',
#  'CANCER LETTERS',
#  'CANCER RESEARCH',
#  'CARDIOVASCULAR RESEARCH',
#  'CELL',
#  'CELL ADHESION AND MIGRATION',
#  'CELL AND TISSUE RESEARCH',
#  'CELL CALCIUM',
#  'CELL CYCLE',
#  'CELL DEATH & DISEASE',
#  'CELL DEATH AND DIFFERENTIATION',
#  'CELL DEATH AND DISEASE',
#  'CELL DEATH DIFFERENTIATION',
#  'CELL HOST & MICROBE',
#  'CELL HOST AND MICROBE',
#  'CELL JOURNAL',
#  'CELL METABOLISM',
#  'CELL PRESS - CELL REPORTS',
#  'CELL REPORTS',
#  'CELL STEM CELL',
#  'CELLULAR AND MOLECULAR CELL SCIENCES',
#  'CELLULAR AND MOLECULAR LIFE SCIENCES',
#  'CELLULAR MICROBIOLOGY',
#  'CELLULAR SIGNALLING',
#  'CENTAURUS',
#  'CEREBRAL CORTEX',
#  'CEREBRAL CORTEX ONLINE',
#  'CEREBRAL CORTEX PRINT',
#  'CHANNELS',
#  'CHEMBIOCHEM',
#  'CHEMICAL COMMUNICATION',
#  'CHEMICAL SOCIETY REVIEWS',
#  'CHEMISTRY - EUROPEAN JOURNAL',
#  'CHEMMEDCHEM',
#  'CHEMSITRY & BIOLOGY',
#  'CHEST',
#  'CHILD NEUROPSYCHOLOGY',
#  'CHILD PSYCHOLOGY PSYCHIATRY',
#  'CHILD: CARE, HEALTH DEVELOPMENT',
#  'CHILD: CARE, HEATH & DEVELOPMENT',
#  'CHILDS NERV SYST',
#  'CHROMOSOME RESEARCH',
#  'CHRONIC ILLNESS',
#  'CIRCULATION RESEARCH',
#  'CLINICAL AND EXPERIMENTAL ALLERGY',
#  'CLINICAL AND VACCINE IMMUNOLOGY',
#  'CLINICAL GENETICS',
#  'CLINICAL INFECTIOUS DISEASES',
#  'CLINICAL INFECTIOUS DISEASES ONLINE',
#  'CLINICAL NEUROLOGY AND NEUROSURGERY',
#  'CLINICAL PROTEOMICS',
#  'CLINICAL RADIOLOGY',
#  'CLINICAL TRANSCRIPTIONAL SCIENCE',
#  'CLINICLA INFECTIOUS DISEASE',
#  'COGNITION',
#  'COGNITIVE DEVELOPMENT',
#  'COGNITIVE PROCESSING',
#  'COGNITIVE THERAPY AND RESEARCH',
#  'COMPUTATIONAL BIOLOGY',
#  'CONSCIOUSNESS & COGNITION',
#  'CONSCIOUSNESS AND COGNITION',
#  'CORTEX',
#  'COST EFFECTIVENESS AND RESOURCE ALLOCATION',
#  'CRIMINAL BEHAVIOR AND MENTAL HEALTH',
#  'CURR BIOL.',
#  'CURRENT ANALYTICAL CHEMISTRY',
#  'CURRENT ATHEROSCLEROSIS REPORTS',
#  'CURRENT BIOLOGY',
#  'CURRENT OBSTETRICS AND GYNECOLOGY REPORTS',
#  'CURRENT OPINION IN NEUROBIOLOGY',
#  'CURRENT OPINION MICROBIOLOGY',
#  'CURRENT OPINIONS IN NEUROBIOLOGY',
#  'CURRENT TOPICS IN MEDICINAL CHEMISTRY',
#  'CYTOSKELETON',
#  'DALTON TRANSACTIONS',
#  'DATABASE',
#  'DEPRESSION AND ANXIETY',
#  'DERMATOLOGIC SURGERY',
#  'DEV WORLD BIOETH.',
#  'DEV. WORLD BIOETH',
#  'DEVELOPING WORLD BIOETHICS',
#  'DEVELOPMENT',
#  'DEVELOPMENT DYNAMICS',
#  'DEVELOPMENT GENES AND EVOLUTION',
#  'DEVELOPMENT SCIENCE',
#  'DEVELOPMENTAL BIOLOGY',
#  'DEVELOPMENTAL CELL',
#  'DEVELOPMENTAL COGNITIVE NEUROSCIENCE',
#  'DEVELOPMENTAL SCIENCE',
#  'DIABETIC MEDICINE',
#  'DIABETOLOGIA',
#  'DIAGNOSTIC MICROBIOLOGY AND INFECTIOUS DISEASE',
#  'DISEASE MODELS AND MECHANISMS',
#  'DRUG AND ALCOHOL REVIEW',
#  'ECOLOGY AND EVOLUTION',
#  'ECOLOGY LETTERS',
#  'ECONOMIC HISTORY REVIEW',
#  'ELSEVIER',
#  'EMBO',
#  'EMBO JOURNAL',
#  'EMBO MOLECULAR MEDICINE',
#  'EMBO REPORTS',
#  'EMOTION',
#  'ENDEAVOUR',
#  'ENDOCRINE RELATED CANCER',
#  'ENDOCRINOLOGY',
#  'ENGLISH STUDIES',
#  'ENVIRONMENT AND PLANNING A',
#  'EPIDEMIOLOGY AND INFECTION',
#  'EPIGENETICS',
#  'EPIGENTICS',
#  'EPILEPSIA',
#  'EPILEPSY RESEARCH',
#  'ESSAYS IN BIOCHEMISTRY',
#  'ETHN HEALTH',
#  'EUKARYOTIC CELL',
#  'EUR J IMMUNOL',
#  'EUROPEAN CHILD AND ADOLESCENT PSYCHIATRY',
#  'EUROPEAN CHILD AND ADOLESCENT PSYCHIATTY',
#  'EUROPEAN HEART JOURNAL ONLINE',
#  'EUROPEAN HISTORY QUARTERLY',
#  'EUROPEAN JOURNAL OF CELL BIOLOGY',
#  'EUROPEAN JOURNAL OF CLINICAL PHARMACOLOGY',
#  'EUROPEAN JOURNAL OF ENDOCRINOLOGY',
#  'EUROPEAN JOURNAL OF ENGLISH STUDIES',
#  'EUROPEAN JOURNAL OF EPIDEMIOLOGY',
#  'EUROPEAN JOURNAL OF HEALTH LAW',
#  'EUROPEAN JOURNAL OF HUMAN GENETICS',
#  'EUROPEAN JOURNAL OF IMMUNOLOGY',
#  'EUROPEAN JOURNAL OF MEDICAL GENETICS',
#  'EUROPEAN JOURNAL OF NEUROSCIENCE',
#  'EUROPEAN JOURNAL OF PREVENTIVE CARDIOLOGY',
#  'EUROPEAN JOURNAL OF PUBLIC HEALTH',
#  'EUROPEAN NEUROPSYCHOPHARMACOLOGY',
#  'EUROPEAN RADIOLOGY',
#  'EUROPEAN RESPIRATORY JOURNAL',
#  'EVALUATION IN CLINICAL PRACTICE',
#  'EVIDENCE, ETHOS AND EXPERIMENT: THE ANTHROPOLOGY AND HISTORY OF MEDICAL RESEARCH IN AFRICA.',
#  'EVODEVO',
#  'EVOLUTION',
#  'EVOLUTIONARY APPLICATIONS',
#  'EXPERIMENTAL BRAIN RESEARCH',
#  'EXPERIMENTAL CELL RESEARCH',
#  'EXPERIMENTAL EYE RESEARCH',
#  'EXPERIMENTAL HEMATOLOGY',
#  'EXPERIMENTAL NEUROLOGY',
#  'EXPERIMENTAL PARASITOLOGY',
#  'EXPERIMENTAL PHYSIOLOGY',
#  'EXPERT REVIEWS IN ANTI-INFECTIVE CHEMOTHERAPY',
#  'EXPERT REVIEWS IN MOLECULAR MEDICINE',
#  'FASEB JOURNAL',
#  'FEBS J.',
#  'FEBS JOURNAL',
#  'FEBS LETTERS',
#  'FEBS OPEN BIO',
#  'FEMS MICROBIOLOGY LETTERS',
#  'FERTILITY AND STERILITY',
#  'FREE RADICAL AND BIOLOGY MEDICINE',
#  'FRONTIERS',
#  'FRONTIERS IN AUDITORY COGNITIVE NEUROSCIENCE',
#  'FRONTIERS IN BEHAVIORAL NEUROSCIENCE',
#  'FRONTIERS IN BRAIN IMAGING METHODS',
#  'FRONTIERS IN CELLULAR NEUROSCIENCE',
#  'FRONTIERS IN COGNITION',
#  'FRONTIERS IN COGNITIVE SCIENCE',
#  'FRONTIERS IN CONSCIOUSNESS RESEARCH',
#  'FRONTIERS IN DECISION NEUROSCIENCE',
#  'FRONTIERS IN DEVELOPMENTAL PSYCHOLOGY',
#  'FRONTIERS IN ELECTROPHYSIOLOGY',
#  'FRONTIERS IN ENDOCRINOLOGY',
#  'FRONTIERS IN GENETICS',
#  'FRONTIERS IN HUMAN NEUROSCIENCE',
#  'FRONTIERS IN IMMUNOLOGICAL MEMORY',
#  'FRONTIERS IN IMMUNOLOGY',
#  'FRONTIERS IN INFLAMMATION',
#  'FRONTIERS IN INTEGRATIVE NEUROSCIENCE',
#  'FRONTIERS IN INVERTEBRATE PHYSIOLOGY',
#  'FRONTIERS IN MOLECULAR NEUROSCIENCE',
#  'FRONTIERS IN NEURAL CIRCUITS',
#  'FRONTIERS IN NEUROROBOTICS',
#  'FRONTIERS IN PERCEPTION SCIENCE',
#  'FRONTIERS IN SCHIZOPHRENIA',
#  'FRONTIERS IN SYSTEMS NEUROSCIENCE',
#  'FRONTIERS IN T CELL BIOLOGY',
#  'FRONTLINE GASTROENTEROLOGY',
#  'FUNGAL BIOLOGY',
#  'FUNGAL ECOLOGY',
#  'FUTURE MEDICINAL CHEMISTRY',
#  'FUTURE MICROBIOLOGY',
#  'FUTURE NEUROLOGY',
#  'FUTURE VIROLOGY',
#  'G3: GENES, GENOMES, GENETICS',
#  'GASTROENTEROLOGY',
#  'GENE',
#  'GENE THERAPY',
#  'GENES & DEVELOPMENT',
#  'GENES BRAIN BEHAVIOUR',
#  'GENESIS: JOURNAL OF GENETICS',
#  'GENETIC EPIDEMIOLOGY',
#  'GENETIC EPIDEMOLOGY',
#  'GENETICS',
#  'GENETICS IN MEDICINE',
#  'GENOME BIOLOGY',
#  'GENOME MEDICINE',
#  'GENOME RESEARCH',
#  'GLIA',
#  'GLYCOBIOLOGY',
#  'GUT',
#  'HAEMATOLOGICA',
#  'HAEMATOLOGICA/THE HAEMATOLOGY JOURNAL',
#  'HBM JNL HUMAN BRAIN MAPPING',
#  'HEALTH',
#  'HEALTH & PLACE',
#  'HEALTH AND PLACE',
#  'HEALTH POLICY PLANNING',
#  'HEALTH PROMOTION INTERNATIONAL',
#  'HEALTH PSYCHOLOGY',
#  'HEALTH: AN INTERDISCIPLINARY JOURNAL FOR THE SOCIAL STUDY OF HEALTH, ILLNESS AND MEDICINE',
#  'HEART',
#  'HEART AND CIRCULATORY PHYSIOLOGY',
#  'HEPATOLOGY',
#  'HEPTOLOGY',
#  'HERNIA',
#  'HIPPOCAMPUS',
#  'HISTORY OF THE HUMAN SCIENCES',
#  'HISTORY WORKSHOP JOURNAL',
#  'HPB',
#  'HUM RESOUR HEALTH',
#  'HUMAN BRAIN MAPPING',
#  'HUMAN MOL GENETICS ONLINE',
#  'HUMAN MOLECULAR GENETICS',
#  'HUMAN MUTATION',
#  'HUMAN MUTATION: VARIATION, INFORMATICS, AND DISEASE',
#  'HUMAN REPRODUCTION',
#  'HUMAN RESOURCES FOR HEALTH',
#  'IJTLD',
#  'IMMNUNOBIOLOGY',
#  'IMMUNITY',
#  'IMMUNOGENETICS',
#  'IMMUNOLOGICAL REVIEWS',
#  'IMMUNOLOGY',
#  'IMMUNOLOGY LETTERS',
#  'IMPLEMENT SCI.',
#  'INFECTION AND IMMUNITY',
#  'INFECTION GENETICS AND EVOLUTION',
#  'INFLAMMATION RESEARCH',
#  'INFLAMMATORY BOWEL DISEASES',
#  'INFLUENZA OTHER RESPI VIRUSES.',
#  'INT J EPIDEMIOL',
#  'INT JOURNAL FOR PARASITOLOGY',
#  'INTERFACE',
#  'INTERNATIONAL HEALTH',
#  'INTERNATIONAL IMMUNOLOGY',
#  'INTERNATIONAL JOURAL OF EPIDEMIOLOGY',
#  'INTERNATIONAL JOURNAL FOR EQUITY IN HEALTH',
#  'INTERNATIONAL JOURNAL FOR PARASITOLOGY',
#  'INTERNATIONAL JOURNAL OF APPLIED EARTH OBSERVATION AND GEOINFORMATION',
#  'INTERNATIONAL JOURNAL OF BEHAVIORAL NUTRITION AND PHYSICAL ACTIVITY',
#  'INTERNATIONAL JOURNAL OF BEHAVIOURAL NUTRITION AND PHYSICAL ACTIVITY',
#  'INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY',
#  'INTERNATIONAL JOURNAL OF CARDIOLOGY',
#  'INTERNATIONAL JOURNAL OF DEVELOPMENTAL BIOLOGY',
#  'INTERNATIONAL JOURNAL OF EPIDEMIOLOGY',
#  'INTERNATIONAL JOURNAL OF EXPERIMENTAL PATHOLOGY',
#  'INTERNATIONAL JOURNAL OF FINANCIAL RESEARCH',
#  'INTERNATIONAL JOURNAL OF GERIATRIC PSYCHIATRY',
#  'INTERNATIONAL JOURNAL OF HEALTH GEOGRAPHICS',
#  'INTERNATIONAL JOURNAL OF LAW IN CONTEXT',
#  'INTERNATIONAL JOURNAL OF MOLECULAR SCIENCES',
#  'INTERNATIONAL JOURNAL OF OBESITY',
#  'INTERNATIONAL JOURNAL OF PARASITOLOGY',
#  'INTERNATIONAL JOURNAL OF RHEUMATOLOGY',
#  'INTERNATIONAL JOURNAL OF STROKE',
#  'INTERNATIONAL JOURNAL OF TUBERCULOSIS AND LUNG DISEASE',
#  'INTERNATIONAL PSYCHOGERIATRICS',
#  'INTERNATIONAL REVIEWS OF IMMUNOLOGY',
#  'INYERNATIONAL JOURNAL OF EPIDEMIOLOGY',
#  'J BIOL CHEM.',
#  'J BIOL CHEMISTRY',
#  'J CARDIOVASC MAGN RESON',
#  'J CELL SCI.',
#  'J CLIN MICROBIOL',
#  'J IMMUNOL',
#  'J INFECT DIS',
#  'J MED CHEM',
#  'J MED CHEM.',
#  'J MED INTERNET RESEARCH',
#  'J MOL BIOL',
#  'J ORG CHEM',
#  'J STEROID BIOCHEM MOL BIOL',
#  'J SYNCHROTRON RADIAT.',
#  'JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES',
#  'JERPH',
#  'JNL OF THE INTERNATIONAL NEUROPSYCHOLOGICAL SOCIETY',
#  'JOUNRAL OF CLINICAL MICROBIOLOGY',
#  'JOURNAL OD CLINICAL ENDOCRINOLOGY',
#  'JOURNAL OF ABNORMAL PSYCHOLOGY',
#  'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES',
#  'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)',
#  'JOURNAL OF AFFECTIVE DISORDERS',
#  'JOURNAL OF AIDS',
#  'JOURNAL OF ALLERGY',
#  'JOURNAL OF ALLERGY & CLINICAL IMMUNOLOGY',
#  'JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY',
#  'JOURNAL OF ALZHEIMER DISEASE',
#  'JOURNAL OF ANTHROPOLOGICAL ARCHAEOLOGY',
#  'JOURNAL OF ANTIMICROBIAL CHEMOTHERAPY',
#  'JOURNAL OF APPLIED CRYSTALLOGRAPHY',
#  'JOURNAL OF APPLIED PHYSIOLOGY',
#  'JOURNAL OF ARCHAEOLOGICAL SCIENCE',
#  'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS',
#  'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS',
#  'JOURNAL OF BACTERIOLOGY',
#  'JOURNAL OF BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY',
#  'JOURNAL OF BEHAVIOUR THERAPY AND EXPERIMENTAL PSYCHIATRY',
#  'JOURNAL OF BIOENERGETICS AND BIOMEMBRANES',
#  'JOURNAL OF BIOETHICAL INQUIRY',
#  'JOURNAL OF BIOL CHEM',
#  'JOURNAL OF BIOLOGICAL CHEMISTRY',
#  'JOURNAL OF BIOLOGICAL PHYSICS',
#  'JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING',
#  'JOURNAL OF BONE AND MINERAL RESEARCH',
#  'JOURNAL OF CELL PHYSIOLOGY',
#  'JOURNAL OF CELL SCIENCE',
#  'JOURNAL OF CELLULAR BIOCHEMISTRY',
#  'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM',
#  'JOURNAL OF CHEMICAL INFORMATION AND MODELING',
#  'JOURNAL OF CHEMINFORMATICS',
#  'JOURNAL OF CHILD PSYCHOLOGY AND PSYCHIATRY',
#  'JOURNAL OF CLINICAL ENDOCRINOLOGY',
#  'JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM',
#  'JOURNAL OF CLINICAL EPIDEMIOLOGY',
#  'JOURNAL OF CLINICAL MICROBIOLOGY',
#  'JOURNAL OF CLINICAL PATHOLOGY',
#  'JOURNAL OF CLINICAL VIROLOGY',
#  'JOURNAL OF COGNITIVE NEUROSCIENCE',
#  'JOURNAL OF COMPARATIVE NEUROLOGY',
#  'JOURNAL OF COMPUTATIONAL NEUROSCIENCE',
#  'JOURNAL OF CONSULTING AND CLINICAL PSYCHOLOGY',
#  'JOURNAL OF CULTURAL ECONOMY',
#  'JOURNAL OF CYCSTIC FIBROSIS',
#  'JOURNAL OF DEPRESSION & ANXIETY',
#  'JOURNAL OF ENDOCRINOLOGY',
#  'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH',
#  'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH',
#  'JOURNAL OF EVALUATION IN CLINICAL PRACTICE',
#  'JOURNAL OF EVOLUTIONARY BIOLOGY',
#  'JOURNAL OF EXPERIMENTAL NANOSCIENCE',
#  'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: ANIMAL BEHAVIOUR PROCESS',
#  'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE',
#  'JOURNAL OF FAMILY PSYCHOLOGY',
#  'JOURNAL OF GENERAL VIROLOGY',
#  'JOURNAL OF GERONTOLOGY SERIES A: MEDICAL SCIENCES',
#  'JOURNAL OF HEPATOLOGY',
#  'JOURNAL OF HISTOCHEMISTRY & CYTOCHEMISTRY',
#  'JOURNAL OF HISTORICAL GEOGRAPHY',
#  'JOURNAL OF HOSPITAL INFECTIONS',
#  'JOURNAL OF IMMUNOLOGY',
#  'JOURNAL OF INFECTION',
#  'JOURNAL OF INFECTIOUS DISEASES',
#  'JOURNAL OF INHERITED METABOLIC',
#  'JOURNAL OF INTERNAL MEDICINE',
#  'JOURNAL OF INVESTIGATIVE DERMATOLOGY',
#  'JOURNAL OF LEUKOCYTE BIOLOGY',
#  'JOURNAL OF MECHANISMS OF AGEING AND DEVELOPMENT',
#  'JOURNAL OF MEDICAL ETHICS',
#  'JOURNAL OF MEDICAL GENETICS',
#  'JOURNAL OF MEDICAL VIROLOGY',
#  'JOURNAL OF MEDICINAL CHEMISTRY',
#  'JOURNAL OF MICROBIOLOGY',
#  'JOURNAL OF MICROSCOPY',
#  'JOURNAL OF MOLECULAR BIOLOGY',
#  'JOURNAL OF MOLECULAR ENDOCRINOLOGY',
#  'JOURNAL OF MOLECULAR MEDICINE',
#  'JOURNAL OF MOLECULAR NEUROSCIENCE',
#  'JOURNAL OF NEURAL TRANSMISSION',
#  'JOURNAL OF NEUROCHEMISTRY',
#  'JOURNAL OF NEUROENDOCRINOLOGY',
#  'JOURNAL OF NEUROINFLAMMATION',
#  'JOURNAL OF NEUROLOGY',
#  'JOURNAL OF NEUROLOGY & TRANSLATIONAL NEUROSCIENCE',
#  'JOURNAL OF NEUROLOGY, NEUROSURGERY & PSYCHIATRY',
#  'JOURNAL OF NEUROLOGY, NEUROSURGERY AND PSYCHIATRY',
#  'JOURNAL OF NEUROPHYSIOLOGY',
#  'JOURNAL OF NEUROSCIENCE',
#  'JOURNAL OF NEUROSCIENCE METHODS',
#  'JOURNAL OF NUTRITION',
#  'JOURNAL OF NUTRITION EDUCATION AND BEHAVIOUR',
#  'JOURNAL OF ORTHOPEDIC RESEARCH',
#  'JOURNAL OF PAEDIATRIC UROLOGY',
#  'JOURNAL OF PARASITOLOGY RESEARCH',
#  'JOURNAL OF PATHOLOGY',
#  'JOURNAL OF PHYSIOLOGY',
#  'JOURNAL OF POVERTY AND SOCIAL JUSTICE',
#  'JOURNAL OF PROTEOME RESEARCH',
#  'JOURNAL OF PROTEOMICS',
#  'JOURNAL OF PSYCHOPHARMACOLOGY',
#  'JOURNAL OF PUBLIC HEALTH',
#  'JOURNAL OF SLEEP RESEARCH',
#  'JOURNAL OF SMALL ANIMAL PRACTICE',
#  'JOURNAL OF STRUCTURAL BIOLOGY',
#  'JOURNAL OF THE AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY',
#  'JOURNAL OF THE AMERICAN CHEMICAL SOCIETY',
#  'JOURNAL OF THE AMERICAN COLLEGE OF CARDIOLOGY',
#  'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY',
#  'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY',
#  'JOURNAL OF THE HISTORY OF THE BEHAVIORAL SCIENCES',
#  'JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE',
#  'JOURNAL OF THE INTERNATIONAL AIDS SOCIETY',
#  'JOURNAL OF THE NATIONAL CANCER INSTITUTE',
#  'JOURNAL OF THE NEUROLOGICAL SCIENCES',
#  'JOURNAL OF THE ROYAL SOCIETY INTERFACE',
#  'JOURNAL OF THE ROYAL SOCIETY OF MEDICINE SHORT REPORTS',
#  'JOURNAL OF THE ROYAL SOCIETY, INTERFACE',
#  'JOURNAL OF THE ROYAL STATISTICAL SOCIETY: SERIES C (APPLIED STATISTICS)',
#  'JOURNAL OF TRANSPORT GEOGRAPHY',
#  'JOURNAL OF VIRAL HEPATITIS',
#  'JOURNAL OF VIROL',
#  'JOURNAL OF VIROLOGICAL METHODS',
#  'JOURNAL OF VIROLOGY',
#  'JOURNAL OF VISION',
#  'JOURNAL OF VISUALIZED EXPERIEMENTS',
#  'JOURNAL OF VISUALIZED EXPERIMENTS',
#  'JOURNAL OF VISULAIZED EXPERMIMENTS',
#  'KIDNEY INTERNATIONAL',
#  'LANCET',
#  'LANCET GLOBAL HEALTH',
#  'LANCET INFECT DIS',
#  'LEARNING AND INDIVIDUAL DIFFERENCES',
#  'LEARNING AND MEMORY',
#  'LEUKEMIA',
#  'LIPIDS IN HEALTH AND DISEASE',
#  'MAGNETIC RESONANCE IN MEDICINE',
#  'MALARIA JOURNAL',
#  'MAMMALIAN GENOME',
#  'MARTEN CHILD NUTR',
#  'MATERNAL AND CHILD NUTRITION',
#  'MATH BIOSCI',
#  'MATRIX BIOLOGY',
#  'MATURITAS',
#  'MBIO',
#  'MCP (MOLECULAR & CELLULAR PROTEOMICS)',
#  'MECHANISMS OF AGEING AND DEVELOPMENT',
#  'MEDICAL ANTHROPOLOGY',
#  'MEDICAL HISTORY',
#  'MEDICAL HUMANITIES',
#  'MEDICAL LAW REVIEW',
#  'METABOLOMICS',
#  'METHODS IN MOLECULAR BIOLOGY',
#  'MICROBES AND INFECTION',
#  'MICROBES INFECT',
#  'MICROBIOLOGY',
#  'MOL BIO',
#  'MOL BIOL AND EVOLUTION',
#  'MOL PHARM',
#  'MOLECLUAR & CELLULAR ENDOCRINOLOGY',
#  'MOLECULAR & BIOCHEMICAL PARASITOLOGY',
#  'MOLECULAR & CELLULAR PROTEOMICS',
#  'MOLECULAR AND CELLULAR BIOCHEMISTRY',
#  'MOLECULAR AND CELLULAR BIOLOGY',
#  'MOLECULAR AND CELLULAR ENDOCRINOLOGY',
#  'MOLECULAR AND CELLULAR PROTEOMICS',
#  'MOLECULAR BIOLOGY',
#  'MOLECULAR BIOLOGY AND EVOLUTION',
#  'MOLECULAR BRAIN',
#  'MOLECULAR CELL',
#  'MOLECULAR ENDOCRINOLOGY',
#  'MOLECULAR GENETICS & GENOMIC MEDICINE',
#  'MOLECULAR GENETICS AND METABOLISM',
#  'MOLECULAR IMMUNOLOGY',
#  'MOLECULAR MEMBRANE BIOLOGY',
#  'MOLECULAR MICROBIOLOGY',
#  'MOLECULAR PAIN',
#  'MOLECULAR PHYLOGENETICS AND EVOLUTION',
#  'MOVEMENT DISORDERS',
#  'MUCOSAL IMMUNOLOGY',
#  'MUSCLE AND NERVE',
#  'N BIOTECHNOL.',
#  'NAN',
#  'NANOTECHNOLOGY',
#  'NATIONAL ACADEMY OF SCIENCES',
#  'NATURE COMMUNICATIONS',
#  'NATURE NEUROSCIENCE',
#  'NATURE SCIENTIFIC REPORTS',
#  'NEPHROLOGY DIALYSIS AND TRANSPLANTATION',
#  'NEPHROLOGY DIALYSIS TRANSPLANTATION',
#  'NEPHRON PHYSIOLOGY',
#  'NEUROBIOLOGY OF AGING',
#  'NEUROBIOLOGY OF DISEASE',
#  'NEUROBIOLOGY OF LEARNING AND MEMORY',
#  'NEUROCHEMISTRY INTERNATIONAL',
#  'NEURODEGENERATIVE DISEASES',
#  'NEUROEPIDEMIOLOGY',
#  'NEUROGENETICS',
#  'NEUROIMAGE',
#  'NEUROIMAGE: CLINICAL',
#  'NEUROINFORMATICS',
#  'NEUROLOGY',
#  'NEUROMOLECULAR MEDICINE',
#  'NEUROMUSCULAR DISORDERS',
#  'NEURON',
#  'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY',
#  'NEUROPHARMACOLOGY',
#  'NEUROPHYSIOLOGIA',
#  'NEUROPSYCHOBIOLOGY',
#  'NEUROPSYCHOLOGIA',
#  'NEUROPSYCHOPHARMACOLOGY',
#  'NEUROSCIENCE',
#  'NEUROSCIENCE AND BEHAVIOURAL REVIEWS',
#  'NEUROSCIENCE LETTERS',
#  'NEUROSCIENTIST',
#  'NICOTINE AND TOBACO RESEARCH',
#  'NITRIC OXIDE',
#  'NMR IN BIOMEDICINE',
#  'NUCLEIC ACIDS RESEARCH',
#  'NUTRITION JOURNAL',
#  'OBESITY REVIEWS',
#  'ONCOGENE',
#  'ONCOTARGET',
#  'OPEN CHOICE',
#  'OPHTHALMOLOGY',
#  'OPTICS EXPRESS',
#  'ORGANIC & BIOMOLECULAR CHEMISTRY',
#  'ORPHANET JOURNAL OF RARE DISEASES',
#  'OSTEOARTHRITIS AND CARTILAGE',
#  'OSTEOPOROSIS INTERNATIONAL',
#  'OXFORD JOURNALS',
#  'OXFORD UNIVERSITY PRESS',
#  'OXIDATIVE MEDICINE & CELLULAR LONGEVITY',
#  'PAIN',
#  'PARASIT VECTORS.',
#  'PARASITE IMMUNOLOGY',
#  'PARASITES AND VECTORS',
#  'PARASITOLOGY',
#  'PARKINSONISM AND RELATED DISORDERS',
#  'PARSITOLOGY',
#  'PEDIATR INFECT DIS J',
#  'PEDIATRICS',
#  'PERSONALITY AND INDIVIDUAL DIFFERENCES',
#  'PFLUGERS ARCHIV',
#  'PFLUGERS ARCHIVE',
#  'PHILOS TRANS R SOC LONDON B BIOL SCI',
#  'PHILOSOPHICAL TRANSACTIONS B',
#  'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES',
#  'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES',
#  'PHYSICS IN BIOLOGY AND MEDICINE',
#  'PLANT BIOTECHNOLOGY JOURNAL',
#  'PLOS',
#  'PLOS BIOLOGY',
#  'PLOS COMPUTATIONAL BIOLOGY',
#  'PLOS GENETICS',
#  'PLOS MEDICINE',
#  'PLOS MEDICINE JOURNAL',
#  'PLOS NEGLECTED TROPICAL DISEASES',
#  'PLOS ONE',
#  'PLOS PATHOGENS',
#  'PMEDICINE-D-12-03130',
#  'PNAS',
#  'PNAS USA',
#  'PNTD',
#  'PONE-D12-17947',
#  'POPULATION, SPACE AND PLACE',
#  'POSTGRADUATE MEDICAL JOURNAL',
#  'PREVENTIVE MEDICINE',
#  'PROC NATL ACAD SCI U S A.',
#  'PROCEEDINGS B',
#  'PROCEEDINGS OF ROYAL SOCIETY',
#  'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES',
#  'PROCEEDINGS OF THE ROYAL SOCIETY',
#  'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES',
#  'PROTEIN ENGINEERING, DESIGN AND SELECTION (',
#  'PROTEIN EXPR PURIF.',
#  'PROTEIN SCIENCE',
#  'PROTEMICS',
#  'PROTIST',
#  'PSYCHOLOGICAL ASSESSMENT',
#  'PSYCHOLOGICAL MEDICINE',
#  'PSYCHOLOGICAL REVIEW',
#  'PSYCHOLOGICAL SCIENCE',
#  'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY',
#  'PSYCHOPHARMACOLOGY',
#  'PUBLIC HEALTH',
#  'PUBLIC HEALTH ETHICS',
#  'PUBLIC HEALTH NUTRITION',
#  'PUBLIC LIBRARY OF SCIENCE',
#  'PUBLIC SERVICE REVIEW',
#  'PULMONARY PHARMACOLOGY & THERAPEUTICS',
#  'PYSCHOLOGICAL MEDICINE',
#  'QJM: AN INTERNATIONAL JOURNAL OF MEDICINE',
#  'QUALITATIVE RESEARCH',
#  'RAPID COMMUNICATIONS IN MASS SPECTROMETRY',
#  'REPRODUCTION(CAMBRIDGE, ENGLAND)',
#  'REPRODUCTIVE MEDICINE AND BIOLOGY',
#  'REPRODUCTIVE SCIENCES',
#  'RESEARCH IN VETERINARY SCIENCE',
#  'RESPIRATION',
#  'RESPIRATORY RESEARCH',
#  'RHEUMATOLOGY',
#  'RNA',
#  'RNA BIOLOGY',
#  'RSTB 2012.0145',
#  'SCHIZOPHRENIA BULLETIN',
#  'SCHIZOPHRENIA RESEARCH',
#  'SCI REP',
#  'SCIENCE AS CULTURE',
#  'SCIENCE-RESEARCH',
#  'SCIENTIFIC REPORTS',
#  'SCIENTIFIC REPORTS-11-00861B',
#  'SEIZURE',
#  'SEMINARS IN IMMUNOPATHOLOGY',
#  'SEMINARS IN ONCOLOGY',
#  'SENSORS',
#  'SEX TRANSM INFECT.',
#  'SEXUALLY TRANSMITTED INFECTIONS',
#  'SGM OPEN OPTION',
#  'SOCIAL COGNITIVE AND AFFECTIVE NEUROSCIENCE',
#  'SOCIAL HISTORY OF MEDICINE',
#  'SOCIAL PSYCHIATRY & PSYCHIATRIC EPIDEMIOLOGY',
#  'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOL',
#  'SOCIAL PSYCHIATRY AND PSYCHIATRIC EPIDEMIOLOGY',
#  'SOCIAL SCIENCE & MEDICINE',
#  'SOCIAL SCIENCE AND MEDICINE',
#  'SOCIAL STUDIES OF SCIENCE',
#  'SOCIOLOGY OF HEALTH & ILLNESS',
#  'SOUTH ASIAN HISTORY AND CULTURE',
#  'SPEECH LANGUAGE AND HEARING RESEARCH',
#  'SPRINGER',
#  'SPRINGER SCIENCE + BUSINESS MEDIA',
#  'STATISTICS IN MEDICINE',
#  'STEM CELL REPORTS',
#  'STEM CELL RESEARCH',
#  'STEM CELLS',
#  'STEM CELLS AND DEVELOPMENT',
#  'STRUCTURE',
#  'STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C',
#  'STUDIES IN HISTORY AND PHILOSOPHY OF SCIENCE PART C: STUDIES IN HISTORY AND PHILOSOPHY OF BIOLOGICAL AND BIOMEDICAL SCIENCES',
#  'SYNAPSE',
#  'TETRAHEDRON LETTERS',
#  'THE AMERICAL JOURNAL OF HUMAN GENETICS',
#  'THE AMERICAN JOURNAL OF HUMAN GENETICS',
#  'THE BRITISH JOURNAL OF PSYCHIATRY',
#  'THE EMBO JOURNAL',
#  'THE EUROPEAN JOURNAL OF NEUROSCIENCE',
#  'THE FASEB JOURNAL',
#  'THE FEBS JOURNAL',
#  'THE HISTORY OF THE FAMILY',
#  'THE INTERNATIONAL JOURNAL OF BIOCHEMISTRY & CELL BIOLOGY',
#  'THE JOURNAL OF ABNORMAL CHILD PSYCHOLOGY AND PSYCHIATRY',
#  'THE JOURNAL OF COGNITIVE NEUROSCIENCE',
#  'THE JOURNAL OF IMMUNOLOGY',
#  'THE JOURNAL OF INFECTIOUS DISEASES',
#  'THE JOURNAL OF INVESTIGATIVE DERMATOLOGY',
#  'THE JOURNAL OF NEUROPHYSIOLOGY',
#  'THE JOURNAL OF PATHOLOGY',
#  'THE JOURNAL OF PHYSIOLOGY',
#  'THE JOURNAL OF STEROID BIOCHEMISTRY & MOLECULAR BIOLOGY',
#  'THE JOURNAL OF VISUALIZED EXPERIMENTS',
#  'THE LANCET',
#  'THE LANCET NEUROLOGY',
#  'THE VET. JOURNAL',
#  'THERANOSTICS',
#  'THORAX',
#  'THORAX AN INTERNATIONAL JOURNAL FOR RESPIRATORY MEDICINE',
#  'TICKS AND TICK-BORNE DISEASES',
#  'TISSUE ENGINEERING: PART A',
#  'TRAFFIC',
#  'TRANSACTIONS OF THE ROYAL SOCIETY OF TROPICAL MEDICINE AND HYGIENE',
#  'TRANSLATIONAL PSYCHIATRY',
#  'TRENDS IN COGNITIVE SCIENCE',
#  'TRENDS IN GENETICS',
#  'TRENDS IN MICROBIOLOGY',
#  'TRENDS IN MOLECULAR MEDICINE',
#  'TRENDS IN NEUROSCIENCE',
#  'TRENDS IN NEUROSCIENCES',
#  'TRENDS IN PARASITOLOGY',
#  'TRIALS',
#  'TROP MED INT HEALTH',
#  'TROPICAL ANIMAL HEALTH & PRODUCTION',
#  'TROPICAL MEDICINE AND INTERNATIONAL HEALTH',
#  'TUBERCULOSIS',
#  'URBAN HISTORY',
#  'UROLITHIASIS',
#  'VACCINE',
#  'VASCULAR PHARMACOLOGY',
#  'VETERINARY MICROBIOLOGY',
#  'VETERINARY PARASITOLOGY',
#  'VETERINARY RECORD',
#  'VETERINARY RESEARCH',
#  'VIROLOGY',
#  'VIROLOGY JOURNAL',
#  'VIRUS RESEARCH',
#  'VISION RESEARCH',
#  'VISUAL NEUROSCIENCE',
#  'ZOONOSES AND PUBLIC HEALTH']

# %%
# More cleaning by starting letter
for journal in list(top_20.index):
    print("Name: ", journal + '\n')
    
    by_letter = [x for x in updated_choices if x.startswith(journal[0])]
    list_by_letter = list(enumerate(by_letter))
    for item in list_by_letter:
        print(item)
    
    answer = None
    while answer not in ['y', 'N']:
        answer = input("Does the name in question match any of the items above? (Enter 'y' or 'N'): ")
    index_best_name = None
    indices_other_names = []
    if answer is 'y':
        while index_best_name not in [x[0] for x in list_by_letter]:
            index_best_name = int(input("Which number corresponds to the best name? (Enter a number): "))
        while indices_other_names == []:
            indices_other_names = input("Enter number(s) separated by commas: ")
            indices_other_names = [int(n) for n in indices_other_names.split(',')]
            for num in indices_other_names:
                if num not in [x[0] for x in list_by_letter]:
                    indices_other_names = []
                else:
                    pass
        key = list_by_letter[index_best_name][1]
        vals = [x[1] for x in list_by_letter if x[0] in indices_other_names]
        print(key, vals)
        print('\n')
        wellcome['Journal title'] = wellcome['Journal title'].apply(lambda x, k=key, v=vals: k if x in v else x)
# Out:
# Name:  PLOS ONE
#
# (0, 'PAIN')
# (1, 'PARASIT VECTORS.')
# (2, 'PARASITE IMMUNOLOGY')
# (3, 'PARASITES AND VECTORS')
# (4, 'PARASITOLOGY')
# (5, 'PARKINSONISM AND RELATED DISORDERS')
# (6, 'PARSITOLOGY')
# (7, 'PEDIATR INFECT DIS J')
# (8, 'PEDIATRICS')
# (9, 'PERSONALITY AND INDIVIDUAL DIFFERENCES')
# (10, 'PFLUGERS ARCHIV')
# (11, 'PFLUGERS ARCHIVE')
# (12, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (13, 'PHILOSOPHICAL TRANSACTIONS B')
# (14, 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')
# (15, 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES')
# (16, 'PHYSICS IN BIOLOGY AND MEDICINE')
# (17, 'PLANT BIOTECHNOLOGY JOURNAL')
# (18, 'PLOS')
# (19, 'PLOS BIOLOGY')
# (20, 'PLOS COMPUTATIONAL BIOLOGY')
# (21, 'PLOS GENETICS')
# (22, 'PLOS MEDICINE')
# (23, 'PLOS MEDICINE JOURNAL')
# (24, 'PLOS NEGLECTED TROPICAL DISEASES')
# (25, 'PLOS ONE')
# (26, 'PLOS PATHOGENS')
# (27, 'PMEDICINE-D-12-03130')
# (28, 'PNAS')
# (29, 'PNAS USA')
# (30, 'PNTD')
# (31, 'PONE-D12-17947')
# (32, 'POPULATION, SPACE AND PLACE')
# (33, 'POSTGRADUATE MEDICAL JOURNAL')
# (34, 'PREVENTIVE MEDICINE')
# (35, 'PROC NATL ACAD SCI U S A.')
# (36, 'PROCEEDINGS B')
# (37, 'PROCEEDINGS OF ROYAL SOCIETY')
# (38, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (39, 'PROCEEDINGS OF THE ROYAL SOCIETY')
# (40, 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')
# (41, 'PROTEIN ENGINEERING, DESIGN AND SELECTION (')
# (42, 'PROTEIN EXPR PURIF.')
# (43, 'PROTEIN SCIENCE')
# (44, 'PROTEMICS')
# (45, 'PROTIST')
# (46, 'PSYCHOLOGICAL ASSESSMENT')
# (47, 'PSYCHOLOGICAL MEDICINE')
# (48, 'PSYCHOLOGICAL REVIEW')
# (49, 'PSYCHOLOGICAL SCIENCE')
# (50, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (51, 'PSYCHOPHARMACOLOGY')
# (52, 'PUBLIC HEALTH')
# (53, 'PUBLIC HEALTH ETHICS')
# (54, 'PUBLIC HEALTH NUTRITION')
# (55, 'PUBLIC LIBRARY OF SCIENCE')
# (56, 'PUBLIC SERVICE REVIEW')
# (57, 'PULMONARY PHARMACOLOGY & THERAPEUTICS')
# (58, 'PYSCHOLOGICAL MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF BIOLOGICAL CHEMISTRY
#
# (0, 'J BIOL CHEM.')
# (1, 'J BIOL CHEMISTRY')
# (2, 'J CARDIOVASC MAGN RESON')
# (3, 'J CELL SCI.')
# (4, 'J CLIN MICROBIOL')
# (5, 'J IMMUNOL')
# (6, 'J INFECT DIS')
# (7, 'J MED CHEM')
# (8, 'J MED CHEM.')
# (9, 'J MED INTERNET RESEARCH')
# (10, 'J MOL BIOL')
# (11, 'J ORG CHEM')
# (12, 'J STEROID BIOCHEM MOL BIOL')
# (13, 'J SYNCHROTRON RADIAT.')
# (14, 'JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (15, 'JERPH')
# (16, 'JNL OF THE INTERNATIONAL NEUROPSYCHOLOGICAL SOCIETY')
# (17, 'JOUNRAL OF CLINICAL MICROBIOLOGY')
# (18, 'JOURNAL OD CLINICAL ENDOCRINOLOGY')
# (19, 'JOURNAL OF ABNORMAL PSYCHOLOGY')
# (20, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (21, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)')
# (22, 'JOURNAL OF AFFECTIVE DISORDERS')
# (23, 'JOURNAL OF AIDS')
# (24, 'JOURNAL OF ALLERGY')
# (25, 'JOURNAL OF ALLERGY & CLINICAL IMMUNOLOGY')
# (26, 'JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY')
# (27, 'JOURNAL OF ALZHEIMER DISEASE')
# (28, 'JOURNAL OF ANTHROPOLOGICAL ARCHAEOLOGY')
# (29, 'JOURNAL OF ANTIMICROBIAL CHEMOTHERAPY')
# (30, 'JOURNAL OF APPLIED CRYSTALLOGRAPHY')
# (31, 'JOURNAL OF APPLIED PHYSIOLOGY')
# (32, 'JOURNAL OF ARCHAEOLOGICAL SCIENCE')
# (33, 'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS')
# (34, 'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS')
# (35, 'JOURNAL OF BACTERIOLOGY')
# (36, 'JOURNAL OF BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (37, 'JOURNAL OF BEHAVIOUR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (38, 'JOURNAL OF BIOENERGETICS AND BIOMEMBRANES')
# (39, 'JOURNAL OF BIOETHICAL INQUIRY')
# (40, 'JOURNAL OF BIOL CHEM')
# (41, 'JOURNAL OF BIOLOGICAL CHEMISTRY')
# (42, 'JOURNAL OF BIOLOGICAL PHYSICS')
# (43, 'JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING')
# (44, 'JOURNAL OF BONE AND MINERAL RESEARCH')
# (45, 'JOURNAL OF CELL PHYSIOLOGY')
# (46, 'JOURNAL OF CELL SCIENCE')
# (47, 'JOURNAL OF CELLULAR BIOCHEMISTRY')
# (48, 'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM')
# (49, 'JOURNAL OF CHEMICAL INFORMATION AND MODELING')
# (50, 'JOURNAL OF CHEMINFORMATICS')
# (51, 'JOURNAL OF CHILD PSYCHOLOGY AND PSYCHIATRY')
# (52, 'JOURNAL OF CLINICAL ENDOCRINOLOGY')
# (53, 'JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM')
# (54, 'JOURNAL OF CLINICAL EPIDEMIOLOGY')
# (55, 'JOURNAL OF CLINICAL MICROBIOLOGY')
# (56, 'JOURNAL OF CLINICAL PATHOLOGY')
# (57, 'JOURNAL OF CLINICAL VIROLOGY')
# (58, 'JOURNAL OF COGNITIVE NEUROSCIENCE')
# (59, 'JOURNAL OF COMPARATIVE NEUROLOGY')
# (60, 'JOURNAL OF COMPUTATIONAL NEUROSCIENCE')
# (61, 'JOURNAL OF CONSULTING AND CLINICAL PSYCHOLOGY')
# (62, 'JOURNAL OF CULTURAL ECONOMY')
# (63, 'JOURNAL OF CYCSTIC FIBROSIS')
# (64, 'JOURNAL OF DEPRESSION & ANXIETY')
# (65, 'JOURNAL OF ENDOCRINOLOGY')
# (66, 'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH')
# (67, 'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH')
# (68, 'JOURNAL OF EVALUATION IN CLINICAL PRACTICE')
# (69, 'JOURNAL OF EVOLUTIONARY BIOLOGY')
# (70, 'JOURNAL OF EXPERIMENTAL NANOSCIENCE')
# (71, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: ANIMAL BEHAVIOUR PROCESS')
# (72, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE')
# (73, 'JOURNAL OF FAMILY PSYCHOLOGY')
# (74, 'JOURNAL OF GENERAL VIROLOGY')
# (75, 'JOURNAL OF GERONTOLOGY SERIES A: MEDICAL SCIENCES')
# (76, 'JOURNAL OF HEPATOLOGY')
# (77, 'JOURNAL OF HISTOCHEMISTRY & CYTOCHEMISTRY')
# (78, 'JOURNAL OF HISTORICAL GEOGRAPHY')
# (79, 'JOURNAL OF HOSPITAL INFECTIONS')
# (80, 'JOURNAL OF IMMUNOLOGY')
# (81, 'JOURNAL OF INFECTION')
# (82, 'JOURNAL OF INFECTIOUS DISEASES')
# (83, 'JOURNAL OF INHERITED METABOLIC')
# (84, 'JOURNAL OF INTERNAL MEDICINE')
# (85, 'JOURNAL OF INVESTIGATIVE DERMATOLOGY')
# (86, 'JOURNAL OF LEUKOCYTE BIOLOGY')
# (87, 'JOURNAL OF MECHANISMS OF AGEING AND DEVELOPMENT')
# (88, 'JOURNAL OF MEDICAL ETHICS')
# (89, 'JOURNAL OF MEDICAL GENETICS')
# (90, 'JOURNAL OF MEDICAL VIROLOGY')
# (91, 'JOURNAL OF MEDICINAL CHEMISTRY')
# (92, 'JOURNAL OF MICROBIOLOGY')
# (93, 'JOURNAL OF MICROSCOPY')
# (94, 'JOURNAL OF MOLECULAR BIOLOGY')
# (95, 'JOURNAL OF MOLECULAR ENDOCRINOLOGY')
# (96, 'JOURNAL OF MOLECULAR MEDICINE')
# (97, 'JOURNAL OF MOLECULAR NEUROSCIENCE')
# (98, 'JOURNAL OF NEURAL TRANSMISSION')
# (99, 'JOURNAL OF NEUROCHEMISTRY')
# (100, 'JOURNAL OF NEUROENDOCRINOLOGY')
# (101, 'JOURNAL OF NEUROINFLAMMATION')
# (102, 'JOURNAL OF NEUROLOGY')
# (103, 'JOURNAL OF NEUROLOGY & TRANSLATIONAL NEUROSCIENCE')
# (104, 'JOURNAL OF NEUROLOGY, NEUROSURGERY & PSYCHIATRY')
# (105, 'JOURNAL OF NEUROLOGY, NEUROSURGERY AND PSYCHIATRY')
# (106, 'JOURNAL OF NEUROPHYSIOLOGY')
# (107, 'JOURNAL OF NEUROSCIENCE')
# (108, 'JOURNAL OF NEUROSCIENCE METHODS')
# (109, 'JOURNAL OF NUTRITION')
# (110, 'JOURNAL OF NUTRITION EDUCATION AND BEHAVIOUR')
# (111, 'JOURNAL OF ORTHOPEDIC RESEARCH')
# (112, 'JOURNAL OF PAEDIATRIC UROLOGY')
# (113, 'JOURNAL OF PARASITOLOGY RESEARCH')
# (114, 'JOURNAL OF PATHOLOGY')
# (115, 'JOURNAL OF PHYSIOLOGY')
# (116, 'JOURNAL OF POVERTY AND SOCIAL JUSTICE')
# (117, 'JOURNAL OF PROTEOME RESEARCH')
# (118, 'JOURNAL OF PROTEOMICS')
# (119, 'JOURNAL OF PSYCHOPHARMACOLOGY')
# (120, 'JOURNAL OF PUBLIC HEALTH')
# (121, 'JOURNAL OF SLEEP RESEARCH')
# (122, 'JOURNAL OF SMALL ANIMAL PRACTICE')
# (123, 'JOURNAL OF STRUCTURAL BIOLOGY')
# (124, 'JOURNAL OF THE AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY')
# (125, 'JOURNAL OF THE AMERICAN CHEMICAL SOCIETY')
# (126, 'JOURNAL OF THE AMERICAN COLLEGE OF CARDIOLOGY')
# (127, 'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY')
# (128, 'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY')
# (129, 'JOURNAL OF THE HISTORY OF THE BEHAVIORAL SCIENCES')
# (130, 'JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE')
# (131, 'JOURNAL OF THE INTERNATIONAL AIDS SOCIETY')
# (132, 'JOURNAL OF THE NATIONAL CANCER INSTITUTE')
# (133, 'JOURNAL OF THE NEUROLOGICAL SCIENCES')
# (134, 'JOURNAL OF THE ROYAL SOCIETY INTERFACE')
# (135, 'JOURNAL OF THE ROYAL SOCIETY OF MEDICINE SHORT REPORTS')
# (136, 'JOURNAL OF THE ROYAL SOCIETY, INTERFACE')
# (137, 'JOURNAL OF THE ROYAL STATISTICAL SOCIETY: SERIES C (APPLIED STATISTICS)')
# (138, 'JOURNAL OF TRANSPORT GEOGRAPHY')
# (139, 'JOURNAL OF VIRAL HEPATITIS')
# (140, 'JOURNAL OF VIROL')
# (141, 'JOURNAL OF VIROLOGICAL METHODS')
# (142, 'JOURNAL OF VIROLOGY')
# (143, 'JOURNAL OF VISION')
# (144, 'JOURNAL OF VISUALIZED EXPERIEMENTS')
# (145, 'JOURNAL OF VISUALIZED EXPERIMENTS')
# (146, 'JOURNAL OF VISULAIZED EXPERMIMENTS')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): y
# Which number corresponds to the best name? (Enter a number): 41
# Enter number(s) separated by commas: 0,1
# JOURNAL OF BIOLOGICAL CHEMISTRY ['J BIOL CHEM.', 'J BIOL CHEMISTRY']
#
#
# Name:  NEUROIMAGE
#
# (0, 'N BIOTECHNOL.')
# (1, 'NAN')
# (2, 'NANOTECHNOLOGY')
# (3, 'NATIONAL ACADEMY OF SCIENCES')
# (4, 'NATURE COMMUNICATIONS')
# (5, 'NATURE NEUROSCIENCE')
# (6, 'NATURE SCIENTIFIC REPORTS')
# (7, 'NEPHROLOGY DIALYSIS AND TRANSPLANTATION')
# (8, 'NEPHROLOGY DIALYSIS TRANSPLANTATION')
# (9, 'NEPHRON PHYSIOLOGY')
# (10, 'NEUROBIOLOGY OF AGING')
# (11, 'NEUROBIOLOGY OF DISEASE')
# (12, 'NEUROBIOLOGY OF LEARNING AND MEMORY')
# (13, 'NEUROCHEMISTRY INTERNATIONAL')
# (14, 'NEURODEGENERATIVE DISEASES')
# (15, 'NEUROEPIDEMIOLOGY')
# (16, 'NEUROGENETICS')
# (17, 'NEUROIMAGE')
# (18, 'NEUROIMAGE: CLINICAL')
# (19, 'NEUROINFORMATICS')
# (20, 'NEUROLOGY')
# (21, 'NEUROMOLECULAR MEDICINE')
# (22, 'NEUROMUSCULAR DISORDERS')
# (23, 'NEURON')
# (24, 'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY')
# (25, 'NEUROPHARMACOLOGY')
# (26, 'NEUROPHYSIOLOGIA')
# (27, 'NEUROPSYCHOBIOLOGY')
# (28, 'NEUROPSYCHOLOGIA')
# (29, 'NEUROPSYCHOPHARMACOLOGY')
# (30, 'NEUROSCIENCE')
# (31, 'NEUROSCIENCE AND BEHAVIOURAL REVIEWS')
# (32, 'NEUROSCIENCE LETTERS')
# (33, 'NEUROSCIENTIST')
# (34, 'NICOTINE AND TOBACO RESEARCH')
# (35, 'NITRIC OXIDE')
# (36, 'NMR IN BIOMEDICINE')
# (37, 'NUCLEIC ACIDS RESEARCH')
# (38, 'NUTRITION JOURNAL')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES
#
# (0, 'PAIN')
# (1, 'PARASIT VECTORS.')
# (2, 'PARASITE IMMUNOLOGY')
# (3, 'PARASITES AND VECTORS')
# (4, 'PARASITOLOGY')
# (5, 'PARKINSONISM AND RELATED DISORDERS')
# (6, 'PARSITOLOGY')
# (7, 'PEDIATR INFECT DIS J')
# (8, 'PEDIATRICS')
# (9, 'PERSONALITY AND INDIVIDUAL DIFFERENCES')
# (10, 'PFLUGERS ARCHIV')
# (11, 'PFLUGERS ARCHIVE')
# (12, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (13, 'PHILOSOPHICAL TRANSACTIONS B')
# (14, 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')
# (15, 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES')
# (16, 'PHYSICS IN BIOLOGY AND MEDICINE')
# (17, 'PLANT BIOTECHNOLOGY JOURNAL')
# (18, 'PLOS')
# (19, 'PLOS BIOLOGY')
# (20, 'PLOS COMPUTATIONAL BIOLOGY')
# (21, 'PLOS GENETICS')
# (22, 'PLOS MEDICINE')
# (23, 'PLOS MEDICINE JOURNAL')
# (24, 'PLOS NEGLECTED TROPICAL DISEASES')
# (25, 'PLOS ONE')
# (26, 'PLOS PATHOGENS')
# (27, 'PMEDICINE-D-12-03130')
# (28, 'PNAS')
# (29, 'PNAS USA')
# (30, 'PNTD')
# (31, 'PONE-D12-17947')
# (32, 'POPULATION, SPACE AND PLACE')
# (33, 'POSTGRADUATE MEDICAL JOURNAL')
# (34, 'PREVENTIVE MEDICINE')
# (35, 'PROC NATL ACAD SCI U S A.')
# (36, 'PROCEEDINGS B')
# (37, 'PROCEEDINGS OF ROYAL SOCIETY')
# (38, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (39, 'PROCEEDINGS OF THE ROYAL SOCIETY')
# (40, 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')
# (41, 'PROTEIN ENGINEERING, DESIGN AND SELECTION (')
# (42, 'PROTEIN EXPR PURIF.')
# (43, 'PROTEIN SCIENCE')
# (44, 'PROTEMICS')
# (45, 'PROTIST')
# (46, 'PSYCHOLOGICAL ASSESSMENT')
# (47, 'PSYCHOLOGICAL MEDICINE')
# (48, 'PSYCHOLOGICAL REVIEW')
# (49, 'PSYCHOLOGICAL SCIENCE')
# (50, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (51, 'PSYCHOPHARMACOLOGY')
# (52, 'PUBLIC HEALTH')
# (53, 'PUBLIC HEALTH ETHICS')
# (54, 'PUBLIC HEALTH NUTRITION')
# (55, 'PUBLIC LIBRARY OF SCIENCE')
# (56, 'PUBLIC SERVICE REVIEW')
# (57, 'PULMONARY PHARMACOLOGY & THERAPEUTICS')
# (58, 'PYSCHOLOGICAL MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): y
# Which number corresponds to the best name? (Enter a number): 38
# Enter number(s) separated by commas: 28,29,35
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES ['PNAS', 'PNAS USA', 'PROC NATL ACAD SCI U S A.']
#
#
# Name:  NUCLEIC ACIDS RESEARCH
#
# (0, 'N BIOTECHNOL.')
# (1, 'NAN')
# (2, 'NANOTECHNOLOGY')
# (3, 'NATIONAL ACADEMY OF SCIENCES')
# (4, 'NATURE COMMUNICATIONS')
# (5, 'NATURE NEUROSCIENCE')
# (6, 'NATURE SCIENTIFIC REPORTS')
# (7, 'NEPHROLOGY DIALYSIS AND TRANSPLANTATION')
# (8, 'NEPHROLOGY DIALYSIS TRANSPLANTATION')
# (9, 'NEPHRON PHYSIOLOGY')
# (10, 'NEUROBIOLOGY OF AGING')
# (11, 'NEUROBIOLOGY OF DISEASE')
# (12, 'NEUROBIOLOGY OF LEARNING AND MEMORY')
# (13, 'NEUROCHEMISTRY INTERNATIONAL')
# (14, 'NEURODEGENERATIVE DISEASES')
# (15, 'NEUROEPIDEMIOLOGY')
# (16, 'NEUROGENETICS')
# (17, 'NEUROIMAGE')
# (18, 'NEUROIMAGE: CLINICAL')
# (19, 'NEUROINFORMATICS')
# (20, 'NEUROLOGY')
# (21, 'NEUROMOLECULAR MEDICINE')
# (22, 'NEUROMUSCULAR DISORDERS')
# (23, 'NEURON')
# (24, 'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY')
# (25, 'NEUROPHARMACOLOGY')
# (26, 'NEUROPHYSIOLOGIA')
# (27, 'NEUROPSYCHOBIOLOGY')
# (28, 'NEUROPSYCHOLOGIA')
# (29, 'NEUROPSYCHOPHARMACOLOGY')
# (30, 'NEUROSCIENCE')
# (31, 'NEUROSCIENCE AND BEHAVIOURAL REVIEWS')
# (32, 'NEUROSCIENCE LETTERS')
# (33, 'NEUROSCIENTIST')
# (34, 'NICOTINE AND TOBACO RESEARCH')
# (35, 'NITRIC OXIDE')
# (36, 'NMR IN BIOMEDICINE')
# (37, 'NUCLEIC ACIDS RESEARCH')
# (38, 'NUTRITION JOURNAL')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PLOS NEGLECTED TROPICAL DISEASES
#
# (0, 'PAIN')
# (1, 'PARASIT VECTORS.')
# (2, 'PARASITE IMMUNOLOGY')
# (3, 'PARASITES AND VECTORS')
# (4, 'PARASITOLOGY')
# (5, 'PARKINSONISM AND RELATED DISORDERS')
# (6, 'PARSITOLOGY')
# (7, 'PEDIATR INFECT DIS J')
# (8, 'PEDIATRICS')
# (9, 'PERSONALITY AND INDIVIDUAL DIFFERENCES')
# (10, 'PFLUGERS ARCHIV')
# (11, 'PFLUGERS ARCHIVE')
# (12, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (13, 'PHILOSOPHICAL TRANSACTIONS B')
# (14, 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')
# (15, 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES')
# (16, 'PHYSICS IN BIOLOGY AND MEDICINE')
# (17, 'PLANT BIOTECHNOLOGY JOURNAL')
# (18, 'PLOS')
# (19, 'PLOS BIOLOGY')
# (20, 'PLOS COMPUTATIONAL BIOLOGY')
# (21, 'PLOS GENETICS')
# (22, 'PLOS MEDICINE')
# (23, 'PLOS MEDICINE JOURNAL')
# (24, 'PLOS NEGLECTED TROPICAL DISEASES')
# (25, 'PLOS ONE')
# (26, 'PLOS PATHOGENS')
# (27, 'PMEDICINE-D-12-03130')
# (28, 'PNAS')
# (29, 'PNAS USA')
# (30, 'PNTD')
# (31, 'PONE-D12-17947')
# (32, 'POPULATION, SPACE AND PLACE')
# (33, 'POSTGRADUATE MEDICAL JOURNAL')
# (34, 'PREVENTIVE MEDICINE')
# (35, 'PROC NATL ACAD SCI U S A.')
# (36, 'PROCEEDINGS B')
# (37, 'PROCEEDINGS OF ROYAL SOCIETY')
# (38, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (39, 'PROCEEDINGS OF THE ROYAL SOCIETY')
# (40, 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')
# (41, 'PROTEIN ENGINEERING, DESIGN AND SELECTION (')
# (42, 'PROTEIN EXPR PURIF.')
# (43, 'PROTEIN SCIENCE')
# (44, 'PROTEMICS')
# (45, 'PROTIST')
# (46, 'PSYCHOLOGICAL ASSESSMENT')
# (47, 'PSYCHOLOGICAL MEDICINE')
# (48, 'PSYCHOLOGICAL REVIEW')
# (49, 'PSYCHOLOGICAL SCIENCE')
# (50, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (51, 'PSYCHOPHARMACOLOGY')
# (52, 'PUBLIC HEALTH')
# (53, 'PUBLIC HEALTH ETHICS')
# (54, 'PUBLIC HEALTH NUTRITION')
# (55, 'PUBLIC LIBRARY OF SCIENCE')
# (56, 'PUBLIC SERVICE REVIEW')
# (57, 'PULMONARY PHARMACOLOGY & THERAPEUTICS')
# (58, 'PYSCHOLOGICAL MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): y
# Which number corresponds to the best name? (Enter a number): 24
# Enter number(s) separated by commas: 30
# PLOS NEGLECTED TROPICAL DISEASES ['PNTD']
#
#
# Name:  PLOS PATHOGENS
#
# (0, 'PAIN')
# (1, 'PARASIT VECTORS.')
# (2, 'PARASITE IMMUNOLOGY')
# (3, 'PARASITES AND VECTORS')
# (4, 'PARASITOLOGY')
# (5, 'PARKINSONISM AND RELATED DISORDERS')
# (6, 'PARSITOLOGY')
# (7, 'PEDIATR INFECT DIS J')
# (8, 'PEDIATRICS')
# (9, 'PERSONALITY AND INDIVIDUAL DIFFERENCES')
# (10, 'PFLUGERS ARCHIV')
# (11, 'PFLUGERS ARCHIVE')
# (12, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (13, 'PHILOSOPHICAL TRANSACTIONS B')
# (14, 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')
# (15, 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES')
# (16, 'PHYSICS IN BIOLOGY AND MEDICINE')
# (17, 'PLANT BIOTECHNOLOGY JOURNAL')
# (18, 'PLOS')
# (19, 'PLOS BIOLOGY')
# (20, 'PLOS COMPUTATIONAL BIOLOGY')
# (21, 'PLOS GENETICS')
# (22, 'PLOS MEDICINE')
# (23, 'PLOS MEDICINE JOURNAL')
# (24, 'PLOS NEGLECTED TROPICAL DISEASES')
# (25, 'PLOS ONE')
# (26, 'PLOS PATHOGENS')
# (27, 'PMEDICINE-D-12-03130')
# (28, 'PNAS')
# (29, 'PNAS USA')
# (30, 'PNTD')
# (31, 'PONE-D12-17947')
# (32, 'POPULATION, SPACE AND PLACE')
# (33, 'POSTGRADUATE MEDICAL JOURNAL')
# (34, 'PREVENTIVE MEDICINE')
# (35, 'PROC NATL ACAD SCI U S A.')
# (36, 'PROCEEDINGS B')
# (37, 'PROCEEDINGS OF ROYAL SOCIETY')
# (38, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (39, 'PROCEEDINGS OF THE ROYAL SOCIETY')
# (40, 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')
# (41, 'PROTEIN ENGINEERING, DESIGN AND SELECTION (')
# (42, 'PROTEIN EXPR PURIF.')
# (43, 'PROTEIN SCIENCE')
# (44, 'PROTEMICS')
# (45, 'PROTIST')
# (46, 'PSYCHOLOGICAL ASSESSMENT')
# (47, 'PSYCHOLOGICAL MEDICINE')
# (48, 'PSYCHOLOGICAL REVIEW')
# (49, 'PSYCHOLOGICAL SCIENCE')
# (50, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (51, 'PSYCHOPHARMACOLOGY')
# (52, 'PUBLIC HEALTH')
# (53, 'PUBLIC HEALTH ETHICS')
# (54, 'PUBLIC HEALTH NUTRITION')
# (55, 'PUBLIC LIBRARY OF SCIENCE')
# (56, 'PUBLIC SERVICE REVIEW')
# (57, 'PULMONARY PHARMACOLOGY & THERAPEUTICS')
# (58, 'PYSCHOLOGICAL MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  PLOS GENETICS
#
# (0, 'PAIN')
# (1, 'PARASIT VECTORS.')
# (2, 'PARASITE IMMUNOLOGY')
# (3, 'PARASITES AND VECTORS')
# (4, 'PARASITOLOGY')
# (5, 'PARKINSONISM AND RELATED DISORDERS')
# (6, 'PARSITOLOGY')
# (7, 'PEDIATR INFECT DIS J')
# (8, 'PEDIATRICS')
# (9, 'PERSONALITY AND INDIVIDUAL DIFFERENCES')
# (10, 'PFLUGERS ARCHIV')
# (11, 'PFLUGERS ARCHIVE')
# (12, 'PHILOS TRANS R SOC LONDON B BIOL SCI')
# (13, 'PHILOSOPHICAL TRANSACTIONS B')
# (14, 'PHILOSOPHICAL TRANSACTIONS OF THE ROYAL SOCIETY OF LONDON. SERIES B, BIOLOGICAL SCIENCES')
# (15, 'PHOTOCHEMICAL & PHOTOBIOLOGICAL SCIENCES')
# (16, 'PHYSICS IN BIOLOGY AND MEDICINE')
# (17, 'PLANT BIOTECHNOLOGY JOURNAL')
# (18, 'PLOS')
# (19, 'PLOS BIOLOGY')
# (20, 'PLOS COMPUTATIONAL BIOLOGY')
# (21, 'PLOS GENETICS')
# (22, 'PLOS MEDICINE')
# (23, 'PLOS MEDICINE JOURNAL')
# (24, 'PLOS NEGLECTED TROPICAL DISEASES')
# (25, 'PLOS ONE')
# (26, 'PLOS PATHOGENS')
# (27, 'PMEDICINE-D-12-03130')
# (28, 'PNAS')
# (29, 'PNAS USA')
# (30, 'PNTD')
# (31, 'PONE-D12-17947')
# (32, 'POPULATION, SPACE AND PLACE')
# (33, 'POSTGRADUATE MEDICAL JOURNAL')
# (34, 'PREVENTIVE MEDICINE')
# (35, 'PROC NATL ACAD SCI U S A.')
# (36, 'PROCEEDINGS B')
# (37, 'PROCEEDINGS OF ROYAL SOCIETY')
# (38, 'PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES')
# (39, 'PROCEEDINGS OF THE ROYAL SOCIETY')
# (40, 'PROCEEDINGS OF THE ROYAL SOCIETY B: BIOLOGICAL SCIENCES')
# (41, 'PROTEIN ENGINEERING, DESIGN AND SELECTION (')
# (42, 'PROTEIN EXPR PURIF.')
# (43, 'PROTEIN SCIENCE')
# (44, 'PROTEMICS')
# (45, 'PROTIST')
# (46, 'PSYCHOLOGICAL ASSESSMENT')
# (47, 'PSYCHOLOGICAL MEDICINE')
# (48, 'PSYCHOLOGICAL REVIEW')
# (49, 'PSYCHOLOGICAL SCIENCE')
# (50, 'PSYCHOLOGICAL TRAUMA: THEORY RESEARCH, PRACTICE AND POLICY')
# (51, 'PSYCHOPHARMACOLOGY')
# (52, 'PUBLIC HEALTH')
# (53, 'PUBLIC HEALTH ETHICS')
# (54, 'PUBLIC HEALTH NUTRITION')
# (55, 'PUBLIC LIBRARY OF SCIENCE')
# (56, 'PUBLIC SERVICE REVIEW')
# (57, 'PULMONARY PHARMACOLOGY & THERAPEUTICS')
# (58, 'PYSCHOLOGICAL MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  HUMAN MOLECULAR GENETICS
#
# (0, 'HAEMATOLOGICA')
# (1, 'HAEMATOLOGICA/THE HAEMATOLOGY JOURNAL')
# (2, 'HBM JNL HUMAN BRAIN MAPPING')
# (3, 'HEALTH')
# (4, 'HEALTH & PLACE')
# (5, 'HEALTH AND PLACE')
# (6, 'HEALTH POLICY PLANNING')
# (7, 'HEALTH PROMOTION INTERNATIONAL')
# (8, 'HEALTH PSYCHOLOGY')
# (9, 'HEALTH: AN INTERDISCIPLINARY JOURNAL FOR THE SOCIAL STUDY OF HEALTH, ILLNESS AND MEDICINE')
# (10, 'HEART')
# (11, 'HEART AND CIRCULATORY PHYSIOLOGY')
# (12, 'HEPATOLOGY')
# (13, 'HEPTOLOGY')
# (14, 'HERNIA')
# (15, 'HIPPOCAMPUS')
# (16, 'HISTORY OF THE HUMAN SCIENCES')
# (17, 'HISTORY WORKSHOP JOURNAL')
# (18, 'HPB')
# (19, 'HUM RESOUR HEALTH')
# (20, 'HUMAN BRAIN MAPPING')
# (21, 'HUMAN MOL GENETICS ONLINE')
# (22, 'HUMAN MOLECULAR GENETICS')
# (23, 'HUMAN MUTATION')
# (24, 'HUMAN MUTATION: VARIATION, INFORMATICS, AND DISEASE')
# (25, 'HUMAN REPRODUCTION')
# (26, 'HUMAN RESOURCES FOR HEALTH')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): y
# Which number corresponds to the best name? (Enter a number): 22
# Enter number(s) separated by commas: 21
# HUMAN MOLECULAR GENETICS ['HUMAN MOL GENETICS ONLINE']
#
#
# Name:  NATURE COMMUNICATIONS
#
# (0, 'N BIOTECHNOL.')
# (1, 'NAN')
# (2, 'NANOTECHNOLOGY')
# (3, 'NATIONAL ACADEMY OF SCIENCES')
# (4, 'NATURE COMMUNICATIONS')
# (5, 'NATURE NEUROSCIENCE')
# (6, 'NATURE SCIENTIFIC REPORTS')
# (7, 'NEPHROLOGY DIALYSIS AND TRANSPLANTATION')
# (8, 'NEPHROLOGY DIALYSIS TRANSPLANTATION')
# (9, 'NEPHRON PHYSIOLOGY')
# (10, 'NEUROBIOLOGY OF AGING')
# (11, 'NEUROBIOLOGY OF DISEASE')
# (12, 'NEUROBIOLOGY OF LEARNING AND MEMORY')
# (13, 'NEUROCHEMISTRY INTERNATIONAL')
# (14, 'NEURODEGENERATIVE DISEASES')
# (15, 'NEUROEPIDEMIOLOGY')
# (16, 'NEUROGENETICS')
# (17, 'NEUROIMAGE')
# (18, 'NEUROIMAGE: CLINICAL')
# (19, 'NEUROINFORMATICS')
# (20, 'NEUROLOGY')
# (21, 'NEUROMOLECULAR MEDICINE')
# (22, 'NEUROMUSCULAR DISORDERS')
# (23, 'NEURON')
# (24, 'NEUROPATHOLOGY AND APPLIED NEUROBIOLOGY')
# (25, 'NEUROPHARMACOLOGY')
# (26, 'NEUROPHYSIOLOGIA')
# (27, 'NEUROPSYCHOBIOLOGY')
# (28, 'NEUROPSYCHOLOGIA')
# (29, 'NEUROPSYCHOPHARMACOLOGY')
# (30, 'NEUROSCIENCE')
# (31, 'NEUROSCIENCE AND BEHAVIOURAL REVIEWS')
# (32, 'NEUROSCIENCE LETTERS')
# (33, 'NEUROSCIENTIST')
# (34, 'NICOTINE AND TOBACO RESEARCH')
# (35, 'NITRIC OXIDE')
# (36, 'NMR IN BIOMEDICINE')
# (37, 'NUCLEIC ACIDS RESEARCH')
# (38, 'NUTRITION JOURNAL')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BRAIN
#
# (0, 'BBA - MOLECULAR BASIS OF DISEASE')
# (1, 'BEHAVIOR RESEARCH AND THERAPY')
# (2, 'BEHAVIORAL NEUROSCIENCE')
# (3, 'BEHAVIOUR RESEARCH AND THERAPY')
# (4, 'BEHAVIOURAL BRAIN RESEARCH')
# (5, 'BIINFORMATICS')
# (6, 'BIOCHEM JOURNAL')
# (7, 'BIOCHEM SOC TRANS')
# (8, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (9, 'BIOCHEMICAL JOURNAL')
# (10, 'BIOCHEMICAL PHARMACOLOGY')
# (11, 'BIOCHEMICAL SOCIETY TRANSACTIONS')
# (12, 'BIOCHEMISTRY')
# (13, 'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS')
# (14, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (15, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (16, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (17, 'BIOCHIMIE')
# (18, 'BIOCONJUGATE CHEMISTRY')
# (19, 'BIOETHICS')
# (20, 'BIOGERONTOLOGY')
# (21, 'BIOINFORMATICS')
# (22, 'BIOINFORMATICS ONLINE')
# (23, 'BIOL OPEN')
# (24, 'BIOLOGICAL PSYCHIATRY')
# (25, 'BIOLOGICAL PSYCHOLOGY')
# (26, 'BIOLOGICIAL CHEMISTRY')
# (27, 'BIOLOGY')
# (28, 'BIOLOGY LETTERS')
# (29, 'BIOLOGY OPEN')
# (30, 'BIOMACROMOLECULES')
# (31, 'BIOMATERIALS')
# (32, 'BIOMED CENTRAL')
# (33, 'BIOMEDICAL MICRODEVICES')
# (34, 'BIOMOLECULAR NMR ASSIGNMENTS')
# (35, 'BIOPHYSICAL JOURNAL')
# (36, 'BIOPOLYMERS')
# (37, 'BIOSCIENCE REPORTS')
# (38, 'BIOSOCIETIES')
# (39, 'BIOSYSTEMS')
# (40, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (41, 'BJOPHTHALMOL')
# (42, 'BJP')
# (43, 'BLOOD')
# (44, 'BLOOD JOURNAL 2012')
# (45, 'BMC BIOLOGY')
# (46, 'BMC GENETICS')
# (47, 'BMC GENOME BIOLOGY')
# (48, 'BMC GENOMICS')
# (49, 'BMC GENOMICS.')
# (50, 'BMC HEALTH SERVICES RESEARCH')
# (51, 'BMC INFECTIOUS DISEASES')
# (52, 'BMC MEDICAL ETHICS')
# (53, 'BMC MEDICAL GENETICS')
# (54, 'BMC MEDICAL IMAGING')
# (55, 'BMC MEDICINE')
# (56, 'BMC MICROBIOLOGY')
# (57, 'BMC MOLECULAR BIOLOGY')
# (58, 'BMC NEUROLOGY')
# (59, 'BMC NEUROSCIENCE')
# (60, 'BMC PEDIATRICS')
# (61, 'BMC PSYCHIATRY')
# (62, 'BMC PUBLIC HEALTH')
# (63, 'BMC RESEARCH NOTES')
# (64, 'BMC VETERINARY RESEARCH')
# (65, 'BMJ')
# (66, 'BMJ OPEN')
# (67, 'BMJ QUALITY AND SAFETY')
# (68, 'BMS GENOMICS')
# (69, 'BONE')
# (70, 'BRAIN')
# (71, 'BRAIN AND COGNITION')
# (72, 'BRAIN AND LANGUAGE')
# (73, 'BRAIN RESEARCH')
# (74, 'BRAIN STRUCTURE AND FUNCTION')
# (75, 'BRAIN TOPOGRAPHY')
# (76, 'BRIEFINGS IN BIOINFORMATICS')
# (77, 'BRIEFINGS IN FUNCTIONAL GENOMICS')
# (78, 'BRITISH JOUNAL OF PHARMACOLOGY')
# (79, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (80, 'BRITISH JOURNAL OF CANCER')
# (81, 'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY')
# (82, 'BRITISH JOURNAL OF DERMATOLOGY')
# (83, 'BRITISH JOURNAL OF HAEMATOLOGY')
# (84, 'BRITISH JOURNAL OF OPHTHALMOLOGY')
# (85, 'BRITISH JOURNAL OF OPTHALMOLOGY')
# (86, 'BRITISH JOURNAL OF PHARMACOLOGY')
# (87, 'BRITISH JOURNAL OF PSYCHIATRY')
# (88, 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')
# (89, 'BRITISH MEDICAL BULLETIN')
# (90, 'BRITISH MEDICAL JOURNAL')
# (91, 'BRITSH JOURNAL OF PSYCHIATRY')
# (92, 'BRT JNL CLINICAL PHARMACOLOGY')
# (93, 'BULLETIN OF THE HISTORY OF MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BMC PUBLIC HEALTH
#
# (0, 'BBA - MOLECULAR BASIS OF DISEASE')
# (1, 'BEHAVIOR RESEARCH AND THERAPY')
# (2, 'BEHAVIORAL NEUROSCIENCE')
# (3, 'BEHAVIOUR RESEARCH AND THERAPY')
# (4, 'BEHAVIOURAL BRAIN RESEARCH')
# (5, 'BIINFORMATICS')
# (6, 'BIOCHEM JOURNAL')
# (7, 'BIOCHEM SOC TRANS')
# (8, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (9, 'BIOCHEMICAL JOURNAL')
# (10, 'BIOCHEMICAL PHARMACOLOGY')
# (11, 'BIOCHEMICAL SOCIETY TRANSACTIONS')
# (12, 'BIOCHEMISTRY')
# (13, 'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS')
# (14, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (15, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (16, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (17, 'BIOCHIMIE')
# (18, 'BIOCONJUGATE CHEMISTRY')
# (19, 'BIOETHICS')
# (20, 'BIOGERONTOLOGY')
# (21, 'BIOINFORMATICS')
# (22, 'BIOINFORMATICS ONLINE')
# (23, 'BIOL OPEN')
# (24, 'BIOLOGICAL PSYCHIATRY')
# (25, 'BIOLOGICAL PSYCHOLOGY')
# (26, 'BIOLOGICIAL CHEMISTRY')
# (27, 'BIOLOGY')
# (28, 'BIOLOGY LETTERS')
# (29, 'BIOLOGY OPEN')
# (30, 'BIOMACROMOLECULES')
# (31, 'BIOMATERIALS')
# (32, 'BIOMED CENTRAL')
# (33, 'BIOMEDICAL MICRODEVICES')
# (34, 'BIOMOLECULAR NMR ASSIGNMENTS')
# (35, 'BIOPHYSICAL JOURNAL')
# (36, 'BIOPOLYMERS')
# (37, 'BIOSCIENCE REPORTS')
# (38, 'BIOSOCIETIES')
# (39, 'BIOSYSTEMS')
# (40, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (41, 'BJOPHTHALMOL')
# (42, 'BJP')
# (43, 'BLOOD')
# (44, 'BLOOD JOURNAL 2012')
# (45, 'BMC BIOLOGY')
# (46, 'BMC GENETICS')
# (47, 'BMC GENOME BIOLOGY')
# (48, 'BMC GENOMICS')
# (49, 'BMC GENOMICS.')
# (50, 'BMC HEALTH SERVICES RESEARCH')
# (51, 'BMC INFECTIOUS DISEASES')
# (52, 'BMC MEDICAL ETHICS')
# (53, 'BMC MEDICAL GENETICS')
# (54, 'BMC MEDICAL IMAGING')
# (55, 'BMC MEDICINE')
# (56, 'BMC MICROBIOLOGY')
# (57, 'BMC MOLECULAR BIOLOGY')
# (58, 'BMC NEUROLOGY')
# (59, 'BMC NEUROSCIENCE')
# (60, 'BMC PEDIATRICS')
# (61, 'BMC PSYCHIATRY')
# (62, 'BMC PUBLIC HEALTH')
# (63, 'BMC RESEARCH NOTES')
# (64, 'BMC VETERINARY RESEARCH')
# (65, 'BMJ')
# (66, 'BMJ OPEN')
# (67, 'BMJ QUALITY AND SAFETY')
# (68, 'BMS GENOMICS')
# (69, 'BONE')
# (70, 'BRAIN')
# (71, 'BRAIN AND COGNITION')
# (72, 'BRAIN AND LANGUAGE')
# (73, 'BRAIN RESEARCH')
# (74, 'BRAIN STRUCTURE AND FUNCTION')
# (75, 'BRAIN TOPOGRAPHY')
# (76, 'BRIEFINGS IN BIOINFORMATICS')
# (77, 'BRIEFINGS IN FUNCTIONAL GENOMICS')
# (78, 'BRITISH JOUNAL OF PHARMACOLOGY')
# (79, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (80, 'BRITISH JOURNAL OF CANCER')
# (81, 'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY')
# (82, 'BRITISH JOURNAL OF DERMATOLOGY')
# (83, 'BRITISH JOURNAL OF HAEMATOLOGY')
# (84, 'BRITISH JOURNAL OF OPHTHALMOLOGY')
# (85, 'BRITISH JOURNAL OF OPTHALMOLOGY')
# (86, 'BRITISH JOURNAL OF PHARMACOLOGY')
# (87, 'BRITISH JOURNAL OF PSYCHIATRY')
# (88, 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')
# (89, 'BRITISH MEDICAL BULLETIN')
# (90, 'BRITISH MEDICAL JOURNAL')
# (91, 'BRITSH JOURNAL OF PSYCHIATRY')
# (92, 'BRT JNL CLINICAL PHARMACOLOGY')
# (93, 'BULLETIN OF THE HISTORY OF MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  MOVEMENT DISORDERS
#
# (0, 'MAGNETIC RESONANCE IN MEDICINE')
# (1, 'MALARIA JOURNAL')
# (2, 'MAMMALIAN GENOME')
# (3, 'MARTEN CHILD NUTR')
# (4, 'MATERNAL AND CHILD NUTRITION')
# (5, 'MATH BIOSCI')
# (6, 'MATRIX BIOLOGY')
# (7, 'MATURITAS')
# (8, 'MBIO')
# (9, 'MCP (MOLECULAR & CELLULAR PROTEOMICS)')
# (10, 'MECHANISMS OF AGEING AND DEVELOPMENT')
# (11, 'MEDICAL ANTHROPOLOGY')
# (12, 'MEDICAL HISTORY')
# (13, 'MEDICAL HUMANITIES')
# (14, 'MEDICAL LAW REVIEW')
# (15, 'METABOLOMICS')
# (16, 'METHODS IN MOLECULAR BIOLOGY')
# (17, 'MICROBES AND INFECTION')
# (18, 'MICROBES INFECT')
# (19, 'MICROBIOLOGY')
# (20, 'MOL BIO')
# (21, 'MOL BIOL AND EVOLUTION')
# (22, 'MOL PHARM')
# (23, 'MOLECLUAR & CELLULAR ENDOCRINOLOGY')
# (24, 'MOLECULAR & BIOCHEMICAL PARASITOLOGY')
# (25, 'MOLECULAR & CELLULAR PROTEOMICS')
# (26, 'MOLECULAR AND CELLULAR BIOCHEMISTRY')
# (27, 'MOLECULAR AND CELLULAR BIOLOGY')
# (28, 'MOLECULAR AND CELLULAR ENDOCRINOLOGY')
# (29, 'MOLECULAR AND CELLULAR PROTEOMICS')
# (30, 'MOLECULAR BIOLOGY')
# (31, 'MOLECULAR BIOLOGY AND EVOLUTION')
# (32, 'MOLECULAR BRAIN')
# (33, 'MOLECULAR CELL')
# (34, 'MOLECULAR ENDOCRINOLOGY')
# (35, 'MOLECULAR GENETICS & GENOMIC MEDICINE')
# (36, 'MOLECULAR GENETICS AND METABOLISM')
# (37, 'MOLECULAR IMMUNOLOGY')
# (38, 'MOLECULAR MEMBRANE BIOLOGY')
# (39, 'MOLECULAR MICROBIOLOGY')
# (40, 'MOLECULAR PAIN')
# (41, 'MOLECULAR PHYLOGENETICS AND EVOLUTION')
# (42, 'MOVEMENT DISORDERS')
# (43, 'MUCOSAL IMMUNOLOGY')
# (44, 'MUSCLE AND NERVE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF NEUROSCIENCE
#
# (0, 'J BIOL CHEM.')
# (1, 'J BIOL CHEMISTRY')
# (2, 'J CARDIOVASC MAGN RESON')
# (3, 'J CELL SCI.')
# (4, 'J CLIN MICROBIOL')
# (5, 'J IMMUNOL')
# (6, 'J INFECT DIS')
# (7, 'J MED CHEM')
# (8, 'J MED CHEM.')
# (9, 'J MED INTERNET RESEARCH')
# (10, 'J MOL BIOL')
# (11, 'J ORG CHEM')
# (12, 'J STEROID BIOCHEM MOL BIOL')
# (13, 'J SYNCHROTRON RADIAT.')
# (14, 'JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (15, 'JERPH')
# (16, 'JNL OF THE INTERNATIONAL NEUROPSYCHOLOGICAL SOCIETY')
# (17, 'JOUNRAL OF CLINICAL MICROBIOLOGY')
# (18, 'JOURNAL OD CLINICAL ENDOCRINOLOGY')
# (19, 'JOURNAL OF ABNORMAL PSYCHOLOGY')
# (20, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (21, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)')
# (22, 'JOURNAL OF AFFECTIVE DISORDERS')
# (23, 'JOURNAL OF AIDS')
# (24, 'JOURNAL OF ALLERGY')
# (25, 'JOURNAL OF ALLERGY & CLINICAL IMMUNOLOGY')
# (26, 'JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY')
# (27, 'JOURNAL OF ALZHEIMER DISEASE')
# (28, 'JOURNAL OF ANTHROPOLOGICAL ARCHAEOLOGY')
# (29, 'JOURNAL OF ANTIMICROBIAL CHEMOTHERAPY')
# (30, 'JOURNAL OF APPLIED CRYSTALLOGRAPHY')
# (31, 'JOURNAL OF APPLIED PHYSIOLOGY')
# (32, 'JOURNAL OF ARCHAEOLOGICAL SCIENCE')
# (33, 'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS')
# (34, 'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS')
# (35, 'JOURNAL OF BACTERIOLOGY')
# (36, 'JOURNAL OF BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (37, 'JOURNAL OF BEHAVIOUR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (38, 'JOURNAL OF BIOENERGETICS AND BIOMEMBRANES')
# (39, 'JOURNAL OF BIOETHICAL INQUIRY')
# (40, 'JOURNAL OF BIOL CHEM')
# (41, 'JOURNAL OF BIOLOGICAL CHEMISTRY')
# (42, 'JOURNAL OF BIOLOGICAL PHYSICS')
# (43, 'JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING')
# (44, 'JOURNAL OF BONE AND MINERAL RESEARCH')
# (45, 'JOURNAL OF CELL PHYSIOLOGY')
# (46, 'JOURNAL OF CELL SCIENCE')
# (47, 'JOURNAL OF CELLULAR BIOCHEMISTRY')
# (48, 'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM')
# (49, 'JOURNAL OF CHEMICAL INFORMATION AND MODELING')
# (50, 'JOURNAL OF CHEMINFORMATICS')
# (51, 'JOURNAL OF CHILD PSYCHOLOGY AND PSYCHIATRY')
# (52, 'JOURNAL OF CLINICAL ENDOCRINOLOGY')
# (53, 'JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM')
# (54, 'JOURNAL OF CLINICAL EPIDEMIOLOGY')
# (55, 'JOURNAL OF CLINICAL MICROBIOLOGY')
# (56, 'JOURNAL OF CLINICAL PATHOLOGY')
# (57, 'JOURNAL OF CLINICAL VIROLOGY')
# (58, 'JOURNAL OF COGNITIVE NEUROSCIENCE')
# (59, 'JOURNAL OF COMPARATIVE NEUROLOGY')
# (60, 'JOURNAL OF COMPUTATIONAL NEUROSCIENCE')
# (61, 'JOURNAL OF CONSULTING AND CLINICAL PSYCHOLOGY')
# (62, 'JOURNAL OF CULTURAL ECONOMY')
# (63, 'JOURNAL OF CYCSTIC FIBROSIS')
# (64, 'JOURNAL OF DEPRESSION & ANXIETY')
# (65, 'JOURNAL OF ENDOCRINOLOGY')
# (66, 'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH')
# (67, 'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH')
# (68, 'JOURNAL OF EVALUATION IN CLINICAL PRACTICE')
# (69, 'JOURNAL OF EVOLUTIONARY BIOLOGY')
# (70, 'JOURNAL OF EXPERIMENTAL NANOSCIENCE')
# (71, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: ANIMAL BEHAVIOUR PROCESS')
# (72, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE')
# (73, 'JOURNAL OF FAMILY PSYCHOLOGY')
# (74, 'JOURNAL OF GENERAL VIROLOGY')
# (75, 'JOURNAL OF GERONTOLOGY SERIES A: MEDICAL SCIENCES')
# (76, 'JOURNAL OF HEPATOLOGY')
# (77, 'JOURNAL OF HISTOCHEMISTRY & CYTOCHEMISTRY')
# (78, 'JOURNAL OF HISTORICAL GEOGRAPHY')
# (79, 'JOURNAL OF HOSPITAL INFECTIONS')
# (80, 'JOURNAL OF IMMUNOLOGY')
# (81, 'JOURNAL OF INFECTION')
# (82, 'JOURNAL OF INFECTIOUS DISEASES')
# (83, 'JOURNAL OF INHERITED METABOLIC')
# (84, 'JOURNAL OF INTERNAL MEDICINE')
# (85, 'JOURNAL OF INVESTIGATIVE DERMATOLOGY')
# (86, 'JOURNAL OF LEUKOCYTE BIOLOGY')
# (87, 'JOURNAL OF MECHANISMS OF AGEING AND DEVELOPMENT')
# (88, 'JOURNAL OF MEDICAL ETHICS')
# (89, 'JOURNAL OF MEDICAL GENETICS')
# (90, 'JOURNAL OF MEDICAL VIROLOGY')
# (91, 'JOURNAL OF MEDICINAL CHEMISTRY')
# (92, 'JOURNAL OF MICROBIOLOGY')
# (93, 'JOURNAL OF MICROSCOPY')
# (94, 'JOURNAL OF MOLECULAR BIOLOGY')
# (95, 'JOURNAL OF MOLECULAR ENDOCRINOLOGY')
# (96, 'JOURNAL OF MOLECULAR MEDICINE')
# (97, 'JOURNAL OF MOLECULAR NEUROSCIENCE')
# (98, 'JOURNAL OF NEURAL TRANSMISSION')
# (99, 'JOURNAL OF NEUROCHEMISTRY')
# (100, 'JOURNAL OF NEUROENDOCRINOLOGY')
# (101, 'JOURNAL OF NEUROINFLAMMATION')
# (102, 'JOURNAL OF NEUROLOGY')
# (103, 'JOURNAL OF NEUROLOGY & TRANSLATIONAL NEUROSCIENCE')
# (104, 'JOURNAL OF NEUROLOGY, NEUROSURGERY & PSYCHIATRY')
# (105, 'JOURNAL OF NEUROLOGY, NEUROSURGERY AND PSYCHIATRY')
# (106, 'JOURNAL OF NEUROPHYSIOLOGY')
# (107, 'JOURNAL OF NEUROSCIENCE')
# (108, 'JOURNAL OF NEUROSCIENCE METHODS')
# (109, 'JOURNAL OF NUTRITION')
# (110, 'JOURNAL OF NUTRITION EDUCATION AND BEHAVIOUR')
# (111, 'JOURNAL OF ORTHOPEDIC RESEARCH')
# (112, 'JOURNAL OF PAEDIATRIC UROLOGY')
# (113, 'JOURNAL OF PARASITOLOGY RESEARCH')
# (114, 'JOURNAL OF PATHOLOGY')
# (115, 'JOURNAL OF PHYSIOLOGY')
# (116, 'JOURNAL OF POVERTY AND SOCIAL JUSTICE')
# (117, 'JOURNAL OF PROTEOME RESEARCH')
# (118, 'JOURNAL OF PROTEOMICS')
# (119, 'JOURNAL OF PSYCHOPHARMACOLOGY')
# (120, 'JOURNAL OF PUBLIC HEALTH')
# (121, 'JOURNAL OF SLEEP RESEARCH')
# (122, 'JOURNAL OF SMALL ANIMAL PRACTICE')
# (123, 'JOURNAL OF STRUCTURAL BIOLOGY')
# (124, 'JOURNAL OF THE AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY')
# (125, 'JOURNAL OF THE AMERICAN CHEMICAL SOCIETY')
# (126, 'JOURNAL OF THE AMERICAN COLLEGE OF CARDIOLOGY')
# (127, 'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY')
# (128, 'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY')
# (129, 'JOURNAL OF THE HISTORY OF THE BEHAVIORAL SCIENCES')
# (130, 'JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE')
# (131, 'JOURNAL OF THE INTERNATIONAL AIDS SOCIETY')
# (132, 'JOURNAL OF THE NATIONAL CANCER INSTITUTE')
# (133, 'JOURNAL OF THE NEUROLOGICAL SCIENCES')
# (134, 'JOURNAL OF THE ROYAL SOCIETY INTERFACE')
# (135, 'JOURNAL OF THE ROYAL SOCIETY OF MEDICINE SHORT REPORTS')
# (136, 'JOURNAL OF THE ROYAL SOCIETY, INTERFACE')
# (137, 'JOURNAL OF THE ROYAL STATISTICAL SOCIETY: SERIES C (APPLIED STATISTICS)')
# (138, 'JOURNAL OF TRANSPORT GEOGRAPHY')
# (139, 'JOURNAL OF VIRAL HEPATITIS')
# (140, 'JOURNAL OF VIROL')
# (141, 'JOURNAL OF VIROLOGICAL METHODS')
# (142, 'JOURNAL OF VIROLOGY')
# (143, 'JOURNAL OF VISION')
# (144, 'JOURNAL OF VISUALIZED EXPERIEMENTS')
# (145, 'JOURNAL OF VISUALIZED EXPERIMENTS')
# (146, 'JOURNAL OF VISULAIZED EXPERMIMENTS')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BIOCHEMICAL JOURNAL
#
# (0, 'BBA - MOLECULAR BASIS OF DISEASE')
# (1, 'BEHAVIOR RESEARCH AND THERAPY')
# (2, 'BEHAVIORAL NEUROSCIENCE')
# (3, 'BEHAVIOUR RESEARCH AND THERAPY')
# (4, 'BEHAVIOURAL BRAIN RESEARCH')
# (5, 'BIINFORMATICS')
# (6, 'BIOCHEM JOURNAL')
# (7, 'BIOCHEM SOC TRANS')
# (8, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (9, 'BIOCHEMICAL JOURNAL')
# (10, 'BIOCHEMICAL PHARMACOLOGY')
# (11, 'BIOCHEMICAL SOCIETY TRANSACTIONS')
# (12, 'BIOCHEMISTRY')
# (13, 'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS')
# (14, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (15, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (16, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (17, 'BIOCHIMIE')
# (18, 'BIOCONJUGATE CHEMISTRY')
# (19, 'BIOETHICS')
# (20, 'BIOGERONTOLOGY')
# (21, 'BIOINFORMATICS')
# (22, 'BIOINFORMATICS ONLINE')
# (23, 'BIOL OPEN')
# (24, 'BIOLOGICAL PSYCHIATRY')
# (25, 'BIOLOGICAL PSYCHOLOGY')
# (26, 'BIOLOGICIAL CHEMISTRY')
# (27, 'BIOLOGY')
# (28, 'BIOLOGY LETTERS')
# (29, 'BIOLOGY OPEN')
# (30, 'BIOMACROMOLECULES')
# (31, 'BIOMATERIALS')
# (32, 'BIOMED CENTRAL')
# (33, 'BIOMEDICAL MICRODEVICES')
# (34, 'BIOMOLECULAR NMR ASSIGNMENTS')
# (35, 'BIOPHYSICAL JOURNAL')
# (36, 'BIOPOLYMERS')
# (37, 'BIOSCIENCE REPORTS')
# (38, 'BIOSOCIETIES')
# (39, 'BIOSYSTEMS')
# (40, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (41, 'BJOPHTHALMOL')
# (42, 'BJP')
# (43, 'BLOOD')
# (44, 'BLOOD JOURNAL 2012')
# (45, 'BMC BIOLOGY')
# (46, 'BMC GENETICS')
# (47, 'BMC GENOME BIOLOGY')
# (48, 'BMC GENOMICS')
# (49, 'BMC GENOMICS.')
# (50, 'BMC HEALTH SERVICES RESEARCH')
# (51, 'BMC INFECTIOUS DISEASES')
# (52, 'BMC MEDICAL ETHICS')
# (53, 'BMC MEDICAL GENETICS')
# (54, 'BMC MEDICAL IMAGING')
# (55, 'BMC MEDICINE')
# (56, 'BMC MICROBIOLOGY')
# (57, 'BMC MOLECULAR BIOLOGY')
# (58, 'BMC NEUROLOGY')
# (59, 'BMC NEUROSCIENCE')
# (60, 'BMC PEDIATRICS')
# (61, 'BMC PSYCHIATRY')
# (62, 'BMC PUBLIC HEALTH')
# (63, 'BMC RESEARCH NOTES')
# (64, 'BMC VETERINARY RESEARCH')
# (65, 'BMJ')
# (66, 'BMJ OPEN')
# (67, 'BMJ QUALITY AND SAFETY')
# (68, 'BMS GENOMICS')
# (69, 'BONE')
# (70, 'BRAIN')
# (71, 'BRAIN AND COGNITION')
# (72, 'BRAIN AND LANGUAGE')
# (73, 'BRAIN RESEARCH')
# (74, 'BRAIN STRUCTURE AND FUNCTION')
# (75, 'BRAIN TOPOGRAPHY')
# (76, 'BRIEFINGS IN BIOINFORMATICS')
# (77, 'BRIEFINGS IN FUNCTIONAL GENOMICS')
# (78, 'BRITISH JOUNAL OF PHARMACOLOGY')
# (79, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (80, 'BRITISH JOURNAL OF CANCER')
# (81, 'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY')
# (82, 'BRITISH JOURNAL OF DERMATOLOGY')
# (83, 'BRITISH JOURNAL OF HAEMATOLOGY')
# (84, 'BRITISH JOURNAL OF OPHTHALMOLOGY')
# (85, 'BRITISH JOURNAL OF OPTHALMOLOGY')
# (86, 'BRITISH JOURNAL OF PHARMACOLOGY')
# (87, 'BRITISH JOURNAL OF PSYCHIATRY')
# (88, 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')
# (89, 'BRITISH MEDICAL BULLETIN')
# (90, 'BRITISH MEDICAL JOURNAL')
# (91, 'BRITSH JOURNAL OF PSYCHIATRY')
# (92, 'BRT JNL CLINICAL PHARMACOLOGY')
# (93, 'BULLETIN OF THE HISTORY OF MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  DEVELOPMENTAL CELL
#
# (0, 'DALTON TRANSACTIONS')
# (1, 'DATABASE')
# (2, 'DEPRESSION AND ANXIETY')
# (3, 'DERMATOLOGIC SURGERY')
# (4, 'DEV WORLD BIOETH.')
# (5, 'DEV. WORLD BIOETH')
# (6, 'DEVELOPING WORLD BIOETHICS')
# (7, 'DEVELOPMENT')
# (8, 'DEVELOPMENT DYNAMICS')
# (9, 'DEVELOPMENT GENES AND EVOLUTION')
# (10, 'DEVELOPMENT SCIENCE')
# (11, 'DEVELOPMENTAL BIOLOGY')
# (12, 'DEVELOPMENTAL CELL')
# (13, 'DEVELOPMENTAL COGNITIVE NEUROSCIENCE')
# (14, 'DEVELOPMENTAL SCIENCE')
# (15, 'DIABETIC MEDICINE')
# (16, 'DIABETOLOGIA')
# (17, 'DIAGNOSTIC MICROBIOLOGY AND INFECTIOUS DISEASE')
# (18, 'DISEASE MODELS AND MECHANISMS')
# (19, 'DRUG AND ALCOHOL REVIEW')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  JOURNAL OF GENERAL VIROLOGY
#
# (0, 'J BIOL CHEM.')
# (1, 'J BIOL CHEMISTRY')
# (2, 'J CARDIOVASC MAGN RESON')
# (3, 'J CELL SCI.')
# (4, 'J CLIN MICROBIOL')
# (5, 'J IMMUNOL')
# (6, 'J INFECT DIS')
# (7, 'J MED CHEM')
# (8, 'J MED CHEM.')
# (9, 'J MED INTERNET RESEARCH')
# (10, 'J MOL BIOL')
# (11, 'J ORG CHEM')
# (12, 'J STEROID BIOCHEM MOL BIOL')
# (13, 'J SYNCHROTRON RADIAT.')
# (14, 'JAIDS JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (15, 'JERPH')
# (16, 'JNL OF THE INTERNATIONAL NEUROPSYCHOLOGICAL SOCIETY')
# (17, 'JOUNRAL OF CLINICAL MICROBIOLOGY')
# (18, 'JOURNAL OD CLINICAL ENDOCRINOLOGY')
# (19, 'JOURNAL OF ABNORMAL PSYCHOLOGY')
# (20, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMES')
# (21, 'JOURNAL OF ACQUIRED IMMUNE DEFICIENCY SYNDROMS (JAIDS)')
# (22, 'JOURNAL OF AFFECTIVE DISORDERS')
# (23, 'JOURNAL OF AIDS')
# (24, 'JOURNAL OF ALLERGY')
# (25, 'JOURNAL OF ALLERGY & CLINICAL IMMUNOLOGY')
# (26, 'JOURNAL OF ALLERGY AND CLINICAL IMMUNOLOGY')
# (27, 'JOURNAL OF ALZHEIMER DISEASE')
# (28, 'JOURNAL OF ANTHROPOLOGICAL ARCHAEOLOGY')
# (29, 'JOURNAL OF ANTIMICROBIAL CHEMOTHERAPY')
# (30, 'JOURNAL OF APPLIED CRYSTALLOGRAPHY')
# (31, 'JOURNAL OF APPLIED PHYSIOLOGY')
# (32, 'JOURNAL OF ARCHAEOLOGICAL SCIENCE')
# (33, 'JOURNAL OF AUTISM AND DEVELOPMENT DISORDERS')
# (34, 'JOURNAL OF AUTISM AND DEVELOPMENTAL DISORDERS')
# (35, 'JOURNAL OF BACTERIOLOGY')
# (36, 'JOURNAL OF BEHAVIOR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (37, 'JOURNAL OF BEHAVIOUR THERAPY AND EXPERIMENTAL PSYCHIATRY')
# (38, 'JOURNAL OF BIOENERGETICS AND BIOMEMBRANES')
# (39, 'JOURNAL OF BIOETHICAL INQUIRY')
# (40, 'JOURNAL OF BIOL CHEM')
# (41, 'JOURNAL OF BIOLOGICAL CHEMISTRY')
# (42, 'JOURNAL OF BIOLOGICAL PHYSICS')
# (43, 'JOURNAL OF BIOMEDICAL GRAPHICS AND COMPUTING')
# (44, 'JOURNAL OF BONE AND MINERAL RESEARCH')
# (45, 'JOURNAL OF CELL PHYSIOLOGY')
# (46, 'JOURNAL OF CELL SCIENCE')
# (47, 'JOURNAL OF CELLULAR BIOCHEMISTRY')
# (48, 'JOURNAL OF CEREBRAL BLOOD FLOW AND METABOLISM')
# (49, 'JOURNAL OF CHEMICAL INFORMATION AND MODELING')
# (50, 'JOURNAL OF CHEMINFORMATICS')
# (51, 'JOURNAL OF CHILD PSYCHOLOGY AND PSYCHIATRY')
# (52, 'JOURNAL OF CLINICAL ENDOCRINOLOGY')
# (53, 'JOURNAL OF CLINICAL ENDOCRINOLOGY AND METABOLISM')
# (54, 'JOURNAL OF CLINICAL EPIDEMIOLOGY')
# (55, 'JOURNAL OF CLINICAL MICROBIOLOGY')
# (56, 'JOURNAL OF CLINICAL PATHOLOGY')
# (57, 'JOURNAL OF CLINICAL VIROLOGY')
# (58, 'JOURNAL OF COGNITIVE NEUROSCIENCE')
# (59, 'JOURNAL OF COMPARATIVE NEUROLOGY')
# (60, 'JOURNAL OF COMPUTATIONAL NEUROSCIENCE')
# (61, 'JOURNAL OF CONSULTING AND CLINICAL PSYCHOLOGY')
# (62, 'JOURNAL OF CULTURAL ECONOMY')
# (63, 'JOURNAL OF CYCSTIC FIBROSIS')
# (64, 'JOURNAL OF DEPRESSION & ANXIETY')
# (65, 'JOURNAL OF ENDOCRINOLOGY')
# (66, 'JOURNAL OF EPIDEMIOLOGY & COMMUNITY HEALTH')
# (67, 'JOURNAL OF EPIDEMIOLOGY AND COMMUNITY HEALTH')
# (68, 'JOURNAL OF EVALUATION IN CLINICAL PRACTICE')
# (69, 'JOURNAL OF EVOLUTIONARY BIOLOGY')
# (70, 'JOURNAL OF EXPERIMENTAL NANOSCIENCE')
# (71, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: ANIMAL BEHAVIOUR PROCESS')
# (72, 'JOURNAL OF EXPERIMENTAL PSYCHOLOGY: HUMAN PERCEPTION AND PERFORMANCE')
# (73, 'JOURNAL OF FAMILY PSYCHOLOGY')
# (74, 'JOURNAL OF GENERAL VIROLOGY')
# (75, 'JOURNAL OF GERONTOLOGY SERIES A: MEDICAL SCIENCES')
# (76, 'JOURNAL OF HEPATOLOGY')
# (77, 'JOURNAL OF HISTOCHEMISTRY & CYTOCHEMISTRY')
# (78, 'JOURNAL OF HISTORICAL GEOGRAPHY')
# (79, 'JOURNAL OF HOSPITAL INFECTIONS')
# (80, 'JOURNAL OF IMMUNOLOGY')
# (81, 'JOURNAL OF INFECTION')
# (82, 'JOURNAL OF INFECTIOUS DISEASES')
# (83, 'JOURNAL OF INHERITED METABOLIC')
# (84, 'JOURNAL OF INTERNAL MEDICINE')
# (85, 'JOURNAL OF INVESTIGATIVE DERMATOLOGY')
# (86, 'JOURNAL OF LEUKOCYTE BIOLOGY')
# (87, 'JOURNAL OF MECHANISMS OF AGEING AND DEVELOPMENT')
# (88, 'JOURNAL OF MEDICAL ETHICS')
# (89, 'JOURNAL OF MEDICAL GENETICS')
# (90, 'JOURNAL OF MEDICAL VIROLOGY')
# (91, 'JOURNAL OF MEDICINAL CHEMISTRY')
# (92, 'JOURNAL OF MICROBIOLOGY')
# (93, 'JOURNAL OF MICROSCOPY')
# (94, 'JOURNAL OF MOLECULAR BIOLOGY')
# (95, 'JOURNAL OF MOLECULAR ENDOCRINOLOGY')
# (96, 'JOURNAL OF MOLECULAR MEDICINE')
# (97, 'JOURNAL OF MOLECULAR NEUROSCIENCE')
# (98, 'JOURNAL OF NEURAL TRANSMISSION')
# (99, 'JOURNAL OF NEUROCHEMISTRY')
# (100, 'JOURNAL OF NEUROENDOCRINOLOGY')
# (101, 'JOURNAL OF NEUROINFLAMMATION')
# (102, 'JOURNAL OF NEUROLOGY')
# (103, 'JOURNAL OF NEUROLOGY & TRANSLATIONAL NEUROSCIENCE')
# (104, 'JOURNAL OF NEUROLOGY, NEUROSURGERY & PSYCHIATRY')
# (105, 'JOURNAL OF NEUROLOGY, NEUROSURGERY AND PSYCHIATRY')
# (106, 'JOURNAL OF NEUROPHYSIOLOGY')
# (107, 'JOURNAL OF NEUROSCIENCE')
# (108, 'JOURNAL OF NEUROSCIENCE METHODS')
# (109, 'JOURNAL OF NUTRITION')
# (110, 'JOURNAL OF NUTRITION EDUCATION AND BEHAVIOUR')
# (111, 'JOURNAL OF ORTHOPEDIC RESEARCH')
# (112, 'JOURNAL OF PAEDIATRIC UROLOGY')
# (113, 'JOURNAL OF PARASITOLOGY RESEARCH')
# (114, 'JOURNAL OF PATHOLOGY')
# (115, 'JOURNAL OF PHYSIOLOGY')
# (116, 'JOURNAL OF POVERTY AND SOCIAL JUSTICE')
# (117, 'JOURNAL OF PROTEOME RESEARCH')
# (118, 'JOURNAL OF PROTEOMICS')
# (119, 'JOURNAL OF PSYCHOPHARMACOLOGY')
# (120, 'JOURNAL OF PUBLIC HEALTH')
# (121, 'JOURNAL OF SLEEP RESEARCH')
# (122, 'JOURNAL OF SMALL ANIMAL PRACTICE')
# (123, 'JOURNAL OF STRUCTURAL BIOLOGY')
# (124, 'JOURNAL OF THE AMERICAN ACADEMY OF CHILD AND ADOLESCENT PSYCHIATRY')
# (125, 'JOURNAL OF THE AMERICAN CHEMICAL SOCIETY')
# (126, 'JOURNAL OF THE AMERICAN COLLEGE OF CARDIOLOGY')
# (127, 'JOURNAL OF THE AMERICAN SOCIETY FOR MASS SPECTROMETRY')
# (128, 'JOURNAL OF THE ASSOCIATION FOR RESEARCH IN OTOLARYNGOLOGY')
# (129, 'JOURNAL OF THE HISTORY OF THE BEHAVIORAL SCIENCES')
# (130, 'JOURNAL OF THE INTERNATIONAL AFRICAN INSTITUTE')
# (131, 'JOURNAL OF THE INTERNATIONAL AIDS SOCIETY')
# (132, 'JOURNAL OF THE NATIONAL CANCER INSTITUTE')
# (133, 'JOURNAL OF THE NEUROLOGICAL SCIENCES')
# (134, 'JOURNAL OF THE ROYAL SOCIETY INTERFACE')
# (135, 'JOURNAL OF THE ROYAL SOCIETY OF MEDICINE SHORT REPORTS')
# (136, 'JOURNAL OF THE ROYAL SOCIETY, INTERFACE')
# (137, 'JOURNAL OF THE ROYAL STATISTICAL SOCIETY: SERIES C (APPLIED STATISTICS)')
# (138, 'JOURNAL OF TRANSPORT GEOGRAPHY')
# (139, 'JOURNAL OF VIRAL HEPATITIS')
# (140, 'JOURNAL OF VIROL')
# (141, 'JOURNAL OF VIROLOGICAL METHODS')
# (142, 'JOURNAL OF VIROLOGY')
# (143, 'JOURNAL OF VISION')
# (144, 'JOURNAL OF VISUALIZED EXPERIEMENTS')
# (145, 'JOURNAL OF VISUALIZED EXPERIMENTS')
# (146, 'JOURNAL OF VISULAIZED EXPERMIMENTS')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  CURRENT BIOLOGY
#
# (0, 'CALCIFIED TISSUE INTERNATIONAL')
# (1, 'CANADIAN JOURNAL OF AFRICAN STUDIES')
# (2, 'CANCER LETTERS')
# (3, 'CANCER RESEARCH')
# (4, 'CARDIOVASCULAR RESEARCH')
# (5, 'CELL')
# (6, 'CELL ADHESION AND MIGRATION')
# (7, 'CELL AND TISSUE RESEARCH')
# (8, 'CELL CALCIUM')
# (9, 'CELL CYCLE')
# (10, 'CELL DEATH & DISEASE')
# (11, 'CELL DEATH AND DIFFERENTIATION')
# (12, 'CELL DEATH AND DISEASE')
# (13, 'CELL DEATH DIFFERENTIATION')
# (14, 'CELL HOST & MICROBE')
# (15, 'CELL HOST AND MICROBE')
# (16, 'CELL JOURNAL')
# (17, 'CELL METABOLISM')
# (18, 'CELL PRESS - CELL REPORTS')
# (19, 'CELL REPORTS')
# (20, 'CELL STEM CELL')
# (21, 'CELLULAR AND MOLECULAR CELL SCIENCES')
# (22, 'CELLULAR AND MOLECULAR LIFE SCIENCES')
# (23, 'CELLULAR MICROBIOLOGY')
# (24, 'CELLULAR SIGNALLING')
# (25, 'CENTAURUS')
# (26, 'CEREBRAL CORTEX')
# (27, 'CEREBRAL CORTEX ONLINE')
# (28, 'CEREBRAL CORTEX PRINT')
# (29, 'CHANNELS')
# (30, 'CHEMBIOCHEM')
# (31, 'CHEMICAL COMMUNICATION')
# (32, 'CHEMICAL SOCIETY REVIEWS')
# (33, 'CHEMISTRY - EUROPEAN JOURNAL')
# (34, 'CHEMMEDCHEM')
# (35, 'CHEMSITRY & BIOLOGY')
# (36, 'CHEST')
# (37, 'CHILD NEUROPSYCHOLOGY')
# (38, 'CHILD PSYCHOLOGY PSYCHIATRY')
# (39, 'CHILD: CARE, HEALTH DEVELOPMENT')
# (40, 'CHILD: CARE, HEATH & DEVELOPMENT')
# (41, 'CHILDS NERV SYST')
# (42, 'CHROMOSOME RESEARCH')
# (43, 'CHRONIC ILLNESS')
# (44, 'CIRCULATION RESEARCH')
# (45, 'CLINICAL AND EXPERIMENTAL ALLERGY')
# (46, 'CLINICAL AND VACCINE IMMUNOLOGY')
# (47, 'CLINICAL GENETICS')
# (48, 'CLINICAL INFECTIOUS DISEASES')
# (49, 'CLINICAL INFECTIOUS DISEASES ONLINE')
# (50, 'CLINICAL NEUROLOGY AND NEUROSURGERY')
# (51, 'CLINICAL PROTEOMICS')
# (52, 'CLINICAL RADIOLOGY')
# (53, 'CLINICAL TRANSCRIPTIONAL SCIENCE')
# (54, 'CLINICLA INFECTIOUS DISEASE')
# (55, 'COGNITION')
# (56, 'COGNITIVE DEVELOPMENT')
# (57, 'COGNITIVE PROCESSING')
# (58, 'COGNITIVE THERAPY AND RESEARCH')
# (59, 'COMPUTATIONAL BIOLOGY')
# (60, 'CONSCIOUSNESS & COGNITION')
# (61, 'CONSCIOUSNESS AND COGNITION')
# (62, 'CORTEX')
# (63, 'COST EFFECTIVENESS AND RESOURCE ALLOCATION')
# (64, 'CRIMINAL BEHAVIOR AND MENTAL HEALTH')
# (65, 'CURR BIOL.')
# (66, 'CURRENT ANALYTICAL CHEMISTRY')
# (67, 'CURRENT ATHEROSCLEROSIS REPORTS')
# (68, 'CURRENT BIOLOGY')
# (69, 'CURRENT OBSTETRICS AND GYNECOLOGY REPORTS')
# (70, 'CURRENT OPINION IN NEUROBIOLOGY')
# (71, 'CURRENT OPINION MICROBIOLOGY')
# (72, 'CURRENT OPINIONS IN NEUROBIOLOGY')
# (73, 'CURRENT TOPICS IN MEDICINAL CHEMISTRY')
# (74, 'CYTOSKELETON')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): y
# Which number corresponds to the best name? (Enter a number): 68
# Enter number(s) separated by commas: 65
# CURRENT BIOLOGY ['CURR BIOL.']
#
#
# Name:  MALARIA JOURNAL
#
# (0, 'MAGNETIC RESONANCE IN MEDICINE')
# (1, 'MALARIA JOURNAL')
# (2, 'MAMMALIAN GENOME')
# (3, 'MARTEN CHILD NUTR')
# (4, 'MATERNAL AND CHILD NUTRITION')
# (5, 'MATH BIOSCI')
# (6, 'MATRIX BIOLOGY')
# (7, 'MATURITAS')
# (8, 'MBIO')
# (9, 'MCP (MOLECULAR & CELLULAR PROTEOMICS)')
# (10, 'MECHANISMS OF AGEING AND DEVELOPMENT')
# (11, 'MEDICAL ANTHROPOLOGY')
# (12, 'MEDICAL HISTORY')
# (13, 'MEDICAL HUMANITIES')
# (14, 'MEDICAL LAW REVIEW')
# (15, 'METABOLOMICS')
# (16, 'METHODS IN MOLECULAR BIOLOGY')
# (17, 'MICROBES AND INFECTION')
# (18, 'MICROBES INFECT')
# (19, 'MICROBIOLOGY')
# (20, 'MOL BIO')
# (21, 'MOL BIOL AND EVOLUTION')
# (22, 'MOL PHARM')
# (23, 'MOLECLUAR & CELLULAR ENDOCRINOLOGY')
# (24, 'MOLECULAR & BIOCHEMICAL PARASITOLOGY')
# (25, 'MOLECULAR & CELLULAR PROTEOMICS')
# (26, 'MOLECULAR AND CELLULAR BIOCHEMISTRY')
# (27, 'MOLECULAR AND CELLULAR BIOLOGY')
# (28, 'MOLECULAR AND CELLULAR ENDOCRINOLOGY')
# (29, 'MOLECULAR AND CELLULAR PROTEOMICS')
# (30, 'MOLECULAR BIOLOGY')
# (31, 'MOLECULAR BIOLOGY AND EVOLUTION')
# (32, 'MOLECULAR BRAIN')
# (33, 'MOLECULAR CELL')
# (34, 'MOLECULAR ENDOCRINOLOGY')
# (35, 'MOLECULAR GENETICS & GENOMIC MEDICINE')
# (36, 'MOLECULAR GENETICS AND METABOLISM')
# (37, 'MOLECULAR IMMUNOLOGY')
# (38, 'MOLECULAR MEMBRANE BIOLOGY')
# (39, 'MOLECULAR MICROBIOLOGY')
# (40, 'MOLECULAR PAIN')
# (41, 'MOLECULAR PHYLOGENETICS AND EVOLUTION')
# (42, 'MOVEMENT DISORDERS')
# (43, 'MUCOSAL IMMUNOLOGY')
# (44, 'MUSCLE AND NERVE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N
# Name:  BMJ
#
# (0, 'BBA - MOLECULAR BASIS OF DISEASE')
# (1, 'BEHAVIOR RESEARCH AND THERAPY')
# (2, 'BEHAVIORAL NEUROSCIENCE')
# (3, 'BEHAVIOUR RESEARCH AND THERAPY')
# (4, 'BEHAVIOURAL BRAIN RESEARCH')
# (5, 'BIINFORMATICS')
# (6, 'BIOCHEM JOURNAL')
# (7, 'BIOCHEM SOC TRANS')
# (8, 'BIOCHEMICAL AND BIOPHYSICAL RESEARCH COMMUNICATIONS')
# (9, 'BIOCHEMICAL JOURNAL')
# (10, 'BIOCHEMICAL PHARMACOLOGY')
# (11, 'BIOCHEMICAL SOCIETY TRANSACTIONS')
# (12, 'BIOCHEMISTRY')
# (13, 'BIOCHIMICA ET BIOOHYSICA ACTA - GENE REGULATORY MECHANISMS')
# (14, 'BIOCHIMICA ET BIOOHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (15, 'BIOCHIMICA ET BIOPHYSICA ACTA (BBA) - MOLECULAR CELL RESEARCH')
# (16, 'BIOCHIMICA ET BIOPHYSICA ACTA - MOLECULAR BASIS OF DISEASE')
# (17, 'BIOCHIMIE')
# (18, 'BIOCONJUGATE CHEMISTRY')
# (19, 'BIOETHICS')
# (20, 'BIOGERONTOLOGY')
# (21, 'BIOINFORMATICS')
# (22, 'BIOINFORMATICS ONLINE')
# (23, 'BIOL OPEN')
# (24, 'BIOLOGICAL PSYCHIATRY')
# (25, 'BIOLOGICAL PSYCHOLOGY')
# (26, 'BIOLOGICIAL CHEMISTRY')
# (27, 'BIOLOGY')
# (28, 'BIOLOGY LETTERS')
# (29, 'BIOLOGY OPEN')
# (30, 'BIOMACROMOLECULES')
# (31, 'BIOMATERIALS')
# (32, 'BIOMED CENTRAL')
# (33, 'BIOMEDICAL MICRODEVICES')
# (34, 'BIOMOLECULAR NMR ASSIGNMENTS')
# (35, 'BIOPHYSICAL JOURNAL')
# (36, 'BIOPOLYMERS')
# (37, 'BIOSCIENCE REPORTS')
# (38, 'BIOSOCIETIES')
# (39, 'BIOSYSTEMS')
# (40, 'BIRTH DEFECTS RESEARCH PART A: CLINICAL AND MOLECULAR TERATOLOGY')
# (41, 'BJOPHTHALMOL')
# (42, 'BJP')
# (43, 'BLOOD')
# (44, 'BLOOD JOURNAL 2012')
# (45, 'BMC BIOLOGY')
# (46, 'BMC GENETICS')
# (47, 'BMC GENOME BIOLOGY')
# (48, 'BMC GENOMICS')
# (49, 'BMC GENOMICS.')
# (50, 'BMC HEALTH SERVICES RESEARCH')
# (51, 'BMC INFECTIOUS DISEASES')
# (52, 'BMC MEDICAL ETHICS')
# (53, 'BMC MEDICAL GENETICS')
# (54, 'BMC MEDICAL IMAGING')
# (55, 'BMC MEDICINE')
# (56, 'BMC MICROBIOLOGY')
# (57, 'BMC MOLECULAR BIOLOGY')
# (58, 'BMC NEUROLOGY')
# (59, 'BMC NEUROSCIENCE')
# (60, 'BMC PEDIATRICS')
# (61, 'BMC PSYCHIATRY')
# (62, 'BMC PUBLIC HEALTH')
# (63, 'BMC RESEARCH NOTES')
# (64, 'BMC VETERINARY RESEARCH')
# (65, 'BMJ')
# (66, 'BMJ OPEN')
# (67, 'BMJ QUALITY AND SAFETY')
# (68, 'BMS GENOMICS')
# (69, 'BONE')
# (70, 'BRAIN')
# (71, 'BRAIN AND COGNITION')
# (72, 'BRAIN AND LANGUAGE')
# (73, 'BRAIN RESEARCH')
# (74, 'BRAIN STRUCTURE AND FUNCTION')
# (75, 'BRAIN TOPOGRAPHY')
# (76, 'BRIEFINGS IN BIOINFORMATICS')
# (77, 'BRIEFINGS IN FUNCTIONAL GENOMICS')
# (78, 'BRITISH JOUNAL OF PHARMACOLOGY')
# (79, 'BRITISH JOURNAL FOR THE HISTORY OF SCIENCE')
# (80, 'BRITISH JOURNAL OF CANCER')
# (81, 'BRITISH JOURNAL OF CLINICAL PHARMACOLOGY')
# (82, 'BRITISH JOURNAL OF DERMATOLOGY')
# (83, 'BRITISH JOURNAL OF HAEMATOLOGY')
# (84, 'BRITISH JOURNAL OF OPHTHALMOLOGY')
# (85, 'BRITISH JOURNAL OF OPTHALMOLOGY')
# (86, 'BRITISH JOURNAL OF PHARMACOLOGY')
# (87, 'BRITISH JOURNAL OF PSYCHIATRY')
# (88, 'BRITISH JOURNAL OF THE HISTORY OF SCIENCE')
# (89, 'BRITISH MEDICAL BULLETIN')
# (90, 'BRITISH MEDICAL JOURNAL')
# (91, 'BRITSH JOURNAL OF PSYCHIATRY')
# (92, 'BRT JNL CLINICAL PHARMACOLOGY')
# (93, 'BULLETIN OF THE HISTORY OF MEDICINE')
# Does the name in question match any of the items above? (Enter 'y' or 'N'): N

# %% [markdown]
# ### 1. Determine the five most common journals and the total articles for each.
# ### _MY RESULTS AFTER CLEANING_

# %%
# Top 5 Journals and the total articles for each
top_20 = wellcome['Journal title'].value_counts().head(20)
top_20.head(5)
# Out:
# PLOS ONE                                           208
# JOURNAL OF BIOLOGICAL CHEMISTRY                     71
# PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES     37
# NEUROIMAGE                                          31
# NUCLEIC ACIDS RESEARCH                              29
# Name: Journal title, dtype: int64

# %% [markdown]
# ### 2. Calculate the mean, median, and standard deviation of the open-access cost per article for each journal.

# %%
# Calculate mean, median, and standard deviation for article costs for each journal
costs = []
for name in list(top_20.head(5).index):
    # Build journal DataFrames
    df_journal = wellcome[wellcome['Journal title'] == name]
    # Build journal series
    series_journal_cost = df_journal['COST (£) charged to Wellcome (inc VAT when charged)']
    
    # Remove the '£' symbol from each record in the cost column
    sjc_floats = series_journal_cost.apply(lambda x: float(x[1:]) if x.startswith('£') else float(x))
    # Remove cost outliers >= £150,000
    sjc_no_outliers = sjc_floats.apply(lambda x: x if x < 150000.00 else None).dropna()
    costs.append(sjc_no_outliers)
    
    print('Journal Name: ', name)
    print('Mean:   ', np.mean(sjc_no_outliers))
    print('Median: ', np.median(sjc_no_outliers))
    print('Std Dev:', np.std(sjc_no_outliers))
    print()
# Out:
# Journal Name:  PLOS ONE
# Mean:    935.5772361809031
# Median:  896.99
# Std Dev: 194.16468771037597
#
# Journal Name:  JOURNAL OF BIOLOGICAL CHEMISTRY
# Mean:    1384.2218840579712
# Median:  1314.53
# Std Dev: 389.20099406785545
#
# Journal Name:  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCES
# Mean:    772.9191666666668
# Median:  732.01
# Std Dev: 365.0141675208953
#
# Journal Name:  NEUROIMAGE
# Mean:    2212.1812903225805
# Median:  2326.43
# Std Dev: 268.7507817091939
#
# Journal Name:  NUCLEIC ACIDS RESEARCH
# Mean:    1162.344827586207
# Median:  852.0
# Std Dev: 434.4607657269006
